# %%
import pandas as pd
import numpy as np

# %%
miss_value = ['']
clientlist = pd.read_csv('2018 ABACUS CLIENTS.csv')
# clientlist = clientlist.dropna()
# clientlist

# %%
productlist = pd.read_csv('product.csv',na_values =miss_value )
# productlist = productlist.dropna()
# productlist
productlist
# Out:
#                                                  p_name   unit    dollar  \
# 0                   Meat Bone Meal Pet Food Animal Food   TONS     460.0
# 1                            Animal Food Feed Grade DCP   TONS     300.0
# 2              Food Grade Milk Powder Replacer for Pigs   TONS    2000.0
# 3            Meat Bone Meal Animal Food Health Feed\r\n   TONS     460.0
# 4                    Fish Meal Poultry Food Animal Feed   TONS     500.0
# 5                Additives High Allicin Garlic Granules   TONS    1900.0
# 6                                  Feed Grade Fish Meal   TONS     500.0
# 7           Protein Powder Animal Food Corn Gluten Meal   TONS     960.0
# 8                        Feed Grade Dicalcium Phosphate   TONS     300.0
# 9     Corn Gluten Meal Animal Food High Quality New ...   TONS     960.0
# 10                                   Feed Grade DCP 18%   TONS     300.0
# 11                            Fish Meal Livestocks Food   TONS     500.0
# 12                             Fish Meal Protein Powder   TONS     600.0
# 13                Lysine HCl 98.5% for Animal Nutrition   TONS    1125.0
# 14              Animal Feed Additives 98.5% L-Threonine   TONS    2800.0
# 15               Feed Grade Lysine HCl 98. % for Animal   TONS    1200.0
# 16                             Mono-Dicalcium Phosphate   TONS     350.0
# 17                            72%Fish Meal for Fish Pig   TONS     500.0
# 18                        Animal Farm Feed Storage Silo    PCS    3500.0
# 19           Lysine Feed Additives Animal Food L-Lysine   TONS    1300.0
# 20                       L-Threonine 98.5% (FEED GRADE)   TONS    1460.0
# 21                  Garlic Powder (100-120) Animal Feed   TONS    2600.0
# 22           Fat Powder for Milk Replacer or in-Filling   TONS    2000.0
# 23            Additive Grade HCl Sulfate L Lysine 98.5%   TONS    1200.0
# 24           Animal Poultry Feed Pemix and Additive\r\n   TONS    2000.0
# 25                    Non Dairy Creamer Feed Addittive    TONS    1000.0
# 26          Feed Additives L-Lysine Animal Fodder 98.5%   TONS    1200.0
# 27                              Wheat Gluten Flour Meal   TONS    1380.0
# 28             Hot Ganlvanized Steel Grain Storage Silo    PCS    5000.0
# 29                    18% TCP Tricalcium Phosphate \r\n   TONS     850.0
# ...                                                 ...    ...       ...
# 2897       Thermoforming Machine for PP PS Pet Material    PCS   75000.0
# 2898          Candy Snack Food Chocolate Making Machine   SETS   65000.0
# 2899  Corn Flakes Cereal Snacks Food Frying Chips Ma...   SETS   25000.0
# 2900   Tray Fast Food Package Containers Making Machine    PCS  127000.0
# 2901      Packaging Equipment Food Processing Machinery   SETS  280000.0
# 2902       Thermoforming Machine for PP PS Pet Material    PCS   40000.0
# 2903                Food Machine for Meat Chicken Slice    PCS   16666.0
# 2904                          Twin Screw Snack Extruder    PCS   35000.0
# 2905              Food Machine for Making Donut Zs-Np-1    PCS    1500.0
# 2906               Poultry Floating Fish Shrimp Machine    PCS    1680.0
# 2907    Industrial Vegetable & Fruit Dehydrator Machine    PCS   13000.0
# 2908  Food Processing Fruit/Vegetable /Food/Seafood ...   SETS    3000.0
# 2909  Plastic Food Container Bowl Thermoforming Mach...    PCS   24400.0
# 2910        Starch Food Container Thermoforming Machine   SETS   90000.0
# 2911       Ce Approved Cake Machineآ forآ Foodآ Factory  ROLLS   50000.0
# 2912    CE Dry Single Screw Floating Fish Foodآ Machine    PCS   28000.0
# 2913   Plasticآ Foodآ Storage Container Makingآ Machine   SETS   60000.0
# 2914  Rolled Sugar ConeMachineآ forآ Food (CBIII-61*2A)   SETS  230000.0
# 2915       Sunflower Seeds /Food Making Coating Machine   SETS   35000.0
# 2916  Corn Puffآ Foodآ Machineآ for Children (SLG 10...   SETS   30000.0
# 2917                  Hot Air Food Drying Dryer Machine    PCS   15000.0
# 2918  PS PSP Foam Lunchآ Food Container and Trayآ Ma...   SETS  240000.0
# 2919  Conche Machine-Professional Food Machine for C...    PCS    7200.0
# 2920  PS Foamآ FoodContainer Makingآ Machine(MT105/120)   SETS   80000.0
# 2921          Food Cleaning Air Bubble Washingآ Machine    PCS    3000.0
# 2922            Automatic Food Machine for Biscuit Line    PCS  500000.0
# 2923              Lineآ Foodآ Extruder Packingآ Machine   SETS   10000.0
# 2924                      Pet Food Processing Machinery   SETS   85000.0
# 2925                          Pet Feed Extruder Machine   SETS   15000.0
# 2926           Automaticآ Food Cleaning Washing Machine    PCS    7800.0
#
#           dirham       euro            type  tradingTypeCode
# 0        1688.20     395.60     ANIMAL FOOD               22
# 1        1101.00     258.00     ANIMAL FOOD               22
# 2        7340.00    1720.00     ANIMAL FOOD               22
# 3        1688.20     395.60     ANIMAL FOOD               22
# 4        1835.00     430.00     ANIMAL FOOD               22
# 5        6973.00    1634.00     ANIMAL FOOD               22
# 6        1835.00     430.00     ANIMAL FOOD               22
# 7        3523.20     825.60     ANIMAL FOOD               22
# 8        1101.00     258.00     ANIMAL FOOD               22
# 9        3523.20     825.60     ANIMAL FOOD               22
# 10       1101.00     258.00     ANIMAL FOOD               22
# 11       1835.00     430.00     ANIMAL FOOD               22
# 12       2202.00     516.00     ANIMAL FOOD               22
# 13       4128.75     967.50     ANIMAL FOOD               22
# 14      10276.00    2408.00     ANIMAL FOOD               22
# 15       4404.00    1032.00     ANIMAL FOOD               22
# 16       1284.50     301.00     ANIMAL FOOD               22
# 17       1835.00     430.00     ANIMAL FOOD               22
# 18      12845.00    3010.00     ANIMAL FOOD               22
# 19       4771.00    1118.00     ANIMAL FOOD               22
# 20       5358.20    1255.60     ANIMAL FOOD               22
# 21       9542.00    2236.00     ANIMAL FOOD               22
# 22       7340.00    1720.00     ANIMAL FOOD               22
# 23       4404.00    1032.00     ANIMAL FOOD               22
# 24       7340.00    1720.00     ANIMAL FOOD               22
# 25       3670.00     860.00     ANIMAL FOOD               22
# 26       4404.00    1032.00     ANIMAL FOOD               22
# 27       5064.60    1186.80     ANIMAL FOOD               22
# 28      18350.00    4300.00     ANIMAL FOOD               22
# 29       3119.50     731.00     ANIMAL FOOD               22
# ...          ...        ...             ...              ...
# 2897   275250.00   64500.00  WOOD MACHINERY               29
# 2898   238550.00   55900.00  WOOD MACHINERY               29
# 2899    91750.00   21500.00  WOOD MACHINERY               29
# 2900   466090.00  109220.00  WOOD MACHINERY               29
# 2901  1027600.00  240800.00  WOOD MACHINERY               29
# 2902   146800.00   34400.00  WOOD MACHINERY               29
# 2903    61164.22   14332.76  WOOD MACHINERY               29
# 2904   128450.00   30100.00  WOOD MACHINERY               29
# 2905     5505.00    1290.00  WOOD MACHINERY               29
# 2906     6165.60    1444.80  WOOD MACHINERY               29
# 2907    47710.00   11180.00  WOOD MACHINERY               29
# 2908    11010.00    2580.00  WOOD MACHINERY               29
# 2909    89548.00   20984.00  WOOD MACHINERY               29
# 2910   330300.00   77400.00  WOOD MACHINERY               29
# 2911   183500.00   43000.00  WOOD MACHINERY               29
# 2912   102760.00   24080.00  WOOD MACHINERY               29
# 2913   220200.00   51600.00  WOOD MACHINERY               29
# 2914   844100.00  197800.00  WOOD MACHINERY               29
# 2915   128450.00   30100.00  WOOD MACHINERY               29
# 2916   110100.00   25800.00  WOOD MACHINERY               29
# 2917    55050.00   12900.00  WOOD MACHINERY               29
# 2918   880800.00  206400.00  WOOD MACHINERY               29
# 2919    26424.00    6192.00  WOOD MACHINERY               29
# 2920   293600.00   68800.00  WOOD MACHINERY               29
# 2921    11010.00    2580.00  WOOD MACHINERY               29
# 2922  1835000.00  430000.00  WOOD MACHINERY               29
# 2923    36700.00    8600.00  WOOD MACHINERY               29
# 2924   311950.00   73100.00  WOOD MACHINERY               29
# 2925    55050.00   12900.00  WOOD MACHINERY               29
# 2926    28626.00    6708.00  WOOD MACHINERY               29
#
# [2927 rows x 7 columns]

# %%
Colist = pd.read_excel('List of Companies.xlsx')
# Colist = Colist.dropna()
Colist
# Out:
#                                              companies  \
# 0                             ORLUX IMPORT-EXPORT GMBH
# 1    SHANDONG FUPPON AGRICULTURAL MACHINERY EQUIPME...
# 2                                       New Hope Group
# 3                                              Cargill
# 4                                         Land O'Lakes
# 5                                                  BRF
# 6                                      ForFarmers N.V.
# 7                                              Nutreco
# 8                                           JA Zen-Noh
# 9                                 ADII SYNERGY SDN BHD
# 10                                           FIMAR SPA
# 11                   KAITO ENTERPRISES COMPANY LIMITED
# 12                                ADII SYNERGY SDN BHD
# 13                                           FIMAR SPA
# 14                   KAITO ENTERPRISES COMPANY LIMITED
# 15         SUZHOU CLEANSTAR ELECTRIC APPLIANCE CO. LTD
# 16              GUANGDONG ZHONGBAO KITCHENWARE CO. LTD
# 17                HOWELL CLEAN APPLIANCES (HK) LIMITED
# 18              GUANGDONG ZHONGBAO KITCHENWARE CO. LTD
# 19                HOWELL CLEAN APPLIANCES (HK) LIMITED
# 20         SUZHOU CLEANSTAR ELECTRIC APPLIANCE CO. LTD
# 21                   AnHuiarts & Crafts imp.exp.Co.Ltd
# 22                   ANHUIARTS & CRAFTS IMP.EXP.CO.LTD
# 23                                      MENGYANG GROUP
# 24                                          SENECA SRL
# 25                              R.B.AUTOMAZIONE S.R.L.
# 26                           ARAYMOND FLUID CONNECTION
# 27                               AUTOMATION CO. UNITED
# 28                    FAURECIA SIEGES D AUTOMOBILE SAS
# 29                            GTEC AUTOMOBILE PTE LTD.
# ..                                                 ...
# 539                       ELINO INTERNATIONAL CO., LTD
# 540                                     ENITENCNI SAGL
# 541           FOSHAN ZHENGSAU STAINLESS STEEL CO. LTD.
# 542             HONGKONG HUIXING STEEL COMPANY LIMITED
# 543                              JIANGSU METAL LIMITED
# 544  JOHOR LAND BERHAD JALAN BUNITED KINGDOMIT MUTIARA
# 545                NINGBO ZHONGHUAN STEEL BALL FACTORY
# 546             OZMET METAL MAL IMAL SAN IC VE DIS LTD
# 547                     PERKIS BAKIR ALASIMLARI SANAYI
# 548                    QINGDAO JIAHEXIN STEEL CO., LTD
# 549                SARBAK METAL TICARET VE SANAYI A.Ş.
# 550      SHANDONG SHUANGWANG ALUMINUM INDUSTRY CO. LTD
# 551        SHENZHEN NEW ORIGIN SPECIAL STEEL CO., LTD.
# 552                          SHINING HOUSEWARES CO LTD
# 553                               AKIJ JUTE MILLS LTD.
# 554             Hangzhou Yinyan Silk Weaving Co., Ltd.
# 555                               AKIJ JUTE MILLS LTD.
# 556                  SHANGHAI CEDL (IM / EX) CO., LTD.
# 557              SHANGHAI BESTWAY INTERNATIONAL CO LTD
# 558            SHANGHAI FAVORS IMPORT & EXPORT CO. LTD
# 559          SHANGHAI JIHAO INT'L ENTERPRISE CO., LTD.
# 560    SHANGHAI MALMAM INTERNATIONAL TRADING CO., LTD.
# 561          SHANGHAI MEILAN APPAREL TECHNOLOGY CO,LTD
# 562     SHIJIAZHUANG JILI TEXTILE LINING CLOTH CO.,LTD
# 563            SHANGHAI P&E IMPORT AND EXPORT CO.,LTD.
# 564                              CALLENS AFRICAN-WOODS
# 565                                HUSONG WOOD CO. LTD
# 566                            JIANGSU LANDISI WOOD CO
# 567                                      Lagae Hout nv
# 568                                  NATURAL TRADE LTD
#
#                         country                    type  \
# 0    Frankfurt Am Main- Germany            AGRICULTURAL
# 1              Liaocheng- China  AGRICULTURAL MACHINERY
# 2            Gansu Sheng- China             ANIMAL FOOD
# 3         Topeka- United States             ANIMAL FOOD
# 4        Florida- United States             ANIMAL FOOD
# 5     Ponta Grossa - PR- Brazil             ANIMAL FOOD
# 6           Lochem- Netherlands             ANIMAL FOOD
# 7          Boxmeer- Netherlands             ANIMAL FOOD
# 8                  Tokyo- Japan             ANIMAL FOOD
# 9        Kuala Lumpur- Malaysia               APLLIANCE
# 10       Villa Verucchio- Italy               APLLIANCE
# 11             Hong Kong- China               APLLIANCE
# 12       Kuala Lumpur- Malaysia               APLLIANCE
# 13       Villa Verucchio- Italy               APLLIANCE
# 14             Hong Kong- China               APLLIANCE
# 15              Shanghai- China               APPLIANCE
# 16               Guandong China               APPLIANCE
# 17            Hong Kong - China               APPLIANCE
# 18               Guandong China               APPLIANCE
# 19            Hong Kong - China               APPLIANCE
# 20              Shanghai- China               APPLIANCE
# 21                  Anhui-China                     ART
# 22                  Anhui-China                     ART
# 23               Jiangsu- China               SPARE CAR
# 24                 Padua- Italy               SPARE CAR
# 25                Genova- Italy               SPARE CAR
# 26             Grenoble- France               SPARE CAR
# 27    Liverpool- United Kingdom               SPARE CAR
# 28             Nanterre- France               SPARE CAR
# 29                Padova- Italy               SPARE CAR
# ..                          ...                     ...
# 539             Shanghai- China                   STEEL
# 540           Bern- Switzerland                   STEEL
# 541            Guangdong- China                   STEEL
# 542            Hong Kong- China                   STEEL
# 543              Jiangsu- China                   STEEL
# 544             Johor- Malaysia                   STEEL
# 545               NINGBO- China                   STEEL
# 546            Istanbul. Turkey                   STEEL
# 547            Istanbul- Turkey                   STEEL
# 548         Qingdao City- China                   STEEL
# 549            Istanbul- Turkey                   STEEL
# 550             Shandong- China                   STEEL
# 551             Shenzhen- China                   STEEL
# 552             Shenzhen- China                   STEEL
# 553           Dhaka- Bangladesh                 TEXTILE
# 554             Hangzhou- China                 TEXTILE
# 555           Dhaka- Bangladesh                 TEXTILE
# 556             Shanghai- China                 TEXTILE
# 557             Shanghai- China                 TEXTILE
# 558             Shanghai- China                 TEXTILE
# 559             Shanghai- China                 TEXTILE
# 560             Shanghai- China                 TEXTILE
# 561              Shanghai China                 TEXTILE
# 562                Hebei- China                 TEXTILE
# 563             Shanghai- China       TEXTILE MACHINERY
# 564             Rekkem- Belgium                    WOOD
# 565             Shanghai- China                    WOOD
# 566              Jiangsu- China                    WOOD
# 567           Kortrijk- Belgium                    WOOD
# 568           Vancouver- Canada                    WOOD
#
#                       origin  loading  discharge  tradingTypeCode
# 0           Origin : Germany      NaN        NaN             21.0
# 1             Origin : China      NaN        NaN             21.0
# 2             Origin : China      NaN        NaN             22.0
# 3     Origin : United States      NaN        NaN             22.0
# 4     Origin : United States      NaN        NaN             22.0
# 5            Origin : Brazil      NaN        NaN             22.0
# 6       Origin : Netherlands      NaN        NaN             22.0
# 7       Origin : Netherlands      NaN        NaN             22.0
# 8             Origin : Japan      NaN        NaN             22.0
# 9          Origin : Malaysia      NaN        NaN             17.0
# 10            Origin : Italy      NaN        NaN             17.0
# 11            Origin : China      NaN        NaN             17.0
# 12         Origin : Malaysia      NaN        NaN             17.0
# 13            Origin : Italy      NaN        NaN             17.0
# 14            Origin : China      NaN        NaN             17.0
# 15            Origin : China      NaN        NaN             17.0
# 16            Origin : China      NaN        NaN             17.0
# 17            Origin : China      NaN        NaN             17.0
# 18            Origin : China      NaN        NaN             17.0
# 19            Origin : China      NaN        NaN             17.0
# 20            Origin : China      NaN        NaN             17.0
# 21            Origin : China      NaN        NaN              NaN
# 22            Origin : China      NaN        NaN              NaN
# 23            Origin : China      NaN        NaN             26.0
# 24            Origin : Italy      NaN        NaN             26.0
# 25            Origin : Italy      NaN        NaN             26.0
# 26           Origin : France      NaN        NaN             26.0
# 27   Origin : United Kingdom      NaN        NaN             26.0
# 28           Origin : France      NaN        NaN             26.0
# 29            Origin : Italy      NaN        NaN             26.0
# ..                       ...      ...        ...              ...
# 539           Origin : China      NaN        NaN              5.0
# 540     Origin : Switzerland      NaN        NaN              5.0
# 541           Origin : China      NaN        NaN              5.0
# 542           Origin : China      NaN        NaN              5.0
# 543           Origin : China      NaN        NaN              5.0
# 544        Origin : Malaysia      NaN        NaN              5.0
# 545           Origin : China      NaN        NaN              5.0
# 546          Origin : Turkey      NaN        NaN              5.0
# 547          Origin : Turkey      NaN        NaN              5.0
# 548           Origin : China      NaN        NaN              5.0
# 549          Origin : Turkey      NaN        NaN              5.0
# 550           Origin : China      NaN        NaN              5.0
# 551           Origin : China      NaN        NaN              5.0
# 552           Origin : China      NaN        NaN              5.0
# 553      Origin : Bangladesh      NaN        NaN             54.0
# 554           Origin : China      NaN        NaN             54.0
# 555      Origin : Bangladesh      NaN        NaN             54.0
# 556           Origin : China      NaN        NaN             54.0
# 557           Origin : China      NaN        NaN             54.0
# 558           Origin : China      NaN        NaN             54.0
# 559           Origin : China      NaN        NaN             54.0
# 560           Origin : China      NaN        NaN             54.0
# 561           Origin : China      NaN        NaN             54.0
# 562           Origin : China      NaN        NaN             54.0
# 563           Origin : China      NaN        NaN              NaN
# 564         Origin : Belgium      NaN        NaN             29.0
# 565           Origin : China      NaN        NaN             29.0
# 566           Origin : China      NaN        NaN             29.0
# 567         Origin : Belgium      NaN        NaN             29.0
# 568          Origin : Canada      NaN        NaN             29.0
#
# [569 rows x 7 columns]

# %%
track = pd.read_excel('TRACK.xlsx')
track
# Out:
#        refrence                       COMPANY NAME       CO.City  \
# 0      HLG-0689  HORIZONE LINE GENERAL TRADING LLC  Dubai- U.A.E
# 1      HLG-0754  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 2      HLG-0690  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 3      HLG-0725  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 4      HLG-0756  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 5      HLG-0746  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 6      HLG-0684  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 7      HLG-0713  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 8      HLG-0714  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 9      HLG-0761  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 10     HLG-0764  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 11     HLG-0673  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 12     HLG-0715  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 13     HLG-0747  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 14     HLG-0668  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 15     HLG-0672  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 16     HLG-0736  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 17     HLG-0659  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 18     HLG-0765  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 19     HLG-0729  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 20     HLG-0667  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 21     HLG-0711  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 22     HLG-0742  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 23     HLG-0738  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 24     HLG-0675  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 25     HLG-0702  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 26     HLG-0721  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 27     HLG-0731  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 28     HLG-0739  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 29     HLG-0701  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# ..          ...                                ...           ...
# 36     HLG-0674  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 37     HLG-0720  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 38  HLG-0681-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 39  HLG-0763-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 40  HLG-0750-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 41  HLG-0758-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 42  HLG-0692-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 43  HLG-0696-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 44  HLG-0717-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 45  HLG-0727-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 46  HLG-0748-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 47  HLG-0755-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 48  HLG-0654-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 49  HLG-0708-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 50  HLG-0663-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 51  HLG-0749-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 52  HLG-0700-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 53  HLG-0682-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 54  HLG-0759-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 55  HLG-0745-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 56  HLG-0737-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 57  HLG-0760-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 58  HLG-0676-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 59  HLG-0657-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 60  HLG-0735-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 61  HLG-0753-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 62  HLG-0677-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 63  HLG-0762-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 64  HLG-0685-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
# 65  HLG-0699-CL  HORIZONE LINE GENERAL TRADING LLC    Dubai- UAE
#
#                 SOURCE COMPANY         SourceCo.City TYPE OF TRANSACTION  \
# 0   TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 1   TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 2   TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 3   TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 4   TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 5   TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 6   TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 7   TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 8   TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 9   TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 10  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 11  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 12  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 13  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 14  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 15  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 16  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 17  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 18  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 19  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 20  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 21  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 22  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 23  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 24  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 25  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 26  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 27  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 28  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 29  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# ..                         ...                   ...                 ...
# 36  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 37  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 38  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 39  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 40  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 41  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 42  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 43  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 44  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 45  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 46  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 47  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 48  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 49  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 50  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 51  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 52  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 53  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 54  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 55  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 56  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 57  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 58  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 59  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 60  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 61  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 62  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 63  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 64  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
# 65  TANGSHAN YIFEI TRADING CO.  Tangshan City- China      GOODS IN TRUST
#
#          MONTH  TYPE OFProducts        date      amount currency  \
# 0   MARCH 2019               35  02/03/2019    93421.00      AED
# 1   MARCH 2019               35  19/03/2019   700000.00      AED
# 2   MARCH 2019               35  02/03/2019   309701.00      AED
# 3   MARCH 2019               35  12/03/2019    94486.59     EURO
# 4   MARCH 2019               13  21/03/2019   150000.00      AED
# 5   MARCH 2019               35  21/03/2019    15059.37     EURO
# 6   MARCH 2019               25  18/03/2019   350000.00      AED
# 7   MARCH 2019               25  19/03/2019   300000.00      AED
# 8   MARCH 2019               25  21/03/2019   450000.00      AED
# 9   MARCH 2019               25  12/03/2019   400000.00      AED
# 10  MARCH 2019               25  21/03/2019   350000.00      AED
# 11  MARCH 2019               35  06/03/2019   183750.00      AED
# 12  MARCH 2019               35  06/03/2019   220013.55     EURO
# 13  MARCH 2019               35  21/03/2019   285013.37     EURO
# 14  MARCH 2019               35  02/03/2019   101283.00      AED
# 15  MARCH 2019               35  06/03/2019   139555.00      AED
# 16  MARCH 2019               35  18/03/2019    82109.78     EURO
# 17  MARCH 2019               35  04/03/2019  1042600.00      AED
# 18  MARCH 2019               35  07/03/2019     9175.12      USD
# 19  MARCH 2019               35  14/03/2019    32466.50     EURO
# 20  MARCH 2019               35  04/03/2019    97560.00     EURO
# 21  MARCH 2019                1  17/03/2019  1378000.00      AED
# 22  MARCH 2019               35  20/03/2019    96617.00     EURO
# 23  MARCH 2019               35  19/03/2019    95566.00     EURO
# 24  MARCH 2019               35  06/03/2019   433850.00      AED
# 25  MARCH 2019               35  13/03/2019   901204.00      AED
# 26  MARCH 2019               35  09/03/2019   111676.70     EURO
# 27  MARCH 2019               35  14/03/2019    65208.50     EURO
# 28  MARCH 2019               35  19/03/2019    20592.00     EURO
# 29  MARCH 2019               35  13/03/2019   623186.00      AED
# ..         ...              ...         ...         ...      ...
# 36  MARCH 2019               35  06/03/2019   400000.00      AED
# 37  MARCH 2019               35  07/03/2019    38377.85     EURO
# 38  MARCH 2019               35  18/03/2019   730880.00      AED
# 39  MARCH 2019               35  19/03/2019  1433602.00      AED
# 40  MARCH 2019               35  18/03/2019  1523268.00      AED
# 41  MARCH 2019               35  05/03/2019   578366.00      AED
# 42  MARCH 2019               35  04/03/2019  1500000.00      AED
# 43  MARCH 2019               35  06/03/2019   878647.00      AED
# 44  MARCH 2019               35  07/03/2019   138208.00     EURO
# 45  MARCH 2019               35  07/03/2019   293495.46     EURO
# 46  MARCH 2019               35  13/03/2019   741711.29     EURO
# 47  MARCH 2019               35  13/03/2019   743980.00      AED
# 48  MARCH 2019               35  04/03/2019  3000000.00      AED
# 49  MARCH 2019               35  05/03/2019  4362955.00      AED
# 50  MARCH 2019               35  16/03/2019  4204435.00      AED
# 51  MARCH 2019                1  13/03/2019  2827000.00      AED
# 52  MARCH 2019                1  02/03/2019   759440.00      AED
# 53  MARCH 2019               35  18/03/2019   877000.00      AED
# 54  MARCH 2019               35  07/03/2019  1600000.00      AED
# 55  MARCH 2019               35  19/03/2019   491655.15     EURO
# 56  MARCH 2019               35  16/03/2019   145019.40     EURO
# 57  MARCH 2019               35  09/03/2019  1000000.00      AED
# 58  MARCH 2019               35  05/03/2019  4610000.00      AED
# 59  MARCH 2019               35  05/03/2019  5684238.00      AED
# 60  MARCH 2019               35  14/03/2019   205448.94     EURO
# 61  MARCH 2019               35  19/03/2019  1054691.00      AED
# 62  MARCH 2019               35  04/03/2019  5500000.00      AED
# 63  MARCH 2019               35  17/03/2019  3736859.00      AED
# 64  MARCH 2019               35  19/03/2019   649842.00      AED
# 65  MARCH 2019               35  06/03/2019   635764.00      AED
#
#                                  exporter/repExporter  \
# 0                                 AL FEEL TRADING LLC
# 1                                 AL FEEL TRADING LLC
# 2                       ALKHALSAN GENERAL TRADING LLC
# 3                                  ANVERALLY AND SONS
# 4                           ANWAAR MEDICAL CENTER LLC
# 5                           BGRS TEXTILE SERVICES LLP
# 6            BRIGHT POINT HEAVY EQUIPMENT TRADING LLC
# 7            BRIGHT POINT HEAVY EQUIPMENT TRADING LLC
# 8            BRIGHT POINT HEAVY EQUIPMENT TRADING LLC
# 9            BRIGHT POINT HEAVY EQUIPMENT TRADING LLC
# 10           BRIGHT POINT HEAVY EQUIPMENT TRADING LLC
# 11                       BUZWAIR GENERAL TRADING LLC
# 12              DMV-FONTERRA EXCIPIENTS GMBH & CO. KG
# 13              DMV-FONTERRA EXCIPIENTS GMBH & CO. KG
# 14                     EMAC ENGINEERING SERVICES LLC
# 15                        FARAHI GENERAL TRADING LLC
# 16                                   GEOCLIMA S.R.L
# 17          GULF PROMPT PARTNERS GENERAL TRADING LLC
# 18                     HARDY EXPORT COMPANY (PVT) LTD
# 19                                 JET PROFIT CO.,LTD
# 20              KLEBCHEMIE M. G. BECKER GMBH & CO. KG
# 21         MAGIC BRICK BUILDING MATERIAL TRADING LLC
# 22                                 MARBO ITALIA SPA
# 23                           MONTE STELLA TRADING LLC
# 24                          NEWROZ BANEH TRADING LLC
# 25                      OPAL INTERNATIONALTRADING FZE
# 26                                    P&A CORPORATION
# 27                               POINT MOBILE CO.,LTD
# 28               RAMZ AL HAQEEGA GENERAL TRADING LLC
# 29                    RECAZ STAR GENERAL TRADING LLC
# ..                                                ...
# 36                                VIVOTEK MIDDLE EAST
# 37                                ZYTOMED SYSTEM GMBH
# 38                               TUF COMMODITIES DMCC
# 39               TOURANTO FLAVOURS AND FRAGRANCES FZE
# 40               TOURANTO FLAVOURS AND FRAGRANCES FZE
# 41                 TAJ AL MULOOK GENERAL TRADING LLC
# 42                        SOREN SKY VIEW TRADING LLC
# 43                                    POLY BRAND FZCO
# 44         PETROCHEMICALS & SOLVENTS MIDDLE EAST DMCC
# 45                              PENTAX INDUSTRIES SPA
# 46                               EURO OTC PHARMA GMBH
# 47                             NORTH WEST TRADING LLC
# 48  MOON STONE HOME ELECTRICAL APPLIANCES TRADING LLC
# 49                  MDKT TRADING FZE
# 50                  MDKT TRADING FZE
# 51         LAKE VIEW BUILDING MATERIALS TRADING LLC
# 52               LAKE VIEW BUILDING MATERIALS LLC
# 53                     GREEN CITY GENERAL TRADING LLC
# 54                     GREEN CITY GENERAL TRADING LLC
# 55                                 EBC KOREA CO.,LTD
# 56                                     DRALON GMBH
# 57                               DOX TECHNOLOGIES LLC
# 58            DANO INTERNATIONAL TRADING LLC
# 59            DANO INTERNATIONAL TRADING LLC
# 60                       CY PRECISION INDUSTRY CO LTD
# 61                  CENTURY LINK GENERAL TRADING LLC
# 62                                                NaN
# 63                 BEHOVER INFORMATION TECHNOLOGY LLC
# 64            ADVANCE  BANKING SOLUTIONS TRADING DMCC
# 65            ABU DHABI FERTILIZER INDUSTRIES CO WLL
#
#                              country
# 0                       Dubai- U.A.E
# 1                       Dubai- U.A.E
# 2                       Dubai- U.A.E
# 3                 Colombo- Sri Lanka
# 4                       Dubai- U.A.E
# 5                     Gujarat- India
# 6                       Dubai- U.A.E
# 7                       Dubai- U.A.E
# 8                       Dubai- U.A.E
# 9                       Dubai- U.A.E
# 10                      Dubai- U.A.E
# 11                      Dubai- U.A.E
# 12                     Goch- Germany
# 13                     Goch- Germany
# 14                      Dubai- U.A.E
# 15                      Dubai- U.A.E
# 16                    Gorizia- Italy
# 17                      Dubai- U.A.E
# 18               Panadura- Sri Lanka
# 19                  Hong Kong- China
# 20               Weingarten- Germany
# 21                      Dubai- U.A.E
# 22                      Pavia- Italy
# 23                      Dubai- U.A.E
# 24                      Dubai- U.A.E
# 25                      Dubai- U.A.E
# 26                Seoul- South Korea
# 27                Seoul- South Korea
# 28                      Dubai- U.A.E
# 29                      Dubai- U.A.E
# ..                               ...
# 36                      Dubai- U.A.E
# 37                   Berlin- Germany
# 38                      Dubai- U.A.E
# 39                      Dubai- U.A.E
# 40                      Dubai- U.A.E
# 41                      Dubai- U.A.E
# 42                      Dubai- U.A.E
# 43                      Dubai- U.A.E
# 44                      Dubai- U.A.E
# 45                     Verona- Italy
# 46                    Bönen- Germany
# 47                      Dubai- U.A.E
# 48                      Dubai- U.A.E
# 49                      Dubai- U.A.E
# 50                      Dubai- U.A.E
# 51                      Dubai- U.A.E
# 52                      Dubai- U.A.E
# 53                      Dubai- U.A.E
# 54                      Dubai- U.A.E
# 55          Gyeonggi-do- South Korea
# 56                   Lingen- Germany
# 57                      Dubai- U.A.E
# 58                      Dubai- U.A.E
# 59                      Dubai- U.A.E
# 60                    Taipei- Taiwan
# 61                      Dubai- U.A.E
# 62                               NaN
# 63                      Dubai- U.A.E
# 64                      Dubai- U.A.E
# 65  Abu Dhabi - United Arab Emirates
#
# [66 rows x 13 columns]

# %%
def getBoldataframe(TradingCode, datalist):
    codeVector = []
    for procode in datalist['tradingTypeCode']:
        if procode ==TradingCode:
            codeVector.append(True)
        else:
            codeVector.append(False)

    return datalist[codeVector]

# %%
# Distangolishing rep.Exporter and exporter in tacking sheet.
repOrMainCo = [True if (('UAE' in str(x))or('uae' in str(x))or('U.A.E' in str(x))or('u.a.e' in str(x))) else False for x in track['country']]# All type of uae

def randomExporter(i, datalist):
    tradedataframe = getBoldataframe(i,datalist)
    r, _ = tradedataframe.shape
    count = np.floor(np.random.rand()*r)
    return str(datalist.loc[count,'companies']),str(datalist.loc[count,'country'])
repExporter = []
cityOfRepExporter = []
exporter = []
cityOfExporter = []
for i in range(len(repOrMainCo)):
    if repOrMainCo[i]:
        repExporter.append(str(track.loc[i, 'exporter/repExporter']).upper())
        cityOfRepExporter.append(str(track.loc[i, 'country']).title())
    else:
        repExporter.append('')
        cityOfRepExporter.append('')

    if not (repOrMainCo[i]):
        exporter.append(str(track.loc[i, 'exporter/repExporter']).upper())
        cityOfExporter.append(str(track.loc[i, 'country']).title())
    else:
        exp , cityExp = randomExporter(track.loc[i,'TYPE OFProducts'],Colist)
        exporter.append(exp)
        cityOfExporter.append(cityExp.title())

# %%
ones = {
    0: '', 1: 'One', 2: 'Two', 3: 'Three', 4: 'Four', 5: 'Five', 6: 'Six',
    7: 'Seven', 8: 'Eight', 9: 'Nine', 10: 'Ten', 11: 'Eleven', 12: 'Twelve',
    13: 'Thirteen', 14: 'Fourteen', 15: 'Fifteen', 16: 'Sixteen',
    17: 'Seventeen', 18: 'Eighteen', 19: 'Nineteen'}
tens = {
    2: 'Twenty', 3: 'Thirty', 4: 'Forty', 5: 'Fifty', 6: 'Sixty',
    7: 'Seventy', 8: 'Eighty', 9: 'Ninety'}
illions = {
    1: 'Thousand', 2: 'Million', 3: 'Billion', 4: 'Trillion', 5: 'Quadrillion',
    6: 'Quintillion', 7: 'Sextillion', 8: 'Septillion', 9: 'Octillion',
    10: 'Nonillion', 11: 'Decillion'}

def say_number(i):
    """
    Convert an integer in to it's word representation.

    say_number(i: integer) -> string
    """
    if i < 0:
        return _join('Negative', _say_number_pos(-i))
    if i == 0:
        return 'Zero'
    return _say_number_pos(i)


def _say_number_pos(i):
    if i == 0:
        return ''
    if i < 1:
        print(str(int(i*100)) + '/100')
        return str(int(i*100)) + '/100'
    if i < 20:
        return _join(ones[int(i)],_say_number_pos(i % 1))
    if i < 100:
        return _join(_join(tens[i // 10], ones[int(i) % 10]),_say_number_pos(i % 1))
    if i < 1000:
        return _divide(i, 100, 'Hundred')
    for illions_number, illions_name in illions.items():
        if i < 1000**(illions_number + 1):
            break
    return _divide(i, 1000**illions_number, illions_name)


def _divide(dividend, divisor, magnitude):
    return _join(
        _say_number_pos(dividend // divisor),
        magnitude,
        _say_number_pos(dividend % divisor),
    )


def _join(*args):
    return ' '.join(filter(bool, args))

# %%
amountToWord = []
c = 0
for number in track['amount']:
    if str(track.loc[c,'currency']).lower() == 'euro':
        amountToWord.append(say_number(number) + ' Euros Only')
    elif str(track.loc[c,'currency']).lower() == 'aed':
        amountToWord.append(say_number(number) + ' Dirhams Only')
    elif str(track.loc[c,'currency']).lower() == 'pound':
        amountToWord.append(say_number(number) + ' Pound sterlings Only')
    elif str(track.loc[c,'currency']).lower() == 'cad':
        amountToWord.append(say_number(number) + ' canadian Dollars Only')
    elif str(track.loc[c,'currency']).lower() == 'usd':
        amountToWord.append(say_number(number) + ' U.S.Dollars Only')
    c +=1

# %%
#,DIS1,QTY1,UNIT1,UNITPRICE1,TOTAL1,DIS2,QTY2,UNIT2,UNITPRICE2,TOTAL2
# businessType, REF, Date,IMPORTER,CTOFIM,REPPOFIM,CTOFREPOFIM,REPOFEXPORTER,CTOFREPOFEXPORTER,EXPORTER,CTOFEX,TOTALAMOUNT,Currency,INWORDS,ORIGIN,LO,DIS, amountInWord

importer = track['SOURCE COMPANY']
repImporter = track['COMPANY NAME']
cityOfImporter = track['SourceCo.City']
cityOfrepImporter = track['CO.City']

# %%
def lcs(X , Y): 
    # find the length of the strings 
    m = len(X) 
    n = len(Y) 
  
    # declaring the array for storing the dp values 
    L = [[None]*(n+1) for i in range(m+1)] 
  
    """Following steps build L[m+1][n+1] in bottom up fashion 
    Note: L[i][j] contains length of LCS of X[0..i-1] 
    and Y[0..j-1]"""
    for i in range(m+1): 
        for j in range(n+1): 
            if i == 0 or j == 0 : 
                L[i][j] = 0
            elif X[i-1] == Y[j-1]: 
                L[i][j] = L[i-1][j-1]+1
            else: 
                L[i][j] = max(L[i-1][j] , L[i][j-1]) 
  
    # L[m][n] contains the length of LCS of X[0..n-1] & Y[0..m-1] 
    return L[m][n] 
#end of function lcs

# %%
def getClientRef(c, clientlist):
    num = str(clientlist.loc[c,'SR. NO.']) + '.'
    for char in clientlist.loc[c,'LIST OF COMPANY']:
        if char != '.':
            num = num + char
        else:
            break
    return num
    
def bestmatch(candid,clientlist):
    # Remove all bad charachters.
    candid = ''.join(e for e in candid if e.isalnum())
    c = 0
    maxAl = 0
    candidRow = []
    num = ''
    maxLCStoClient = 0
    for client in clientlist['LIST OF COMPANY']:
    #     print(client)
        candidLcs = lcs(candid.lower(), client.lower())
        LCStoClient = candidLcs / len(client)
#         print(candidLcs)
#         print(len(candid),candidLcs)
#         if candidLcs > maxAl:
#             match = c
#             maxAl = candidLcs
#             maxLCStoClient = LCStoClient
#         elif (candidLcs == maxAl) and (maxLCStoClient < LCStoClient):
#             match = c
#             maxAl = candidLcs
#             maxLCStoClient = LCStoClient                
                
#         print(len(candid),candidLcs)
        if (candidLcs == len(candid)):
#             print(len(client.lower()))
#             print(len(candid),candidLcs)
            if (candidLcs / len(client.lower()) >= 0.5):
                if (maxLCStoClient < LCStoClient):
                    candidRow = list(clientlist.iloc[c])
                    num = getClientRef(c, clientlist)
                    maxLCStoClient = LCStoClient
#                 print(maxLCStoClient)
#                 print(num, candidRow)
        c+=1


    return num, candidRow
bestmatch('AL FEEL TRADING LLC',clientlist)
# Out:
# ('', [])

# %%
for i in range(len(exporter)):
    if (str(exporter[i]) == '') or (str(exporter[i]) == str(np.nan)) or (str(exporter[i]) == 'NAN'):
        exp , cityExp = randomExporter(track.loc[i,'TYPE OFProducts'],Colist)
        exporter[i] =  exp
        cityOfExporter[i] = cityExp
#     print(exporter[i],i)

# %%
numlist = []
veclist = []
c = 0
for client in repExporter:
    num , vec = bestmatch(client,clientlist)
    numlist.append(num)
    veclist.append(vec)
    if num != '':
        cityOfRepExporter[c] = vec[3].title()
#         print(cityOfRepExporter[c])
        exporter[c] = vec[4].upper()
        cityOfExporter[c] = vec[5]
    c += 1

# %%
def QtyClassification(amount, mean):
    estQty = int(amount / mean)
    if (estQty < 30):
        return 1
    elif (estQty >= 30) and (estQty < 80):
        return np.ceil(np.random.randint(1,2,1))
    
    if (estQty >= 80) and (estQty < 150):
        return np.ceil(np.random.randint(2,3,1))
    
    elif (estQty >= 150) and (estQty < 300):
        return np.ceil(np.random.randint(2,4,1))
    
    elif (estQty >= 300) and (estQty < 600):
        return np.ceil(np.random.randint(3,4,1))

    elif (estQty >= 600) and (estQty <1000 ):
        return np.ceil(np.random.randint(4,5,1))

    elif (estQty > 1000 ):
        return 5

# %%
#Choosing products

def getRandomKProduct(amount,iD, datalist):
    tradedataframe = getBoldataframe(iD,datalist)
    codeVector = []
    # removing greater than amount
    for proAmount in tradedataframe['dollar']:
        if amount > proAmount:
            codeVector.append(True)
        else:
            codeVector.append(False)
    tradedataframe = tradedataframe[codeVector]
    #Computing mean value
    codeVector = []
    mean = np.mean(tradedataframe['dollar'])

    for proAmount in tradedataframe['dollar']:
        if (proAmount > mean/80) and proAmount < mean*80:
            codeVector.append(True)
        else:
            codeVector.append(False)
    
    r, _ = tradedataframe.shape

    tradedataframe = tradedataframe[codeVector]
    
    r, _ = tradedataframe.shape

    k = int(QtyClassification(amount , mean))

    produc = []
    if k < r:
        for i in range(k):
            count = np.random.randint(0,r-1,1)

            produc.append(list(tradedataframe.iloc[count[0]]))
            tradedataframe.drop(tradedataframe.index[count[0]], inplace=True)
            r, c = tradedataframe.shape

    else:
        produc =tradedataframe

    RandomKProduct = pd.DataFrame(produc)

    RandomKProduct.columns = ['p_name','unit','dollar','dirham','euro','type','tradingTypeCode']
    return RandomKProduct

# %%
# print(np.random.randint(0,102,1))
getRandomKProduct(139409,26, productlist)
# Out:
#                                               p_name unit  dollar   dirham  \
# 0                      LPR Brake Pad Set  disc brake  PCS   10.95    40.19
# 1                         Compressor-8FK 351 135-811  PCS  286.00  1049.62
# 2   Original VAICO Quality  Tensioner  Cogged V-Belt  PCS   52.00   190.84
# 3                             Wheel cover Celine 15"  PCS   22.00    80.74
# 4  Original VAICO   Pulley  V-Ribbed Belt Guidanc...  PCS   43.00   157.81
#
#      euro       type  tradingTypeCode
# 0    9.53  SPARE CAR               26
# 1  248.82  SPARE CAR               26
# 2   45.24  SPARE CAR               26
# 3   19.14  SPARE CAR               26
# 4   37.41  SPARE CAR               26

# %%
def changeCurrency(i , data):
#     print(str(track.loc[i,'currency']).lower())
    
    if str(track.loc[i,'currency']).lower() == 'euro':

        return float(track.loc[i,'amount'] * 1.13)
    elif str(track.loc[i,'currency']).lower()[:] == 'aed':

        return float(track.loc[i,'amount'] * 0.27)
    elif str(track.loc[i,'currency']).lower() == 'pound':

        return float(track.loc[i,'amount'] * 1.32)
    elif str(track.loc[i,'currency']).lower() == 'cad':

        return float(track.loc[i,'amount'] * 0.75)
    else:

        return

# %%
def returnCurrency( unitp, i, trak):
    if str(track.loc[i,'currency']).lower() == 'euro':
        return float(unitp) / 0.89
    elif str(track.loc[i,'currency']).lower() == 'aed':
        return float(unitp) / 3.67
    elif str(track.loc[i,'currency']).lower() == 'pound':
        return float(unitp) / 0.76
    elif str(track.loc[i,'currency']).lower() == 'cad':
        return float(unitp) / 1.34
    else:
        return unitp

# %%
#amount    currency
#1
p1name = []
p1unit = []
p1unitp = []
p1qty = []
p1total = []
#2
p2name = []
p2unit = []
p2unitp = []
p2qty = []
p2total = []
#3
p3name = []
p3unit = []
p3unitp = []
p3qty = []
p3total = []
#4
p4name = []
p4unit = []
p4unitp = []
p4qty = []
p4total = []
#5
p5name = []
p5unit = []
p5unitp = []
p5qty = []
p5total = []
for i in range(len(track['date'])):

    pname = []
    unit = []
    unitp = []
    qty = []
    total = []

    if str(track.loc[i,'currency']).lower() == 'usd':
        amount = float(track.loc[i,'amount'])
    else:
        amount = float(changeCurrency(i,track))

    TradingCode = track.loc[i, 'TYPE OFProducts']
    RandomKProduct = getRandomKProduct(amount, TradingCode, productlist)
    RandomKProduct = RandomKProduct.sort_values(by='dollar', ascending=False)
    
    copyamount = amount = float(track.loc[i,'amount'])

    #allocating rest of amount
    tot = 0
    tempqty = 0
    if (len(RandomKProduct['p_name']) > 1):
        for j in range(len(RandomKProduct['p_name']) - 1):
            bound = int(copyamount / float(RandomKProduct.loc[j,'dollar'] ))
            pname.append(RandomKProduct.loc[j,'p_name'] )
            unit.append(RandomKProduct.loc[j,'unit'])
            unitp.append(returnCurrency(RandomKProduct.loc[j,'dollar'],i ,track))
            tempqty = np.floor(np.random.randint(1,(bound-1),1)[0])
#             print((amount - (unitp[-1] * tempqty))/float(RandomKProduct.loc[j + 1,'dollar']))
#             while((amount - (unitp[-1] * tempqty))/float(RandomKProduct.loc[j + 1,'dollar']) < 1) and (amount - (unitp[-1] * tempqty)) < 0:
#                 tempqty = np.floor(np.random.randint(1,(bound/2),1)[0])
#                 print((amount - (unitp[-1] * tempqty))/float(RandomKProduct.loc[j + 1,'dollar']))
            copyamount = copyamount - (unitp[-1] * tempqty)
            qty.append(tempqty)
            total.append((unitp[-1] * qty[-1]))
            tot += (unitp[-1] * qty[-1])
    k = len(RandomKProduct['p_name']) - 1
    pname.append(RandomKProduct.loc[k,'p_name'] )
    unit.append(RandomKProduct.loc[k,'unit'])
    unitp.append(returnCurrency(RandomKProduct.loc[k,'dollar'],i ,track))

    qty.append(int(copyamount / RandomKProduct.loc[k,'dollar']))
#     print(qty, i)
#     print(RandomKProduct)
#     print(RandomKProduct['dollar'])
#     print(unitp[-1])
    if copyamount % RandomKProduct.loc[k,'dollar'] !=0:
        unitp[-1] = float(copyamount / qty[-1])
    total.append(amount - tot)
#     print(unitp[-1])
    

    #1
    p1name.append(pname[0])
    p1unit.append(unit[0])
    p1unitp.append(unitp[0])
    p1qty.append(qty[0])
    p1total.append(total[0])
    #2
    if len(pname) > 1:
        p2name.append(pname[1])
        p2unit.append(unit[1])
        p2unitp.append(unitp[1])
        p2qty.append(qty[1])
        p2total.append(total[1])
    else:
        p2name.append('')
        p2unit.append('')
        p2unitp.append('')
        p2qty.append('')
        p2total.append('')
        
    #3
    if len(pname) > 2:
        p3name.append(pname[2])
        p3unit.append(unit[2])
        p3unitp.append(unitp[2])
        p3qty.append(qty[2])
        p3total.append(total[2])
    else:
        p3name.append('')
        p3unit.append('')
        p3unitp.append('')
        p3qty.append('')
        p3total.append('')        
    #4
    if len(pname) > 3:
        p4name.append(pname[3])
        p4unit.append(unit[3])
        p4unitp.append(unitp[3])
        p4qty.append(qty[3])
        p4total.append(total[3])
    else:
        p4name.append('')
        p4unit.append('')
        p4unitp.append('')
        p4qty.append('')
        p4total.append('')        
    #5
    if len(pname) > 4:
        p5name.append(pname[4])
        p5unit.append(unit[4])
        p5unitp.append(unitp[4])
        p5qty.append(qty[4])
        p5total.append(total[4])
    else:
        p5name.append('')
        p5unit.append('')
        p5unitp.append('')
        p5qty.append('')
        p5total.append('')

# %%
#Origin
origin = []
bol = False
for word in cityOfExporter:
    word = str(word)
    if word == '':
        origin.append(word)
        continue
    for i in range(len(word)):
        if word[i] == '-':
            origin.append('Origin: ' + str(word[(i+1):len(word)]))
            bol = True
            break
        else:
            bol = False
    if not bol:
        origin.append('Origin: ' + word)

# %%
#Loading
load = []
for city in cityOfExporter:
    load.append('Loading: ' + str(city))

# %%
#dischareg
dischareg = []
for city in cityOfImporter:
    dischareg.append('Discharge: ' + str(city))

# %%
# exporter

# %%
forPO = []
forPO = pd.DataFrame()
forPO['REF'] = track['refrence']

forPO['repExporter'], forPO['cityOfRepExporter'] = repExporter, (cityOfRepExporter)
forPO['exporter'], forPO['cityOfExporter']  = exporter, cityOfExporter

forPO['importer'], forPO['cityOfImporter'] = importer, cityOfImporter
forPO['repImporter'], forPO['cityOfrepImporter'] = repImporter, list(cityOfrepImporter)

forPO['Origin'], forPO['laoding'], forPO['Discharge'] = origin, load, dischareg

forPO['totalAmount'], forPO['amountToWord'] = track['amount'], amountToWord
#1
forPO['p1name'] = p1name
forPO['p1qty'] = p1qty
forPO['p1unit'] = p1unit
forPO['p1unitp'] = p1unitp
forPO['p1total'] = p1total
#2
forPO['p2name'] = p2name
forPO['p2qty'] = p2qty
forPO['p2unit'] = p2unit
forPO['p2unitp'] = p2unitp
forPO['p2total'] =p2total
#3
forPO['p3name'] = p3name
forPO['p3qty'] = p3qty
forPO['p3unit'] = p3unit
forPO['p3unitp'] = p3unitp
forPO['p3total'] = p3total
#4
forPO['p4name'] = p4name
forPO['p4qty'] = p4qty
forPO['p4unit'] = p4unit
forPO['p4unitp'] = p4unitp
forPO['p4total'] = p4total
#5
forPO['p5name'] = p5name
forPO['p5qty'] = p5qty
forPO['p5unit'] = p5unit
forPO['p5unitp'] = p5unitp
forPO['p5total'] = p5total

forPO['numOfClient'] = numlist

forPO['currency'], forPO['date'] = track['currency'], track['date']

forPO.to_csv('Tracking Sheet output.csv', index = False)
