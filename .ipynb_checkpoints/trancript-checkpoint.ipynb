# %%
import pandas as pd
import numpy as np

TradingCode = 1
importername = 'Tianjin Kaigui Machinery Co.LTD'
repImportername = 'BEYLERBEYI GENERAL TRADING LLC'
cityOfImportername = 'Tianjin- China'
cityOfrepImportername = 'Dubi-UAE'

# %%
miss_value = ['']
clientlist = pd.read_csv('2018 ABACUS CLIENTS.csv')

# %%
# clientlist = clientlist.dropna()
clientlist
# Out:
#      SR. NO.       CLIENT NAME  \
# 0          1     YAKAMOZ GROUP
# 1          1     YAKAMOZ GROUP
# 2          1     YAKAMOZ GROUP
# 3          1     YAKAMOZ GROUP
# 4          1     YAKAMOZ GROUP
# 5          1     YAKAMOZ GROUP
# 6          1     YAKAMOZ GROUP
# 7          1     YAKAMOZ GROUP
# 8          2  BEYLERBEYI GROUP
# 9          2  BEYLERBEYI GROUP
# 10         2  BEYLERBEYI GROUP
# 11         2  BEYLERBEYI GROUP
# 12         2  BEYLERBEYI GROUP
# 13         2  BEYLERBEYI GROUP
# 14         2  BEYLERBEYI GROUP
# 15         3     MARCELO GROUP
# 16         3     MARCELO GROUP
# 17         3     MARCELO GROUP
# 18         3     MARCELO GROUP
# 19         3     MARCELO GROUP
# 20         3     MARCELO GROUP
# 21         4             GAZAL
# 22         5         TEKNONEFT
# 23         5         TEKNONEFT
# 24         5         TEKNONEFT
# 25         5         TEKNONEFT
# 26         6            NOSHAN
# 27         6            NOSHAN
# 28         6            NOSHAN
# 29         6            NOSHAN
# ..       ...               ...
# 142       32          KALABANI
# 143       32          KALABANI
# 144       33            ETAKAR
# 145       34         MONTAZERI
# 146       34         MONTAZERI
# 147       35    KHAT ALETEBAR
# 148       36    KHAT ALETEBAR
# 149       36           VENTURE
# 150       37          BOX TECH
# 151       38            ATAKAN
# 152       38            ATAKAN
# 153       38            ATAKAN
# 154       38            ATAKAN
# 155       38            ATAKAN
# 156       38            ATAKAN
# 157       39      PERFECT MOON
# 158       39      PERFECT MOON
# 159       39      PERFECT MOON
# 160       40      JAFAR SIHAWI
# 161       41            APAREX
# 162       42             QLIQ
# 163       42             QLIQ
# 164       42             QLIQ
# 165       43        JAZIRA DAS
# 166       44           CAPITAL
# 167       44           CAPITAL
# 168       44           CAPITAL
# 169       45           AL NOOR
# 170       45           AL NOOR
# 171       45           AL NOOR
#
#                                        LIST OF COMPANY  \
# 0            1. BORNOVA BUILDING MATERIALS TRADING LLC
# 1                       2. YAKAMOZ GENERAL TRADING LLC
# 2           3. STIRLING BRIDGE CHEMICALS TRADING L.L.C
# 3                         4. TRUVA GENERAL TRADING LLC
# 4                      5. SERAY FURNITURES TRADING LLC
# 5                                     6. NORTH SEA FZE
# 6                                    7. MATTERHORN FZE
# 7                                   8. MNR TRADING FZE
# 8                  1. BEYLERBEYI GENERAL TRADING L.L.C
# 9    2. KANNUR INDUSTRIAL PLANT EQUIPMENT & SPARE P...
# 10                       3. ELYSEE GENERAL TRADING LLC
# 11   4. D E V INDUSTRIAL PLANT EQUIPMENT & SPARE PA...
# 12       5. YEDI TEPE BUILDING MATERIALS TRADING L.L.C
# 24                                JIANGSU- CHINA
# 25                          TASHKENT- UZBEKISTAN
# 26                                           NaN
# 27                              FUKUSHIMA- JAPAN
# 28                        KUALA LUMPUR- MALAYSIA
# 29                                           NaN
# ..                                           ...
# 142                               HongKong-China
# 143                                 DOHA - QATAR
# 144                                          NaN
# 145                                          NaN
# 146                                          NaN
# 147                           Maharashtra- India
# 148                              NASSAU- BAHAMAS
# 149                                          NaN
# 150                                          NaN
# 151                                          NaN
# 152                                          NaN
# 153                                          NaN
# 154                                          NaN
# 155                                          NaN
# 156                                          NaN
# 157                                          NaN
# 158                                 Milan- Italy
# 159                                          NaN
# 160                                          NaN
# 161                               SUIZHOU- CHINA
# 162                                          NaN
# 163                                          NaN
# 164                     ESPANA- Barcelona- Spain
# 165                                          NaN
# 166                             ISTANBUL- TURKEY
# 167                             ISTANBUL- TURKEY
# 168                             ISTANBUL- TURKEY
# 169                              Ontario- Canada
# 170                              Ontario- Canada
# 171                              Ontario- Canada
#
# [172 rows x 6 columns]

# %%
# import csv
# productname = []
# unit = []
# doller = []
# derham = []
# euro = []
# tradetype = []
# code =[]
# with open('product.csv') as csvfile:
#     readCSV = csv.reader(csvfile, delimiter=',')
#     for row in readCSV:
#         productname.append(row[0])
#         unit.append(row[1])
#         doller.append(row[2])
#         derham.append(row[3])
#         euro.append(row[4])
#         tradetype.append(row[5])
#         code.append(row[6])
# productname =list(productname)
# unit = list(unit)
# doller=list(doller)
# derham = list(derham)
# euro=list(euro)
# code= list(code)     

# productfram = []
# productfram = pd.DataFrame()
# productfram['p_name'] ,productfram['unit'], productfram['dollar'],productfram['dirham']= productname , unit , doller, derham
# productfram['euro'], productfram['type'], productfram['tradingTypeCode'] = euro, tradetype, code

# productfram.to_csv('product.csv',index=False)

# %%
productlist = pd.read_csv('product.csv',na_values =miss_value )

# %%
productlist = productlist.dropna()
productlist
# Out:
#                                                  p_name           unit  \
# 0     0.125-3.0mm Building Material Gi Galvanized St...           TONS
# 1     0.12-6.0mm Dx51d Steel Material Galvanized Ste...           TONS
# 2     0.15*665mm Ral3009 PPGI Corrugated Prepainted ...           TONS
# 3          0.15-0.8mm Cold Rolled Galvanized Steel Coil           TONS
# 4                    100X100mm Carbon Steel Square Tube           TONS
# 5     12mm Building Material Artificial Stone Acryli...            PCS
# 6     12mm Building Material Big Slab Marble Like Ve...            PCS
# 7     150kg/M3 Insulation Board Rockwool with 80% Ba...           TONS
# 8     18mm Thickness Other Plastic Building Material...            PCS
# 9                     201 304 316 Stainless Steel Plate           TONS
# 10    2017آ Buildingآ Materialآ Rapid Rolling High S...            PCS
# 11              25mm White Color Marble Honeycomb Panel  SQUARE METERS
# 12    3003h24 Flat Aluminum Sheet Metalآ Buildingآ C...  SQUARE METERS
# 13                  300mm PVC Decorative Ceiling Panels  SQUARE METERS
# 14                  316 Grade Stainless Steel Round Bar           TONS
# 15                                  4pcf EVA Foam Sheet  SQUARE METERS
# 16        600*600mm Rustic Floor Porcelain Tile(OLG600)             M3
# 5        120.00     440.40     103.20  BUILDING (2)                1
# 6        129.00     473.43     110.94  BUILDING (2)                1
# 7        925.00    3394.75     795.50  BUILDING (2)                1
# 8         20.00      73.40      17.20  BUILDING (2)                1
# 9        650.00    2385.50     559.00  BUILDING (2)                1
# 10      1200.00    4404.00    1032.00  BUILDING (2)                1
# 11        60.00     220.20      51.60  BUILDING (2)                1
# 12        68.00     249.56      58.48  BUILDING (2)                1
# 13         8.00      29.36       6.88  BUILDING (2)                1
# 14      3888.00   14268.96    3343.68  BUILDING (2)                1
# 15       260.00     954.20     223.60  BUILDING (2)                1
# 16         9.00      33.03       7.74  BUILDING (2)                1
# 17        13.22      48.52      11.37  BUILDING (2)                1
# 18        19.44      71.34      16.72  BUILDING (2)                1
# 19       650.00    2385.50     559.00  BUILDING (2)                1
# 20        10.00      36.70       8.60  BUILDING (2)                1
# 21       700.00    2569.00     602.00  BUILDING (2)                1
# 22        50.00     183.50      43.00  BUILDING (2)                1
# 23        15.00      55.05      12.90  BUILDING (2)                1
# 24        10.00      36.70       8.60  BUILDING (2)                1
# 25       350.00    1284.50     301.00  BUILDING (2)                1
# 26        70.00     256.90      60.20  BUILDING (2)                1
# 27      2300.00    8441.00    1978.00  BUILDING (2)                1
# 28       100.00     367.00      86.00  BUILDING (2)                1
# 29       100.00     367.00      86.00  BUILDING (2)                1
# ...         ...        ...        ...           ...              ...
# 2897       1.65       6.06       1.42       Leather               60
# 2898       5.50      20.19       4.73       Leather               60
# 2899       2.90      10.64       2.49       Leather               60
# 2900       6.27      23.01       5.39       Leather               60
# 2901       5.00      18.35       4.30       Leather               60
# 2902       2.55       9.36       2.19       Leather               60
# 2903       2.80      10.28       2.41       Leather               60
# 2904       7.00      25.69       6.02       Leather               60
# 2905       2.44       8.95       2.10       Leather               60
# 2906       5.90      21.65       5.07       Leather               60
# 2907       4.00      14.68       3.44       Leather               60
# 2908       6.85      25.14       5.89       Leather               60
# 2909       2.50       9.18       2.15       Leather               60
# 2910       3.80      13.95       3.27       Leather               60
# 2911       2.25       8.26       1.94       Leather               60
# 2912       4.75      17.43       4.09       Leather               60
# 2913       2.90      10.64       2.49       Leather               60
# 2914       6.27      23.01       5.39       Leather               60
# 2915      16.00      58.72      13.76       Leather               60
# 2916       4.87      17.87       4.19       Leather               60
# 2917    5000.00   18350.00    4300.00       Leather               60
# 2918    6600.00   24222.00    5676.00       Leather               60
# 2919   31800.00  116706.00   27348.00       Leather               60
# 2920  120000.00  440400.00  103200.00       Leather               60
# 2921    3500.00   12845.00    3010.00       Leather               60
# 2922    5090.00   18680.30    4377.40       Leather               60
# 2923    5200.00   19084.00    4472.00       Leather               60
# 2924    8000.00   29360.00    6880.00       Leather               60
# 2925    2500.00    9175.00    2150.00       Leather               60
# 2926    5000.00   18350.00    4300.00       Leather               60
#
# [2927 rows x 7 columns]

# %%
Colist = pd.read_excel('List of Companies.xlsx')

# %%
Colist = Colist.dropna()
Colist
# Out:
#                                              companies  \
# 0                       Refarmed Chemicals Switzerland
# 211                  Shanghai- China      WOOD          Origin : China
# 212                   Jiangsu- China      WOOD          Origin : China
# 213                Kortrijk- Belgium      WOOD        Origin : Belgium
# 214          North Vancouver- Canada      WOOD         Origin : Canada
#
#                                        loading  \
# 0                Loading : Lugano- Switzerland
# 1                     Loading : Gujarat- India
# 2                   Loading : Hong Kong- China
# 3                    Loading : Marcallo- Italy
# 4              Loading : Via Del Lavoro- Italy
# 5                    Loading : Sofia- Bulgaria
# 6                  Loading : Posidonos- Greece
# 7                     Loading : Beijing- China
# 8                          Loading : Ohio- USA
# 9                  Loading : Balıkesir- Turkey
# 10                    Loading : Worms- Germany
# 11                     Loading : Mumbai- India
# 12                      Loading : Hebei- China
# 13                   Loading : Marbella- Spain
# 14                     Loading : Howrah- India
# 15                   Loading : Zhejiang- China
# 16                 Loading : Budapest- Hungary
# 17            Loading : Domat/Ems- Switzerland
# 18                    Loading : Essen- Germany
# 19         Loading : Henstedt-Ulzburg- Germany
# 20                  Loading : Fougères- France
# 21                  Loading : New Delhi- India
# 22                  Loading : Guangzhou- China
# 23                  Loading : New Delhi- India
# 24           Loading : Kongens Lyngby- Denmark
# 25                      Loading : Henan- China
# 26                      Loading : Tokyo- Japan
# 27                   Loading : Shandong- China
# 28                    Loading : Guangxi- China
# 29                     Loading : Fujian- China
# ..                                         ...
# 185              Loading : Losenstein- Austria
# 186                 Loading : Hamburg- Germany
# 187                   Loading : Taipei- Taiwan
# 188                   Loading : Taipei- Taiwan
# 189                Loading : Kaohsiung- Taiwan
# 190                   Loading : Zhejiang China
# 191              Loading : Kapfenberg- Austria
# 192                   Loading : Oelde- Germany
# 193                     Loading : Henan- China
# 194               Loading : Stuttgart- Germany
# 195                   Loading : Jiaozuo- China
# 196  Loading : Dannstadt-Schauernheim- Germany
# 197                 Loading : Lindlar- Germany
# 198                 Loading : New Delhi- India
# 199                   Loading : Tianjin- China
# 200                   Loading : Tianjin- China
# 201         Loading : Lemgoer Strasse- Germany
# 202                  Loading : Shanghai- China
# 203                Loading : Bern- Switzerland
# 204                 Loading : Guangdong- China
# 205                 Loading : Hong Kong- China
# 206              Loading : Chhattisgarh- India
# 207                     Loading : Muscat- Oman
# 208                  Loading : Hangzhou- China
# 209                 Loading : Selbitz- Germany
# 210                  Loading : Rekkem- Belgium
# 211                  Loading : Shanghai- China
# 212                   Loading : Jiangsu- China
# 213                Loading : Kortrijk- Belgium
# 214          Loading : North Vancouver- Canada
#
#                                        discharge  tradingTypeCode
# 0                Discharge : Lugano- Switzerland               45
# 1                     Discharge : Gujarat- India               45
# 2                   Discharge : Hong Kong- China               45
# 3                    Discharge : Marcallo- Italy               45
# 4              Discharge : Via Del Lavoro- Italy               45
# 5                    Discharge : Sofia- Bulgaria               45
# 6                  Discharge : Posidonos- Greece               45
# 7                     Discharge : Beijing- China               45
# 8                          Discharge : Ohio- USA               45
# 9                  Discharge : Balıkesir- Turkey               45
# 10                    Discharge : Worms- Germany               45
# 11                     Discharge : Mumbai- India               45
# 12                      Discharge : Hebei- China               45
# 136            ZHANGJIAGANG HUAMING MACHINERY CO LTD              CHINA
# 137                ZHEJIANG THREE CHILDREN FOOD CO LTD            CHINA
# 138                ZHEJIANG THREE CHILDREN FOOD CO LTD            CHINA
# 139            ZHONGSHAN YUANAN IMPORT AND EXPORT CO.-            CHINA
#
# [140 rows x 6 columns]

# %%
def getBoldataframe(TradingCode, datalist):
    codeVector = []
    for procode in datalist['tradingTypeCode']:
        if procode ==TradingCode:
            codeVector.append(True)
        else:
            codeVector.append(False)

    return datalist[codeVector]

# %%
# Distangolishing rep.Exporte and exporte in tacking sheet.
repOrMainCo = [True if (('UAE' in str(x))or('uae' in str(x))or('U.A.E' in str(x))or('u.a.e' in str(x))) else False for x in track['country']]# All type of uae

def randomExporter(i, datalist):
    tradedataframe = getBoldataframe(i,datalist)
    r, _ = tradedataframe.shape
    count = np.floor(np.random.rand()*r)
    return str(datalist.loc[count,'companies']),str(datalist.loc[count,'country'])
repExporter = []
cityOfRepExporter = []
exporter = []
cityOfExporter = []
for i in range(len(repOrMainCo)):
    if repOrMainCo[i]:
        repExporter.append(str(track.loc[i, 'exporter/repExporter']))
        cityOfRepExporter.append(str(track.loc[i, 'country']))
    else:
        repExporter.append('')
        cityOfRepExporter.append('')
#     print(repExporter[i] , str(track.loc[i, 'exporter/repExporter']))
    if not (repOrMainCo[i]):
        exporter.append(str(track.loc[i, 'exporter/repExporter']))
        cityOfExporter.append(str(track.loc[i, 'country']))
    else:
        exp , cityExp = randomExporter(i,Colist)
        exporter.append(exp)
        cityOfExporter.append(cityExp)

# %%
ones = {
    0: '', 1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: 'five', 6: 'six',
    7: 'seven', 8: 'eight', 9: 'nine', 10: 'ten', 11: 'eleven', 12: 'twelve',
    13: 'thirteen', 14: 'fourteen', 15: 'fifteen', 16: 'sixteen',
    17: 'seventeen', 18: 'eighteen', 19: 'nineteen'}
tens = {
    2: 'twenty', 3: 'thirty', 4: 'forty', 5: 'fifty', 6: 'sixty',
    7: 'seventy', 8: 'eighty', 9: 'ninety'}
illions = {
    1: 'thousand', 2: 'million', 3: 'billion', 4: 'trillion', 5: 'quadrillion',
    6: 'quintillion', 7: 'sextillion', 8: 'septillion', 9: 'octillion',
    10: 'nonillion', 11: 'decillion'}

def say_number(i):
    """
    Convert an integer in to it's word representation.

    say_number(i: integer) -> string
    """
    if i < 0:
        return _join('negative', _say_number_pos(-i))
    if i == 0:
        return 'zero'
    return _say_number_pos(i)


def _say_number_pos(i):
    if i < 20:
        return ones[i]
    if i < 100:
        return _join(tens[i // 10], ones[i % 10])
    if i < 1000:
        return _divide(i, 100, 'hundred')
    for illions_number, illions_name in illions.items():
        if i < 1000**(illions_number + 1):
            break
    return _divide(i, 1000**illions_number, illions_name)


def _divide(dividend, divisor, magnitude):
    return _join(
        _say_number_pos(dividend // divisor),
        magnitude,
        _say_number_pos(dividend % divisor),
    )


def _join(*args):
    return ' '.join(filter(bool, args))

# %%
amountToWord = []
for number in track['amount']:
    amountToWord.append(say_number(number))

# %%
#,DIS1,QTY1,UNIT1,UNITPRICE1,TOTAL1,DIS2,QTY2,UNIT2,UNITPRICE2,TOTAL2
# businessType, REF, Date,IMPORTER,CTOFIM,REPPOFIM,CTOFREPOFIM,REPOFEXPORTER,CTOFREPOFEXPORTER,EXPORTER,CTOFEX,TOTALAMOUNT,Currency,INWORDS,ORIGIN,LO,DIS, amountInWord

importer = np.full(len(track['refrence']),importername)
repImporter = np.full(len(track['refrence']),repImportername)
cityOfImporter = np.full(len(track['refrence']),cityOfImportername)
cityOfrepImporter = np.full(len(track['refrence']),cityOfrepImportername)

# %%
def lcs(X , Y): 
    # find the length of the strings 
    m = len(X) 
    n = len(Y) 
  
    # declaring the array for storing the dp values 
    L = [[None]*(n+1) for i in range(m+1)] 
  
    """Following steps build L[m+1][n+1] in bottom up fashion 
    Note: L[i][j] contains length of LCS of X[0..i-1] 
    and Y[0..j-1]"""
    for i in range(m+1): 
        for j in range(n+1): 
            if i == 0 or j == 0 : 
                L[i][j] = 0
            elif X[i-1] == Y[j-1]: 
                L[i][j] = L[i-1][j-1]+1
            else: 
                L[i][j] = max(L[i-1][j] , L[i][j-1]) 
  
    # L[m][n] contains the length of LCS of X[0..n-1] & Y[0..m-1] 
    return L[m][n] 
#end of function lcs 
  
# Driver program to test the above function 
X = "AGGTAB"
Y = "GXTXAYB"
print("Length of LCS is ", lcs(X, Y))
# Out:
# Length of LCS is  4

# %%
# def lcs(s1, s2):
#     matrix = [["" for x in range(len(s2))] for x in range(len(s1))]
#     for i in range(len(s1)):
#         for j in range(len(s2)):
#             if s1[i] == s2[j]:
#                 if i == 0 or j == 0:
#                     matrix[i][j] = s1[i]
#                 else:
#                     matrix[i][j] = matrix[i-1][j-1] + s1[i]
#             else:
#                 matrix[i][j] = max(matrix[i-1][j], matrix[i][j-1], key=len)

#     cs = matrix[-1][-1]

#     return len(cs), cs

# print(lcs("abcdaf", "acbcf"))

# %%
# def lcs(X, Y, m, n): 
  
#     if m == 0 or n == 0: 
#        return 0; 
#     elif X[m-1] == Y[n-1]: 
#        return 1 + lcs(X, Y, m-1, n-1); 
#     else: 
#        return max(lcs(X, Y, m, n-1), lcs(X, Y, m-1, n)); 
# X = "AGGTAB"
# Y = "GXTXAYB"
# print("Length of LCS is ", lcs(X , Y, len(X), len(Y)))

# %%
# def longestSubstringFinder(string1, string2):
#     answer = ""
#     len1, len2 = len(string1), len(string2)
#     for i in range(len1):
#         match = ""
#         for j in range(len2):
#             if (i + j < len1 and string1[i + j] == string2[j]):
#                 match += string2[j]
#             else:
#                 if (len(match) > len(answer)): answer = match
#                 match = ""
#     return answer

# print(longestSubstringFinder("apple pie available", "apple pies"))
# print(longestSubstringFinder("apples", "appleses"))
# print(longestSubstringFinder("bapples", "cappleses"))

# %%
def getClientRef(c, clientlist):
    num = str(clientlist.loc[c,'SR. NO.']) + '.'
    for char in clientlist.loc[c,'LIST OF COMPANY']:
        if char != '.':
            num = num + char
        else:
            break
    return num
    
def bestmatch(candid,clientlist):
    candid = ''.join(e for e in candid if e.isalnum())
    c = 0
    maxAl = 0
    candidRow = []
    num = ''
    for client in clientlist['LIST OF COMPANY']:
    #     print(client)
        candidLcs = lcs(candid.lower(), client.lower())
    #     print(LsubSF)
        if candidLcs > maxAl:
            match = c
            maxAl = candidLcs
            print(len(candid),candidLcs)
            if candidLcs >= len(candid):
                candidRow = list(clientlist.iloc[c])
                num = getClientRef(c, clientlist)
        c+=1

    print(num, candidRow)
    return num, candidRow
# bestmatch('STORZ MEDICAL AG',clientlist)

# %%
numlist = []
veclist = []
c = 0
for client in repExporter:
#     print(client)
    num , vec = bestmatch(client,clientlist)
    numlist.append(num)
    veclist.append(vec)
    if num != '':
        cityOfRepExporter[c] = vec[3]
        exporter[c] = vec[4]
        cityOfExporter[c] = vec[5]
    c += 1
# Out:
#  []
#
#  []
#  CIELO OESTE GENERAL TRADING FZE
# 27 14
# 27 15
# 27 18
# 27 19
# 27 21
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#  NOVATEK GENERAL TRADING LLC
# 24 19
# 24 20
# 24 22
#  []
#
#  []
#  PHOENIX TYRES TRADING F.Z.E
# 22 13
# 22 14
# 22 16
#  []
#
#  []
#
#  []
#
#  []
#  SYED NAEEM GENERAL TRADING CO LLC
# 28 17
# 28 20
# 28 21
# 28 23
#  []
#  SYED NAEEM GENERAL TRADING CO LLC
# 28 17
# 28 20
# 28 21
# 28 23
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
# ARMACO GENERAL TRADING LLC
# 23 17
# 23 20
# 23 21
#  []
#
#  []
#
#  []
# BEYZADE GENERAL TRADING
# 21 15
# 21 16
# 21 18
# 21 21
# 2.6 [2, 'BEYLERBEYI GROUP', '6. BEYZADE GENERAL TRADING L.L.C.', 'Dubai- United Arab Emirates', 'SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD.', nan]
# BEYZADE GENERAL TRADING
# 21 15
# 21 16
# 21 18
# 21 21
# 2.6 [2, 'BEYLERBEYI GROUP', '6. BEYZADE GENERAL TRADING L.L.C.', 'Dubai- United Arab Emirates', 'SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD.', nan]
# BEYZADE GENERAL TRADING
# 21 15
# 21 16
# 21 18
# 21 21
# 2.6 [2, 'BEYLERBEYI GROUP', '6. BEYZADE GENERAL TRADING L.L.C.', 'Dubai- United Arab Emirates', 'SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD.', nan]
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
# GALAXY SUN TELECOM LLC
# 19 9
# 19 10
# 19 11
# 19 12
# 19 13
#  []
#
#  []
# GULF LINE INTERNATIONAL TRADING COMPANY LLC
# 38 20
# 38 21
# 38 25
# 38 27
#  []
# HABIB MUHAMMAD SIDDIQUE FOOD AND BEVERAGE LLC
# 39 14
# 39 16
# 39 17
# 39 18
#  []
# HABIB MUHAMMAD SIDDIQUE FOOD AND BEVERAGE LLC
# 39 14
# 39 16
# 39 17
# 39 18
#  []
#
#  []
#
#  []
#
#  []
#
#  []
# KARJI GENERAL TRADING ESTABLISHMENT
# 32 15
# 32 17
# 32 18
# 32 19
# 32 20
#  []
#
#  []
# KMG ROBUST COMMODITY DMCC
# 22 9
# 22 10
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
# MEDIST FZE
# 9 5
# 9 6
# 9 7
# 9 8
#  []
#
#  []
#
#  []
#
#  []
# MOHAMED RUYAN MEDICAL EQUIPMENT TRADING
# 35 16
# 35 23
# 35 27
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
# SIG COMBIBLOC OEBEIKAN FZCO
# 24 9
# 24 11
# 24 13
#  []
# SILVER POOL GENERAL TRADING
# 24 15
# 24 16
# 24 17
# 24 19
# 24 21
#  []
#
#  []
#
#  []
#
#  []
# SURAWUT THIANGLE TRADING LLC
# 25 17
# 25 18
# 25 19
#  []
# SURAWUT THIANGLE TRADING LLC
# 25 17
# 25 18
# 25 19
#  []
# SURAWUT THIANGLE TRADING LLC
# 25 17
# 25 18
# 25 19
#  []
#
#  []
#
#  []
#
#  []
# TAJ AL MULOOK GENERAL TRADING LLC
# 28 18
# 28 21
#  []
#
#  []
#
#  []
#
#  []
#
#  []
# THE WATCH FZ LLC
# 13 7
# 13 8
# 13 9
#  []
#
#  []
# TOP PACIFIC TRADING LLC
# 20 14
# 20 15
# 20 16
#  []
# TOP PACIFIC TRADING LLC
# 20 14
# 20 15
# 20 16
#  []
#
#  []
#
#  []
# TURAN TRADING FZE
# 15 10
# 15 11
# 15 13
# 15 14
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []

# %%
# r,c = track.shape

# po = []
# for i in range(r):   
#     if track.loc[i,'Unnamed: 3'] == 'EURO':
#         track.is_copy = False
#         track.loc[i,'Unnamed: 3'] = 'AED'
#         track.loc[i,'Unnamed: 2'] = str(int(track.loc[i,'Unnamed: 2']) * 4.13)
#         print(track.loc[i,'Unnamed: 2'])

# print(track.loc[1, 'exporter/repExporter'])

# %%
def QtyClassification(amount, mean):
    estQty = int(amount / mean)
    if (estQty < 50):
        return 1
    elif (estQty >= 50) and (estQty < 100):
        return np.ceil(np.random.randint(1,2,1))
    
    if (estQty >= 100) and (estQty < 300):
        return np.ceil(np.random.randint(2,3,1))
    
    elif (estQty >= 300) and (estQty < 600):
        return np.ceil(np.random.randint(2,4,1))
    
    elif (estQty >= 600) and (estQty < 1500):
        return np.ceil(np.random.randint(3,4,1))

    elif (estQty >= 1500) and (estQty <3000 ):
        return np.ceil(np.random.randint(4,5,1))

    elif (estQty > 3000 ):
        return 5

# %%
int(QtyClassification(400000 , 2991.8068396226417))
# Out:
# 2

# %%
#Choosing products

def getRandomKProduct(amount,iD, datalist):
    tradedataframe = getBoldataframe(iD,datalist)
    codeVector = []
    # removing greater than amount
    for proAmount in tradedataframe['dollar']:
        if amount > proAmount:
            codeVector.append(True)
        else:
            codeVector.append(False)
    tradedataframe = tradedataframe[codeVector]
    #Computing mean value
    codeVector = []
    mean = np.mean(tradedataframe['dollar'])
#     print(mean)
    for proAmount in tradedataframe['dollar']:
        if (proAmount > mean/5) and proAmount < mean*5:
            codeVector.append(True)
        else:
            codeVector.append(False)
    
    r, _ = tradedataframe.shape
#     print(r)
    tradedataframe = tradedataframe[codeVector]
    
    r, _ = tradedataframe.shape
#     print(r)
#     print(amount , mean)
    k = int(QtyClassification(amount , mean))
#     print(k)
    produc = []
    if k < r:
        for i in range(k):
            count = np.random.randint(0,r-1,1)
            produc.append(list(tradedataframe.iloc[i]))
            tradedataframe.drop(tradedataframe.index[count], inplace=True)
#             r, c = tradedataframe.shape
#             print(r)
    else:
        produc =tradedataframe
#     print(len(produc), k)
    RandomKProduct = pd.DataFrame(produc)
#     print(RandomKProduct)
    RandomKProduct.columns = ['p_name','unit','dollar','dirham','euro','type','tradingTypeCode']
#     RandomKProduct.rename(inplace=True, header={'0':'p_name','1':'unit','2':'dollar','3':'dirham','4':'euro','5':'type','6':'tradingTypeCode'}, axis='columns')
    return RandomKProduct

# %%
# print(np.random.randint(4,5,1))
getRandomKProduct(400000,TradingCode, productlist)
# Out:
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1

# %%
np.random.randint(1,10,3)
# Out:
# array([6, 6, 4])

# %%
def changeCurrency(i , data):
    if str(track.loc[i,'currency']) == 'Euro':
        return float(track.loc[i,'amount'] * 1.13)
    else:
        return float(track.loc[i,'amount'] * 0.27)

# %%
# Out:
# 5

# %%
#amount    currency
# 
for i in range(len(track['date'])):
#     print(i)
    pname1 = []
    unit1 = []
    unitp1 = []
    qty1 = []
    total1 = []
    
    pname2 = []
    unit2 = []
    unitp2 = []
    qty2 = []
    total2 = []
    
    ratio2 = [0.42, 0.58]
    ratio3 = [0.22, 0.33, 0.45]
    ratio4 = [0.14, 0.21 ,0.28, 0.37]
    ratio5 = [0.1, 0.15, 0.2, 0.25, 0.3]
    
#     pname3 = []
#     unit3 = []
#     unitp3 = []
#     qty3 = []
#     total3 = []
    
#     pname4 = []
#     unit4 = []
#     unitp4 = []
#     qty4 = []
#     total4 = []
    
#     pname5 = []
#     unit5 = []
#     unitp5 = []
#     qty5 = []
#     total5 = []
    
    if str(track.loc[i,'currency']) == 'Dollar':
        amount = float(track.loc[i,'currency'])
    else:
        amount = float(changeCurrency(i,track))
    
    RandomKProduct = getRandomKProduct(amount, TradingCode, productlist)
    RandomKProduct = RandomKProduct.sort_values(by='dollar', ascending=False)
    print(RandomKProduct)
    copyamount =amount
    #allocating rest of amount
    if (len(RandomKProduct['p_name']) !=1):
        for j in range(len(RandomKProduct['p_name']) - 1):
            bound = int(copyamount / RandomKProduct.loc[j,'dollar'] )
            pname1.append(RandomKProduct.loc[j,'p_name'] )
            unit1.append(RandomKProduct.loc[j,'unit'])
            unitp1.append(RandomKProduct.loc[j,'dollar'])
            qty1.append(np.floor(np.random.randint(4,bound,1)))
            copyamount = unitp1[-1] * qty1[-1]
    
        
           
    
    print(unit1,unitp1,qty1,total1)
# Out:
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name unit  dollar  dirham  \
# 0  12mm Building Material Artificial Stone Acryli...  PCS   120.0   440.4
#
#     euro          type  tradingTypeCode
# 0  103.2  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 1  0.12-6.0mm Dx51d Steel Material Galvanized Ste...  TONS   850.0  3119.5
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 1  731.0  BUILDING (2)                1
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 1  0.12-6.0mm Dx51d Steel Material Galvanized Ste...  TONS   850.0  3119.5
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 1  731.0  BUILDING (2)                1
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 1  0.12-6.0mm Dx51d Steel Material Galvanized Ste...  TONS   850.0  3119.5
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 1  731.0  BUILDING (2)                1
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name unit  dollar  dirham  \
# 0  2017آ Buildingآ Materialآ Rapid Rolling High S...  PCS  1200.0  4404.0
#
#      euro          type  tradingTypeCode
# 0  1032.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar    dirham  \
# 1                316 Grade Stainless Steel Round Bar  TONS  3888.0  14268.96
# 0  2017آ Buildingآ Materialآ Rapid Rolling High S...   PCS  1200.0   4404.00
#
#       euro          type  tradingTypeCode
# 1  3343.68  BUILDING (2)                1
# 0  1032.00  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name unit  dollar  dirham  \
# 0  2017آ Buildingآ Materialآ Rapid Rolling High S...  PCS  1200.0  4404.0
#
#      euro          type  tradingTypeCode
# 0  1032.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name unit  dollar  dirham  \
# 0  2017آ Buildingآ Materialآ Rapid Rolling High S...  PCS  1200.0  4404.0
#
#      euro          type  tradingTypeCode
# 0  1032.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name unit  dollar  dirham  \
# 0  2017آ Buildingآ Materialآ Rapid Rolling High S...  PCS  1200.0  4404.0
#
#      euro          type  tradingTypeCode
# 0  1032.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name unit  dollar  dirham  \
# 0  2017آ Buildingآ Materialآ Rapid Rolling High S...  PCS  1200.0  4404.0
#
#      euro          type  tradingTypeCode
# 0  1032.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar    dirham  \
# 1                316 Grade Stainless Steel Round Bar  TONS  3888.0  14268.96
# 0  2017آ Buildingآ Materialآ Rapid Rolling High S...   PCS  1200.0   4404.00
#
#       euro          type  tradingTypeCode
# 1  3343.68  BUILDING (2)                1
# 0  1032.00  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []
#                                               p_name  unit  dollar  dirham  \
# 0  0.125-3.0mm Building Material Gi Galvanized St...  TONS   600.0  2202.0
#
#     euro          type  tradingTypeCode
# 0  516.0  BUILDING (2)                1
# [] [] [] []

# %%
unitp1,qty1,total1
# Out:
# ([847.7417692307691,
#   816.3439259259259,
#   918.3869166666666,
#   1197.8959782608695,
#   3800.221724137931],
#  [130.0, 135.0, 120.0, 92.0, 29.0],
#  [110206.43, 110206.43, 110206.43, 110206.43, 110206.43])

# %%
#Origin
origin = []
bol = False
for word in cityOfExporter:
    word = str(word)
    if word == '':
        origin.append(word)
        continue
    for i in range(len(word)):
        if word[i] == '-':
            origin.append(word[(i+1):len(word)])
            bol = True
            break
        else:
            bol = False
    if not bol:
        origin.append(word)

# %%
print(len(repExporter), len(exporter))
# Out:
# 140 140

# %%
forPO = []
forPO = pd.DataFrame()
forPO['REF'],forPO['date'],forPO['totalAmount'] = track['refrence'], track['date'],track['amount'] 
forPO['amountToWord'],forPO['currency'],forPO['importer'] = amountToWord,track['currency'],importer
forPO['cityOfImporter'],forPO['repImporter'],forPO['cityOfrepImporter'] = cityOfImporter,repImporter,cityOfrepImporter
forPO['exporter'] = exporter
forPO['cityOfExporter'] = cityOfExporter
forPO['repExporter'] = repExporter
forPO['cityOfRepExporter'],forPO['numOfClient'],forPO['laoding'] = cityOfRepExporter, numlist, cityOfExporter
forPO['Discharge'],forPO['Origin'] = cityOfImporter,origin
forPO.to_csv('buf.csv')
