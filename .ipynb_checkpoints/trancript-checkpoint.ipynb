# %%
import pandas as pd
import numpy as np

TradingCode = 1
importername = 'Tianjin Kaigui Machinery Co.LTD'
repImportername = 'BEYLERBEYI GENERAL TRADING LLC'
cityOfImportername = 'Tianjin- China'
cityOfrepImportername = 'Dubi-UAE'

# %%
clientlist = pd.read_csv('2018 ABACUS CLIENTS.csv')

# %%
# clientlist = clientlist.dropna()
clientlist
# Out:
#      SR. NO.       CLIENT NAME  \
# 0          1     YAKAMOZ GROUP
# 1          1     YAKAMOZ GROUP
# 2          1     YAKAMOZ GROUP
# 3          1     YAKAMOZ GROUP
# 4          1     YAKAMOZ GROUP
# 5          1     YAKAMOZ GROUP
# 6          1     YAKAMOZ GROUP
# 7          1     YAKAMOZ GROUP
# 8          2  BEYLERBEYI GROUP
# 9          2  BEYLERBEYI GROUP
# 10         2  BEYLERBEYI GROUP
# 11         2  BEYLERBEYI GROUP
# 12         2  BEYLERBEYI GROUP
# 13         2  BEYLERBEYI GROUP
# 14         2  BEYLERBEYI GROUP
# 15         3     MARCELO GROUP
# 16         3     MARCELO GROUP
# 17         3     MARCELO GROUP
# 18         3     MARCELO GROUP
# 19         3     MARCELO GROUP
# 20         3     MARCELO GROUP
# 21         4             GAZAL
# 22         5         TEKNONEFT
# 23         5         TEKNONEFT
# 24         5         TEKNONEFT
# 25         5         TEKNONEFT
# 26         6            NOSHAN
# 27         6            NOSHAN
# 28         6            NOSHAN
# 29         6            NOSHAN
# ..       ...               ...
# 142       32          KALABANI
# 143       32          KALABANI
# 144       33            ETAKAR
# 145       34         MONTAZERI
# 146       34         MONTAZERI
# 147       35    KHAT ALETEBAR
# 148       36    KHAT ALETEBAR
# 149       36           VENTURE
# 150       37          BOX TECH
# 151       38            ATAKAN
# 152       38            ATAKAN
# 153       38            ATAKAN
# 154       38            ATAKAN
# 155       38            ATAKAN
# 156       38            ATAKAN
# 157       39      PERFECT MOON
# 158       39      PERFECT MOON
# 159       39      PERFECT MOON
# 160       40      JAFAR SIHAWI
# 161       41            APAREX
# 162       42             QLIQ
# 163       42             QLIQ
# 164       42             QLIQ
# 165       43        JAZIRA DAS
# 166       44           CAPITAL
# 167       44           CAPITAL
# 168       44           CAPITAL
# 169       45           AL NOOR
# 170       45           AL NOOR
# 171       45           AL NOOR
#
#                                        LIST OF COMPANY  \
# 0            1. BORNOVA BUILDING MATERIALS TRADING LLC
# 1                       2. YAKAMOZ GENERAL TRADING LLC
# 2           3. STIRLING BRIDGE CHEMICALS TRADING L.L.C
# 3                         4. TRUVA GENERAL TRADING LLC
# 4                      5. SERAY FURNITURES TRADING LLC
# 5                                     6. NORTH SEA FZE
# 6                                    7. MATTERHORN FZE
# 7                                   8. MNR TRADING FZE
# 8                  1. BEYLERBEYI GENERAL TRADING L.L.C
# 9    2. KANNUR INDUSTRIAL PLANT EQUIPMENT & SPARE P...
# 10                       3. ELYSEE GENERAL TRADING LLC
# 11   4. D E V INDUSTRIAL PLANT EQUIPMENT & SPARE PA...
# 12       5. YEDI TEPE BUILDING MATERIALS TRADING L.L.C
# 27                              FUKUSHIMA- JAPAN
# 28                        KUALA LUMPUR- MALAYSIA
# 29                                           NaN
# ..                                           ...
# 142                               HongKong-China
# 143                                 DOHA - QATAR
# 144                                          NaN
# 145                                          NaN
# 146                                          NaN
# 147                           Maharashtra- India
# 148                              NASSAU- BAHAMAS
# 149                                          NaN
# 150                                          NaN
# 151                                          NaN
# 152                                          NaN
# 153                                          NaN
# 154                                          NaN
# 155                                          NaN
# 156                                          NaN
# 157                                          NaN
# 158                                 Milan- Italy
# 159                                          NaN
# 160                                          NaN
# 161                               SUIZHOU- CHINA
# 162                                          NaN
# 163                                          NaN
# 164                     ESPANA- Barcelona- Spain
# 165                                          NaN
# 166                             ISTANBUL- TURKEY
# 167                             ISTANBUL- TURKEY
# 168                             ISTANBUL- TURKEY
# 169                              Ontario- Canada
# 170                              Ontario- Canada
# 171                              Ontario- Canada
#
# [172 rows x 6 columns]

# %%
# import csv
# productname = []
# unit = []
# doller = []
# derham = []
# euro = []
# code =[]
# with open('product.csv') as csvfile:
#     readCSV = csv.reader(csvfile, delimiter=',')
#     for row in readCSV:
#         productname.append(row[0])
#         unit.append(row[1])
#         doller.append(row[2])
#         derham.append(row[3])
#         euro.append(row[4])
#         code.append(row[5])
# productname =list(productname)
# unit = list(unit)
# doller=list(doller)
# derham = list(derham)
# euro=list(euro)
# code= list(code)

# %%
# productfram = []
# productfram = pd.DataFrame()
# productfram['p_name'] ,productfram['unit'], productfram['dollar'],productfram['dirham'], productfram['euro'],productfram['code'] = productname , unit , doller, derham, euro, code
# # productfram['unit'], productfram['doller'] = unit , doller

# %%
# productfram.to_csv('product.csv',index=False)

# %%
productlist = pd.read_csv('product.csv')

# %%
productlist = productlist.dropna()
productlist
# Out:
#                                                  p_name           unit  \
# 0     0.125-3.0mm Building Material Gi Galvanized St...           TONS
# 1     0.12-6.0mm Dx51d Steel Material Galvanized Ste...           TONS
# 2     0.15*665mm Ral3009 PPGI Corrugated Prepainted ...           TONS
# 3          0.15-0.8mm Cold Rolled Galvanized Steel Coil           TONS
# 4                    100X100mm Carbon Steel Square Tube           TONS
# 5     12mm Building Material Artificial Stone Acryli...            PCS
# 6     12mm Building Material Big Slab Marble Like Ve...            PCS
# 7     150kg/M3 Insulation Board Rockwool with 80% Ba...           TONS
# 8     18mm Thickness Other Plastic Building Material...            PCS
# 9                     201 304 316 Stainless Steel Plate           TONS
# 10    2017ط¢آ Buildingط¢آ Materialط¢آ Rapid Rolling ...            PCS
# 11              25mm White Color Marble Honeycomb Panel  SQUARE METERS
# 12    3003h24 Flat Aluminum Sheet Metalط¢آ Buildingط...  SQUARE METERS
# 13                  300mm PVC Decorative Ceiling Panels  SQUARE METERS
# 14                  316 Grade Stainless Steel Round Bar           TONS
# 15                                  4pcf EVA Foam Sheet  SQUARE METERS
# 16        600*600mm Rustic Floor Porcelain Tile(OLG600)             M3
# 17    600X1200mmط¢آ Polished Porcelain Floor Tile & ...  SQUARE METERS
# 18    600X600mm Rough Surface Porcelain Beige Color ...  SQUARE METERS
# 10      1200.00    4404.0000    1032.0000     1
# 11        60.00     220.2000      51.6000     1
# 12        68.00     249.5600      58.4800     1
# 13         8.00      29.3600       6.8800     1
# 14      3888.00   14268.9600    3343.6800     1
# 15       260.00     954.2000     223.6000     1
# 16         9.00      33.0300       7.7400     1
# 17        13.22      48.5174      11.3692     1
# 18        19.44      71.3448      16.7184     1
# 19       650.00    2385.5000     559.0000     1
# 20        10.00      36.7000       8.6000     1
# 21       700.00    2569.0000     602.0000     1
# 22        50.00     183.5000      43.0000     1
# 23        15.00      55.0500      12.9000     1
# 24        10.00      36.7000       8.6000     1
# 25       350.00    1284.5000     301.0000     1
# 26        70.00     256.9000      60.2000     1
# 27      2300.00    8441.0000    1978.0000     1
# 28       100.00     367.0000      86.0000     1
# 29       100.00     367.0000      86.0000     1
# ...         ...          ...          ...   ...
# 2897       1.65       6.0555       1.4190    60
# 2898       5.50      20.1850       4.7300    60
# 2899       2.90      10.6430       2.4940    60
# 2900       6.27      23.0109       5.3922    60
# 2901       5.00      18.3500       4.3000    60
# 2902       2.55       9.3585       2.1930    60
# 2903       2.80      10.2760       2.4080    60
# 2904       7.00      25.6900       6.0200    60
# 2905       2.44       8.9548       2.0984    60
# 2906       5.90      21.6530       5.0740    60
# 2907       4.00      14.6800       3.4400    60
# 2908       6.85      25.1395       5.8910    60
# 2909       2.50       9.1750       2.1500    60
# 2910       3.80      13.9460       3.2680    60
# 2911       2.25       8.2575       1.9350    60
# 2912       4.75      17.4325       4.0850    60
# 2913       2.90      10.6430       2.4940    60
# 2914       6.27      23.0109       5.3922    60
# 2915      16.00      58.7200      13.7600    60
# 2916       4.87      17.8729       4.1882    60
# 2917    5000.00   18350.0000    4300.0000    60
# 2918    6600.00   24222.0000    5676.0000    60
# 2919   31800.00  116706.0000   27348.0000    60
# 2920  120000.00  440400.0000  103200.0000    60
# 2921    3500.00   12845.0000    3010.0000    60
# 2922    5090.00   18680.3000    4377.4000    60
# 2923    5200.00   19084.0000    4472.0000    60
# 2924    8000.00   29360.0000    6880.0000    60
# 2925    2500.00    9175.0000    2150.0000    60
# 2926    5000.00   18350.0000    4300.0000    60
#
# [2927 rows x 6 columns]

# %%
Colist = pd.read_excel('List of Companies.xlsx')

# %%
Colist = Colist.dropna()
Colist
# Out:
#                                              companies  \
# 0    \nMPT DEMİR ÇELİK KİMYA İTHALAT VE İHRACAT SAN...
# 1         (GIT) GLOBAL INFORMATION TECHNOLOGY CO. LTD.
# 2                   AB CAPITAL FURNITURE DESIGNS INTL.
# 3                                          ACC LIMITED
# 4                       ACT SINO INTERNATIONAL LIMITED
# 5                                 ADII SYNERGY SDN BHD
# 6                                         AEPODIA S.A.
# 7                                        AERO VIM GMBH
# 8                                     AGULEJOS GIMENEZ
# 9                                 AKIJ JUTE MILLS LTD.
# 10                            AL JABOR TRADING COMPANY
# 11                                      ALATAS GERMANY
# 12                                     ALISEIA S.R.L
# 13                                  All Makes Co Omaha
# 14                   ALTEK DÖKÜM VE HADDE MAMULLERİ SA
# 15                                      AMBUJA CEMENTS
# 14            Istanbul- Turkey                HEAVY         Origin : Turkey
# 15               Mumbai- India    BUILDING MATERIAL          Origin : India
# 16                Anhui- China           ELECTRONIC          Origin : China
# 17                 Anhui-China                  ART          Origin : China
# 18             Zhejiang- China            FURNITURE          Origin : China
# 19             Shenzhen- China           ELECTRONIC          Origin : China
# 20             Habikino- Japan                HEAVY          Origin : Japan
# 21            Grenoble- France           AUTOMATIVE         Origin : France
# 22             Marcallo- Italy             CHEMICAL          Origin : Italy
# 23   Sacramento- United States            FURNITURE  Origin : United States
# 24                Parre- Italy          SPARE PARTS          Origin : Italy
# 25                Delhi- India           ELECTRONIC          Origin : India
# 26                 Osaka-Japan                 FOOD          Origin : Japan
# 27             Nicosia- Cyprus                HEAVY         Origin : Cyprus
# 28              Chennai- India                HEAVY          Origin : India
# 29         Copenhagen- Denmark              MEDICAL        Origin : Denmark
# ..                         ...                  ...                     ...
# 489        Losenstein- Austria               *SPARE               Origin :
# 491       Singapore- Singapore              * HEAVY               Origin :
# 492             Zhejiang China              * SPARE          Origin : China
# 493            Zhejiang- China                    *          Origin : China
# 498    Perchtoldsdorf- Austria            * MEDICAL               Origin :
# 499              Kerala- India  * BUILDING MATERIAL          Origin : India
# 500   Beckum-Neubeckum Germany                    *        Origin : Germany
# 502         Seoul- South Korea         * ELECTRONIC    Origin : South Korea
# 503     Amsterdam- Netherlands                    *               Origin :
# 505       Singapore- Singapore          * FURNITURE               Origin :
# 508             Jiangsu- China                    *          Origin : China
# 512            Shanghai- China                    *          Origin : China
# 517          Hong Kong - China         * ELECTRONIC          Origin : China
# 519            Shanghai- China         * ELECTRONIC          Origin : China
# 525            Zhejiang- China                    *          Origin : China
# 526            Shanghai- China                    *          Origin : China
# 533            Sassuolo- Italy                    *          Origin : Italy
# 536             Traun- Austria                    *               Origin :
# 537         Andrimont- Belgium                    *               Origin :
# 539             Jodhpur- India                    *          Origin : India
# 540          Ratingen- Germany                    *        Origin : Germany
# 541            Hongkong- China                    *          Origin : China
# 542     Vittorio Veneto- Italy                    *          Origin : Italy
# 543            Shanghai- China                    *          Origin : China
# 545           Hamburg- Germany                    *        Origin : Germany
# 546        Tainan City- Taiwan                    *               Origin :
# 547              Vallès- Spain       * CONSTRUCTION               Origin :
# 552        Manchester- England       * CONSTRUCTION               Origin :
# 553              Mumbai- India                    *          Origin : India
# 554            Shanghai- China          *ELECTRONIC          Origin : China
#
#                                  loading  \
# 0             Loading : Istanbul- Turkey
# 1           Loading : Seoul- South Korea
# 2       Loading : Cebu City- Philippines
# 3                Loading : Mumbai- India
# 4             Loading : Hong Kong- China
# 5       Loading : Kuala Lumpur- Malaysia
# 6    Loading : Louvain-La-Neuve- Belgium
# 7          Loading : Nieder-Olm- Germany
# 8                Loading : Murcia- Spain
# 9            Loading : Dhaka- Bangladesh
# 10                 Loading : Doha- Qatar
# 11             Loading : Bremen- Germany
# 12               Loading : Milano- Italy
# 13               Loading : Nebraska- USA
# 14            Loading : Istanbul- Turkey
# 15               Loading : Mumbai- India
# 16                Loading : Anhui- China
# 17                 Loading : Anhui-China
# 18             Loading : Zhejiang- China
# 19             Loading : Shenzhen- China
# 20             Loading : Habikino- Japan
# 21            Loading : Grenoble- France
# 22             Loading : Marcallo- Italy
# 23   Loading : Sacramento- United States
# 24                Loading : Parre- Italy
# 25                Loading : Delhi- India
# 26                 Loading : Osaka-Japan
# 27             Loading : Nicosia- Cyprus
# 28              Loading : Chennai- India
# 29         Loading : Copenhagen- Denmark
# ..                                   ...
# 489        Loading : Losenstein- Austria
# 491       Loading : Singapore- Singapore
# 492             Loading : Zhejiang China
# 493            Loading : Zhejiang- China
# 498    Loading : Perchtoldsdorf- Austria
# 499              Loading : Kerala- India
# 500   Loading : Beckum-Neubeckum Germany
# 502         Loading : Seoul- South Korea
# 503     Loading : Amsterdam- Netherlands
# 505       Loading : Singapore- Singapore
# 508             Loading : Jiangsu- China
# 512            Loading : Shanghai- China
# 517          Loading : Hong Kong - China
# 519            Loading : Shanghai- China
# 525            Loading : Zhejiang- China
# 526            Loading : Shanghai- China
# 533            Loading : Sassuolo- Italy
# 536             Loading : Traun- Austria
# 537         Loading : Andrimont- Belgium
# 539             Loading : Jodhpur- India
# 540          Loading : Ratingen- Germany
# 541            Loading : Hongkong- China
# 542     Loading : Vittorio Veneto- Italy
# 543            Loading : Shanghai- China
# 545           Loading : Hamburg- Germany
# 546        Loading : Tainan City- Taiwan
# 547              Loading : Vallès- Spain
# 552        Loading : Manchester- England
# 553              Loading : Mumbai- India
# 554            Loading : Shanghai- China
#
#                                  discharge
# 0             Discharge : Istanbul- Turkey
# 1           Discharge : Seoul- South Korea
# 2       Discharge : Cebu City- Philippines
# 3                Discharge : Mumbai- India
# 4             Discharge : Hong Kong- China
# 5       Discharge : Kuala Lumpur- Malaysia
# 6    Discharge : Louvain-La-Neuve- Belgium
# 7          Discharge : Nieder-Olm- Germany
# 8                Discharge : Murcia- Spain
# 9            Discharge : Dhaka- Bangladesh
# 10                 Discharge : Doha- Qatar
# 11             Discharge : Bremen- Germany
# 12               Discharge : Milano- Italy
# 13               Discharge : Nebraska- USA
# 14            Discharge : Istanbul- Turkey
# 15               Discharge : Mumbai- India
# 16                Discharge : Anhui- China
# 17                 Discharge : Anhui-China
# 18             Discharge : Zhejiang- China
# 19             Discharge : Shenzhen- China
# 20             Discharge : Habikino- Japan
# 21            Discharge : Grenoble- France
# 22             Discharge : Marcallo- Italy
# 23   Discharge : Sacramento- United States
# 24                Discharge : Parre- Italy
# 25                Discharge : Delhi- India
# 26                 Discharge : Osaka-Japan
# 27             Discharge : Nicosia- Cyprus
# 28              Discharge : Chennai- India
# 29         Discharge : Copenhagen- Denmark
# ..                                     ...
# 489        Discharge : Losenstein- Austria
# 491       Discharge : Singapore- Singapore
# 492             Discharge : Zhejiang China
# 493            Discharge : Zhejiang- China
# 498    Discharge : Perchtoldsdorf- Austria
# 499              Discharge : Kerala- India
# 500   Discharge : Beckum-Neubeckum Germany
# 502         Discharge : Seoul- South Korea
# 503     Discharge : Amsterdam- Netherlands
# 505       Discharge : Singapore- Singapore
# 508             Discharge : Jiangsu- China
# 512            Discharge : Shanghai- China
# 517          Discharge : Hong Kong - China
# 519            Discharge : Shanghai- China
# 525            Discharge : Zhejiang- China
# 526            Discharge : Shanghai- China
# 533            Discharge : Sassuolo- Italy
# 536             Discharge : Traun- Austria
# 537         Discharge : Andrimont- Belgium
# 539             Discharge : Jodhpur- India
# 540          Discharge : Ratingen- Germany
# 541            Discharge : Hongkong- China
# 542     Discharge : Vittorio Veneto- Italy
# 543            Discharge : Shanghai- China
# 545           Discharge : Hamburg- Germany
# 546        Discharge : Tainan City- Taiwan
# 547              Discharge : Vallès- Spain
# 552        Discharge : Manchester- England
# 553              Discharge : Mumbai- India
# 554            Discharge : Shanghai- China
#
# [378 rows x 6 columns]

# %%
track = pd.read_csv('TRACKING SHEET.csv',skiprows = 7)

# %%
# r,c = track.shape

# po = []
# for i in range(r):   
#     if track.loc[i,'Unnamed: 3'] == 'EURO':
#         track.is_copy = False
#         track.loc[i,'Unnamed: 3'] = 'AED'
#         track.loc[i,'Unnamed: 2'] = str(int(track.loc[i,'Unnamed: 2']) * 4.13)
#         print(track.loc[i,'Unnamed: 2'])

print(track.loc[1, 'exporter/repExporter'])
# Out:
#  CHEMEM COMPANY LIMITED

# %%
# Distangolishing rep.Exporte and exporte in tacking sheet.
repOrMainCo = [True if (('UAE' in str(x))or('uae' in str(x))or('U.A.E' in str(x))or('u.a.e' in str(x))) else False for x in track['country']]# All type of uae
def randomExporter(i, Colist):
    tradingCode = []
    
    return str("")
repExporter = []
cityOfRepExporter = []
exporter = []
cityOfExporter = []
for i in range(len(repOrMainCo)):
    if repOrMainCo[i]:
        repExporter.append(str(track.loc[i, 'exporter/repExporter']))
        cityOfRepExporter.append(str(track.loc[i, 'country']))
    else:
        repExporter.append('')
        cityOfRepExporter.append('')
#     print(repExporter[i] , str(track.loc[i, 'exporter/repExporter']))
    if not (repOrMainCo[i]):
        exporter.append(str(track.loc[i, 'exporter/repExporter']))
        cityOfExporter.append(str(track.loc[i, 'country']))
    else:
        exp , cityExp = randomExporter()
        exporter.append('')
        cityOfExporter.append('')

# %%
ones = {
    0: '', 1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: 'five', 6: 'six',
    7: 'seven', 8: 'eight', 9: 'nine', 10: 'ten', 11: 'eleven', 12: 'twelve',
    13: 'thirteen', 14: 'fourteen', 15: 'fifteen', 16: 'sixteen',
    17: 'seventeen', 18: 'eighteen', 19: 'nineteen'}
tens = {
    2: 'twenty', 3: 'thirty', 4: 'forty', 5: 'fifty', 6: 'sixty',
    7: 'seventy', 8: 'eighty', 9: 'ninety'}
illions = {
    1: 'thousand', 2: 'million', 3: 'billion', 4: 'trillion', 5: 'quadrillion',
    6: 'quintillion', 7: 'sextillion', 8: 'septillion', 9: 'octillion',
    10: 'nonillion', 11: 'decillion'}

def say_number(i):
    """
    Convert an integer in to it's word representation.

    say_number(i: integer) -> string
    """
    if i < 0:
        return _join('negative', _say_number_pos(-i))
    if i == 0:
        return 'zero'
    return _say_number_pos(i)


def _say_number_pos(i):
    if i < 20:
        return ones[i]
    if i < 100:
        return _join(tens[i // 10], ones[i % 10])
    if i < 1000:
        return _divide(i, 100, 'hundred')
    for illions_number, illions_name in illions.items():
        if i < 1000**(illions_number + 1):
            break
    return _divide(i, 1000**illions_number, illions_name)


def _divide(dividend, divisor, magnitude):
    return _join(
        _say_number_pos(dividend // divisor),
        magnitude,
        _say_number_pos(dividend % divisor),
    )


def _join(*args):
    return ' '.join(filter(bool, args))

# %%
amountToWord = []
for number in track['amount']:
    amountToWord.append(say_number(number))

# %%
#,DIS1,QTY1,UNIT1,UNITPRICE1,TOTAL1,DIS2,QTY2,UNIT2,UNITPRICE2,TOTAL2
# businessType, REF, Date,IMPORTER,CTOFIM,REPPOFIM,CTOFREPOFIM,REPOFEXPORTER,CTOFREPOFEXPORTER,EXPORTER,CTOFEX,TOTALAMOUNT,Currency,INWORDS,ORIGIN,LO,DIS, amountInWord

importer = np.full(len(track['refrence']),importername)
repImporter = np.full(len(track['refrence']),repImportername)
cityOfImporter = np.full(len(track['refrence']),cityOfImportername)
cityOfrepImporter = np.full(len(track['refrence']),cityOfrepImportername)

# %%
def lcs(X , Y): 
    # find the length of the strings 
    m = len(X) 
    n = len(Y) 
  
    # declaring the array for storing the dp values 
    L = [[None]*(n+1) for i in range(m+1)] 
  
    """Following steps build L[m+1][n+1] in bottom up fashion 
    Note: L[i][j] contains length of LCS of X[0..i-1] 
    and Y[0..j-1]"""
    for i in range(m+1): 
        for j in range(n+1): 
            if i == 0 or j == 0 : 
                L[i][j] = 0
            elif X[i-1] == Y[j-1]: 
                L[i][j] = L[i-1][j-1]+1
            else: 
                L[i][j] = max(L[i-1][j] , L[i][j-1]) 
  
    # L[m][n] contains the length of LCS of X[0..n-1] & Y[0..m-1] 
    return L[m][n] 
#end of function lcs 
  
# Driver program to test the above function 
X = "AGGTAB"
Y = "GXTXAYB"
print("Length of LCS is ", lcs(X, Y))
# Out:
# Length of LCS is  4

# %%
# def lcs(s1, s2):
#     matrix = [["" for x in range(len(s2))] for x in range(len(s1))]
#     for i in range(len(s1)):
#         for j in range(len(s2)):
#             if s1[i] == s2[j]:
#                 if i == 0 or j == 0:
#                     matrix[i][j] = s1[i]
#                 else:
#                     matrix[i][j] = matrix[i-1][j-1] + s1[i]
#             else:
#                 matrix[i][j] = max(matrix[i-1][j], matrix[i][j-1], key=len)

#     cs = matrix[-1][-1]

#     return len(cs), cs

# print(lcs("abcdaf", "acbcf"))

# %%
# def lcs(X, Y, m, n): 
  
#     if m == 0 or n == 0: 
#        return 0; 
#     elif X[m-1] == Y[n-1]: 
#        return 1 + lcs(X, Y, m-1, n-1); 
#     else: 
#        return max(lcs(X, Y, m, n-1), lcs(X, Y, m-1, n)); 
# X = "AGGTAB"
# Y = "GXTXAYB"
# print("Length of LCS is ", lcs(X , Y, len(X), len(Y)))

# %%
# def longestSubstringFinder(string1, string2):
#     answer = ""
#     len1, len2 = len(string1), len(string2)
#     for i in range(len1):
#         match = ""
#         for j in range(len2):
#             if (i + j < len1 and string1[i + j] == string2[j]):
#                 match += string2[j]
#             else:
#                 if (len(match) > len(answer)): answer = match
#                 match = ""
#     return answer

# print(longestSubstringFinder("apple pie available", "apple pies"))
# print(longestSubstringFinder("apples", "appleses"))
# print(longestSubstringFinder("bapples", "cappleses"))

# %%
def getClientRef(c, clientlist):
    num = str(clientlist.loc[c,'SR. NO.']) + '.'
    for char in clientlist.loc[c,'LIST OF COMPANY']:
        if char != '.':
            num = num + char
        else:
            break
    return num
    
def bestmatch(candid,clientlist):
    candid = ''.join(e for e in candid if e.isalnum())
    c = 0
    maxAl = 0
    candidRow = []
    num = ''
    for client in clientlist['LIST OF COMPANY']:
    #     print(client)
        candidLcs = lcs(candid.lower(), client.lower())
    #     print(LsubSF)
        if candidLcs > maxAl:
            match = c
            maxAl = candidLcs
            print(len(candid),candidLcs)
            if candidLcs >= len(candid):
                candidRow = list(clientlist.iloc[c])
                num = getClientRef(c, clientlist)
        c+=1

    print(num, candidRow)
    return num, candidRow
bestmatch('STORZ MEDICAL AG',clientlist)
# Out:
# 14 9
# 14 10
# 14 12
#  []
# ('', [])

# %%
numlist = []
veclist = []
c = 0
for client in repExporter:
    print(client)
    num , vec = bestmatch(client,clientlist)
    numlist.append(num)
    veclist.append(vec)
    if num != '':
        cityOfRepExporter[c] = vec[3]
        exporter[c] = vec[4]
        cityOfExporter[c] = vec[5]
    c += 1
# Out:
#  []
#
#  []
#  CIELO OESTE GENERAL TRADING FZE
# 27 14
# 27 15
# 27 18
# 27 19
# 27 21
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#  NOVATEK GENERAL TRADING LLC
# 24 19
# 24 20
# 24 22
#  []
#
#  []
#  PHOENIX TYRES TRADING F.Z.E
# 22 13
# 22 14
# 22 16
#  []
#
#  []
#
#  []
#
#  []
#  SYED NAEEM GENERAL TRADING CO LLC
# 28 17
# 28 20
# 28 21
# 28 23
#  []
#  SYED NAEEM GENERAL TRADING CO LLC
# 28 17
# 28 20
# 28 21
# 28 23
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
# ARMACO GENERAL TRADING LLC
# 23 17
# 23 20
# 23 21
#  []
#
#  []
#
#  []
# BEYZADE GENERAL TRADING
# 21 15
# 21 16
# 21 18
# 21 21
# 2.6 [2, 'BEYLERBEYI GROUP', '6. BEYZADE GENERAL TRADING L.L.C.', 'Dubai- United Arab Emirates', 'SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD.', nan]
# BEYZADE GENERAL TRADING
# 21 15
# 21 16
# 21 18
# 21 21
# 2.6 [2, 'BEYLERBEYI GROUP', '6. BEYZADE GENERAL TRADING L.L.C.', 'Dubai- United Arab Emirates', 'SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD.', nan]
# BEYZADE GENERAL TRADING
# 21 15
# 21 16
# 21 18
# 21 21
# 2.6 [2, 'BEYLERBEYI GROUP', '6. BEYZADE GENERAL TRADING L.L.C.', 'Dubai- United Arab Emirates', 'SHANGHAI SEVEN BENEVOLENCE INTERNATIONAL TRADE CO. LTD.', nan]
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
# GALAXY SUN TELECOM LLC
# 19 9
# 19 10
# 19 11
# 19 12
# 19 13
#  []
#
#  []
# GULF LINE INTERNATIONAL TRADING COMPANY LLC
# 38 20
# 38 21
# 38 25
# 38 27
#  []
# HABIB MUHAMMAD SIDDIQUE FOOD AND BEVERAGE LLC
# 39 14
# 39 16
# 39 17
# 39 18
#  []
# HABIB MUHAMMAD SIDDIQUE FOOD AND BEVERAGE LLC
# 39 14
# 39 16
# 39 17
# 39 18
#  []
#
#  []
#
#  []
#
#  []
#
#  []
# KARJI GENERAL TRADING ESTABLISHMENT
# 32 15
# 32 17
# 32 18
# 32 19
# 32 20
#  []
#
#  []
# KMG ROBUST COMMODITY DMCC
# 22 9
# 22 10
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
# MEDIST FZE
# 9 5
# 9 6
# 9 7
# 9 8
#  []
#
#  []
#
#  []
#
#  []
# MOHAMED RUYAN MEDICAL EQUIPMENT TRADING
# 35 16
# 35 23
# 35 27
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
# SIG COMBIBLOC OEBEIKAN FZCO
# 24 9
# 24 11
# 24 13
#  []
# SILVER POOL GENERAL TRADING
# 24 15
# 24 16
# 24 17
# 24 19
# 24 21
#  []
#
#  []
#
#  []
#
#  []
# SURAWUT THIANGLE TRADING LLC
# 25 17
# 25 18
# 25 19
#  []
# SURAWUT THIANGLE TRADING LLC
# 25 17
# 25 18
# 25 19
#  []
# SURAWUT THIANGLE TRADING LLC
# 25 17
# 25 18
# 25 19
#  []
#
#  []
#
#  []
#
#  []
# TAJ AL MULOOK GENERAL TRADING LLC
# 28 18
# 28 21
#  []
#
#  []
#
#  []
#
#  []
#
#  []
# THE WATCH FZ LLC
# 13 7
# 13 8
# 13 9
#  []
#
#  []
# TOP PACIFIC TRADING LLC
# 20 14
# 20 15
# 20 16
#  []
# TOP PACIFIC TRADING LLC
# 20 14
# 20 15
# 20 16
#  []
#
#  []
#
#  []
# TURAN TRADING FZE
# 15 10
# 15 11
# 15 13
# 15 14
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []
#
#  []

# %%
#Choosing products
codeVector = []
for procode in productlist['code']:
    if procode ==TradingCode:
        codeVector.append(True)
    else:
        codeVector.append(False)
for i in range(len(codeVector)):
    1

# %%
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  ...]

# %%
#Origin
origin = []
bol = False
for word in cityOfExporter:
    word = str(word)
    if word == '':
        origin.append(word)
        continue
    for i in range(len(word)):
        if word[i] == '-':
            origin.append(word[(i+1):len(word)])
            bol = True
            break
        else:
            bol = False
    if not bol:
        origin.append(word)

# %%
forPO = []
forPO = pd.DataFrame()
forPO['REF'],forPO['date'],forPO['totalAmount'] = track['refrence'], track['date'],track['amount'] 
forPO['amountToWord'],forPO['currency'],forPO['importer'] = amountToWord,track['currency'],importer
forPO['cityOfImporter'],forPO['repImporter'],forPO['cityOfrepImporter'] = cityOfImporter,repImporter,cityOfrepImporter
forPO['exporter'],forPO['cityOfExporter'],forPO['repExporter'] = exporter,cityOfExporter,repExporter
forPO['cityOfRepExporter'],forPO['numOfClient'],forPO['laoding'] = cityOfRepExporter, numlist, cityOfExporter
forPO['Discharge'],forPO['Origin'] = cityOfImporter,origin
forPO.to_csv('buf.csv')
