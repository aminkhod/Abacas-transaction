# %%
import pandas as pd
import numpy as np

# %%
miss_value = ['']
clientlist = pd.read_csv('2018 ABACUS CLIENTS.csv')
# clientlist

# %%
productlist = pd.read_csv('product.csv',encoding='latin1' )
# productlist
productlist
# Out:
#                                                  p_name   unit    dollar  \
# 0                   Meat Bone Meal Pet Food Animal Food   TONS     460.0
# 1                            Animal Food Feed Grade DCP   TONS     300.0
# 2              Food Grade Milk Powder Replacer for Pigs   TONS    2000.0
# 3              Meat Bone Meal Animal Food Health Feed\r   TONS     460.0
# 4                    Fish Meal Poultry Food Animal Feed   TONS     500.0
# 5                Additives High Allicin Garlic Granules   TONS    1900.0
# 6                                  Feed Grade Fish Meal   TONS     500.0
# 7           Protein Powder Animal Food Corn Gluten Meal   TONS     960.0
# 8                        Feed Grade Dicalcium Phosphate   TONS     300.0
# 9     Corn Gluten Meal Animal Food High Quality New ...   TONS     960.0
# 10                                   Feed Grade DCP 18%   TONS     300.0
# 11                            Fish Meal Livestocks Food   TONS     500.0
# 12                             Fish Meal Protein Powder   TONS     600.0
# 13                Lysine HCl 98.5% for Animal Nutrition   TONS    1125.0
# 14              Animal Feed Additives 98.5% L-Threonine   TONS    2800.0
# 15               Feed Grade Lysine HCl 98. % for Animal   TONS    1200.0
# 16                             Mono-Dicalcium Phosphate   TONS     350.0
# 17                            72%Fish Meal for Fish Pig   TONS     500.0
# 18                        Animal Farm Feed Storage Silo    PCS    3500.0
# 19           Lysine Feed Additives Animal Food L-Lysine   TONS    1300.0
# 20                       L-Threonine 98.5% (FEED GRADE)   TONS    1460.0
# 21                  Garlic Powder (100-120) Animal Feed   TONS    2600.0
# 22           Fat Powder for Milk Replacer or in-Filling   TONS    2000.0
# 23            Additive Grade HCl Sulfate L Lysine 98.5%   TONS    1200.0
# 24             Animal Poultry Feed Pemix and Additive\r   TONS    2000.0
# 25                    Non Dairy Creamer Feed Addittive    TONS    1000.0
# 26          Feed Additives L-Lysine Animal Fodder 98.5%   TONS    1200.0
# 27                              Wheat Gluten Flour Meal   TONS    1380.0
# 28             Hot Ganlvanized Steel Grain Storage Silo    PCS    5000.0
# 29                      18% TCP Tricalcium Phosphate \r   TONS     850.0
# ...                                                 ...    ...       ...
# 2896       Thermoforming Machine for PP PS Pet Material    PCS   75000.0
# 2897          Candy Snack Food Chocolate Making Machine   SETS   65000.0
# 2898  Corn Flakes Cereal Snacks Food Frying Chips Ma...   SETS   25000.0
# 2899   Tray Fast Food Package Containers Making Machine    PCS  127000.0
# 2900      Packaging Equipment Food Processing Machinery   SETS  280000.0
# 2901       Thermoforming Machine for PP PS Pet Material    PCS   40000.0
# 2902                Food Machine for Meat Chicken Slice    PCS   16666.0
# 2903                          Twin Screw Snack Extruder    PCS   35000.0
# 2904              Food Machine for Making Donut Zs-Np-1    PCS    1500.0
# 2905               Poultry Floating Fish Shrimp Machine    PCS    1680.0
# 2906    Industrial Vegetable & Fruit Dehydrator Machine    PCS   13000.0
# 2907  Food Processing Fruit/Vegetable /Food/Seafood ...   SETS    3000.0
# 2908  Plastic Food Container Bowl Thermoforming Mach...    PCS   24400.0
# 2909        Starch Food Container Thermoforming Machine   SETS   90000.0
# 2910          Ce Approved Cake Machine for Food Factory  ROLLS   50000.0
# 2911     CE Dry Single Screw Floating Fish Food Machine    PCS   28000.0
# 2912      Plastic Food Storage Container Making Machine   SETS   60000.0
# 2913    Rolled Sugar ConeMachine for Food (CBIII-61*2A)   SETS  230000.0
# 2914       Sunflower Seeds /Food Making Coating Machine   SETS   35000.0
# 2915  Corn Puff Food Machine for Children (SLG 100-3...   SETS   30000.0
# 2916                  Hot Air Food Drying Dryer Machine    PCS   15000.0
# 2917  PS PSP Foam Lunch Food Container and Tray Machine   SETS  240000.0
# 2918  Conche Machine-Professional Food Machine for C...    PCS    7200.0
# 2919    PS Foam FoodContainer Making Machine(MT105/120)   SETS   80000.0
# 2920           Food Cleaning Air Bubble Washing Machine    PCS    3000.0
# 2921            Automatic Food Machine for Biscuit Line    PCS  500000.0
# 2922                 Line Food Extruder Packing Machine   SETS   10000.0
# 2923                      Pet Food Processing Machinery   SETS   85000.0
# 2924                          Pet Feed Extruder Machine   SETS   15000.0
# 2925            Automatic Food Cleaning Washing Machine    PCS    7800.0
#
#           dirham       euro            type  tradingTypeCode
# 0        1688.20     395.60     ANIMAL FOOD               22
# 1        1101.00     258.00     ANIMAL FOOD               22
# 2        7340.00    1720.00     ANIMAL FOOD               22
# 3        1688.20     395.60     ANIMAL FOOD               22
# 4        1835.00     430.00     ANIMAL FOOD               22
# 5        6973.00    1634.00     ANIMAL FOOD               22
# 6        1835.00     430.00     ANIMAL FOOD               22
# 7        3523.20     825.60     ANIMAL FOOD               22
# 8        1101.00     258.00     ANIMAL FOOD               22
# 9        3523.20     825.60     ANIMAL FOOD               22
# 10       1101.00     258.00     ANIMAL FOOD               22
# 11       1835.00     430.00     ANIMAL FOOD               22
# 12       2202.00     516.00     ANIMAL FOOD               22
# 13       4128.75     967.50     ANIMAL FOOD               22
# 14      10276.00    2408.00     ANIMAL FOOD               22
# 15       4404.00    1032.00     ANIMAL FOOD               22
# 16       1284.50     301.00     ANIMAL FOOD               22
# 17       1835.00     430.00     ANIMAL FOOD               22
# 18      12845.00    3010.00     ANIMAL FOOD               22
# 19       4771.00    1118.00     ANIMAL FOOD               22
# 20       5358.20    1255.60     ANIMAL FOOD               22
# 21       9542.00    2236.00     ANIMAL FOOD               22
# 22       7340.00    1720.00     ANIMAL FOOD               22
# 23       4404.00    1032.00     ANIMAL FOOD               22
# 24       7340.00    1720.00     ANIMAL FOOD               22
# 25       3670.00     860.00     ANIMAL FOOD               22
# 26       4404.00    1032.00     ANIMAL FOOD               22
# 27       5064.60    1186.80     ANIMAL FOOD               22
# 28      18350.00    4300.00     ANIMAL FOOD               22
# 29       3119.50     731.00     ANIMAL FOOD               22
# ...          ...        ...             ...              ...
# 2896   275250.00   64500.00  WOOD MACHINERY               29
# 2897   238550.00   55900.00  WOOD MACHINERY               29
# 2898    91750.00   21500.00  WOOD MACHINERY               29
# 2899   466090.00  109220.00  WOOD MACHINERY               29
# 2900  1027600.00  240800.00  WOOD MACHINERY               29
# 2901   146800.00   34400.00  WOOD MACHINERY               29
# 2902    61164.22   14332.76  WOOD MACHINERY               29
# 2903   128450.00   30100.00  WOOD MACHINERY               29
# 2904     5505.00    1290.00  WOOD MACHINERY               29
# 2905     6165.60    1444.80  WOOD MACHINERY               29
# 2906    47710.00   11180.00  WOOD MACHINERY               29
# 2907    11010.00    2580.00  WOOD MACHINERY               29
# 2908    89548.00   20984.00  WOOD MACHINERY               29
# 2909   330300.00   77400.00  WOOD MACHINERY               29
# 2910   183500.00   43000.00  WOOD MACHINERY               29
# 2911   102760.00   24080.00  WOOD MACHINERY               29
# 2912   220200.00   51600.00  WOOD MACHINERY               29
# 2913   844100.00  197800.00  WOOD MACHINERY               29
# 2914   128450.00   30100.00  WOOD MACHINERY               29
# 2915   110100.00   25800.00  WOOD MACHINERY               29
# 2916    55050.00   12900.00  WOOD MACHINERY               29
# 2917   880800.00  206400.00  WOOD MACHINERY               29
# 2918    26424.00    6192.00  WOOD MACHINERY               29
# 2919   293600.00   68800.00  WOOD MACHINERY               29
# 2920    11010.00    2580.00  WOOD MACHINERY               29
# 2921  1835000.00  430000.00  WOOD MACHINERY               29
# 2922    36700.00    8600.00  WOOD MACHINERY               29
# 2923   311950.00   73100.00  WOOD MACHINERY               29
# 2924    55050.00   12900.00  WOOD MACHINERY               29
# 2925    28626.00    6708.00  WOOD MACHINERY               29
#
# [2926 rows x 7 columns]

# %%
Colist = pd.read_excel('List of Companies.xlsx')
Colist
# Out:
#                                              companies  \
# 0                             ORLUX IMPORT,EXPORT GMBH
# 1    SHANDONG FUPPON AGRICULTURAL MACHINERY EQUIPME...
# 2                                       New Hope Group
# 3                                              Cargill
# 4                                         Land O'Lakes
# 5                                                  BRF
# 6                                      ForFarmers N.V.
# 7                                              Nutreco
# 8                                           JA Zen,Noh
# 9                                 ADII SYNERGY SDN BHD
# 10                                           FIMAR SPA
# 11                   KAITO ENTERPRISES COMPANY LIMITED
# 12                                ADII SYNERGY SDN BHD
# 13                                           FIMAR SPA
# 14                   KAITO ENTERPRISES COMPANY LIMITED
# 15         SUZHOU CLEANSTAR ELECTRIC APPLIANCE CO. LTD
# 16              GUANGDONG ZHONGBAO KITCHENWARE CO. LTD
# 17                HOWELL CLEAN APPLIANCES (HK) LIMITED
# 18              GUANGDONG ZHONGBAO KITCHENWARE CO. LTD
# 19                HOWELL CLEAN APPLIANCES (HK) LIMITED
# 20         SUZHOU CLEANSTAR ELECTRIC APPLIANCE CO. LTD
# 21                   AnHuiarts & Crafts imp.exp.Co.Ltd
# 22                   ANHUIARTS & CRAFTS IMP.EXP.CO.LTD
# 23                                      MENGYANG GROUP
# 24                                          SENECA SRL
# 25                              R.B.AUTOMAZIONE S.R.L.
# 26                           ARAYMOND FLUID CONNECTION
# 27                               AUTOMATION CO. UNITED
# 28                    FAURECIA SIEGES D AUTOMOBILE SAS
# 29                            GTEC AUTOMOBILE PTE LTD.
# ..                                                 ...
# 539                       ELINO INTERNATIONAL CO., LTD
# 540                                     ENITENCNI SAGL
# 541           FOSHAN ZHENGSAU STAINLESS STEEL CO. LTD.
# 542             HONGKONG HUIXING STEEL COMPANY LIMITED
# 543                              JIANGSU METAL LIMITED
# 544  JOHOR LAND BERHAD JALAN BUNITED KINGDOMIT MUTIARA
# 545                NINGBO ZHONGHUAN STEEL BALL FACTORY
# 546             OZMET METAL MAL IMAL SAN IC VE DIS LTD
# 547                     PERKIS BAKIR ALASIMLARI SANAYI
# 548                    QINGDAO JIAHEXIN STEEL CO., LTD
# 549                SARBAK METAL TICARET VE SANAYI A.Ş.
# 550      SHANDONG SHUANGWANG ALUMINUM INDUSTRY CO. LTD
# 551        SHENZHEN NEW ORIGIN SPECIAL STEEL CO., LTD.
# 552                          SHINING HOUSEWARES CO LTD
# 553                               AKIJ JUTE MILLS LTD.
# 554             Hangzhou Yinyan Silk Weaving Co., Ltd.
# 555                               AKIJ JUTE MILLS LTD.
# 556                  SHANGHAI CEDL (IM / EX) CO., LTD.
# 557              SHANGHAI BESTWAY INTERNATIONAL CO LTD
# 558            SHANGHAI FAVORS IMPORT & EXPORT CO. LTD
# 559          SHANGHAI JIHAO INT'L ENTERPRISE CO., LTD.
# 560    SHANGHAI MALMAM INTERNATIONAL TRADING CO., LTD.
# 561          SHANGHAI MEILAN APPAREL TECHNOLOGY CO,LTD
# 562     SHIJIAZHUANG JILI TEXTILE LINING CLOTH CO.,LTD
# 563            SHANGHAI P&E IMPORT AND EXPORT CO.,LTD.
# 564                              CALLENS AFRICAN,WOODS
# 565                                HUSONG WOOD CO. LTD
# 566                            JIANGSU LANDISI WOOD CO
# 567                                      Lagae Hout nv
# 568                                  NATURAL TRADE LTD
#
#                         country                    type  \
# 0    Frankfurt Am Main, Germany            AGRICULTURAL
# 1              Liaocheng, China  AGRICULTURAL MACHINERY
# 2            Gansu Sheng, China             ANIMAL FOOD
# 3         Topeka, United States             ANIMAL FOOD
# 4        Florida, United States             ANIMAL FOOD
# 5     Ponta Grossa , PR, Brazil             ANIMAL FOOD
# 6           Lochem, Netherlands             ANIMAL FOOD
# 7          Boxmeer, Netherlands             ANIMAL FOOD
# 8                  Tokyo, Japan             ANIMAL FOOD
# 9        Kuala Lumpur, Malaysia               APLLIANCE
# 10       Villa Verucchio, Italy               APLLIANCE
# 11             Hong Kong, China               APLLIANCE
# 12       Kuala Lumpur, Malaysia               APLLIANCE
# 13       Villa Verucchio, Italy               APLLIANCE
# 14             Hong Kong, China               APLLIANCE
# 15              Shanghai, China               APPLIANCE
# 16               Guandong China               APPLIANCE
# 17            Hong Kong , China               APPLIANCE
# 18               Guandong China               APPLIANCE
# 19            Hong Kong , China               APPLIANCE
# 20              Shanghai, China               APPLIANCE
# 21                  Anhui,China                     ART
# 22                  Anhui,China                     ART
# 23               Jiangsu, China               SPARE CAR
# 24                 Padua, Italy               SPARE CAR
# 25                Genova, Italy               SPARE CAR
# 26             Grenoble, France               SPARE CAR
# 27    Liverpool, United Kingdom               SPARE CAR
# 28             Nanterre, France               SPARE CAR
# 29                Padova, Italy               SPARE CAR
# ..                          ...                     ...
# 539             Shanghai, China                   STEEL
# 540           Bern, Switzerland                   STEEL
# 541            Guangdong, China                   STEEL
# 542            Hong Kong, China                   STEEL
# 543              Jiangsu, China                   STEEL
# 544             Johor, Malaysia                   STEEL
# 545               NINGBO, China                   STEEL
# 546            Istanbul. Turkey                   STEEL
# 547            Istanbul, Turkey                   STEEL
# 548         Qingdao City, China                   STEEL
# 549            Istanbul, Turkey                   STEEL
# 550             Shandong, China                   STEEL
# 551             Shenzhen, China                   STEEL
# 552             Shenzhen, China                   STEEL
# 553           Dhaka, Bangladesh                 TEXTILE
# 554             Hangzhou, China                 TEXTILE
# 555           Dhaka, Bangladesh                 TEXTILE
# 556             Shanghai, China                 TEXTILE
# 557             Shanghai, China                 TEXTILE
# 558             Shanghai, China                 TEXTILE
# 559             Shanghai, China                 TEXTILE
# 560             Shanghai, China                 TEXTILE
# 561              Shanghai China                 TEXTILE
# 562                Hebei, China                 TEXTILE
# 563             Shanghai, China       TEXTILE MACHINERY
# 564             Rekkem, Belgium                    WOOD
# 565             Shanghai, China                    WOOD
# 566              Jiangsu, China                    WOOD
# 567           Kortrijk, Belgium                    WOOD
# 568           Vancouver, Canada                    WOOD
#
#                       origin  loading  discharge  tradingTypeCode
# 0           Origin : Germany      NaN        NaN             21.0
# 1             Origin : China      NaN        NaN             21.0
# 2             Origin : China      NaN        NaN             22.0
# 3     Origin : United States      NaN        NaN             22.0
# 4     Origin : United States      NaN        NaN             22.0
# 5            Origin : Brazil      NaN        NaN             22.0
# 6       Origin : Netherlands      NaN        NaN             22.0
# 7       Origin : Netherlands      NaN        NaN             22.0
# 8             Origin : Japan      NaN        NaN             22.0
# 9          Origin : Malaysia      NaN        NaN             17.0
# 10            Origin : Italy      NaN        NaN             17.0
# 11            Origin : China      NaN        NaN             17.0
# 12         Origin : Malaysia      NaN        NaN             17.0
# 13            Origin : Italy      NaN        NaN             17.0
# 14            Origin : China      NaN        NaN             17.0
# 15            Origin : China      NaN        NaN             17.0
# 16            Origin : China      NaN        NaN             17.0
# 17            Origin : China      NaN        NaN             17.0
# 18            Origin : China      NaN        NaN             17.0
# 19            Origin : China      NaN        NaN             17.0
# 20            Origin : China      NaN        NaN             17.0
# 21            Origin : China      NaN        NaN              NaN
# 22            Origin : China      NaN        NaN              NaN
# 23            Origin : China      NaN        NaN             26.0
# 24            Origin : Italy      NaN        NaN             26.0
# 25            Origin : Italy      NaN        NaN             26.0
# 26           Origin : France      NaN        NaN             26.0
# 27   Origin : United Kingdom      NaN        NaN             26.0
# 28           Origin : France      NaN        NaN             26.0
# 29            Origin : Italy      NaN        NaN             26.0
# ..                       ...      ...        ...              ...
# 539           Origin : China      NaN        NaN              5.0
# 540     Origin : Switzerland      NaN        NaN              5.0
# 541           Origin : China      NaN        NaN              5.0
# 542           Origin : China      NaN        NaN              5.0
# 543           Origin : China      NaN        NaN              5.0
# 544        Origin : Malaysia      NaN        NaN              5.0
# 545           Origin : China      NaN        NaN              5.0
# 546          Origin : Turkey      NaN        NaN              5.0
# 547          Origin : Turkey      NaN        NaN              5.0
# 548           Origin : China      NaN        NaN              5.0
# 549          Origin : Turkey      NaN        NaN              5.0
# 550           Origin : China      NaN        NaN              5.0
# 551           Origin : China      NaN        NaN              5.0
# 552           Origin : China      NaN        NaN              5.0
# 553      Origin : Bangladesh      NaN        NaN             54.0
# 20      AED                                 NaN             NaN
# 21      AED                                 NaN             NaN
# 22      AED                                 NaN             NaN
# 23      AED                                 NaN             NaN
# 24      AED                                 NaN             NaN
# 25      AED                                 NaN             NaN
# 26      AED                                 NaN             NaN
# 27      AED                                 NaN             NaN
# 28      AED                                 NaN             NaN
# 29      AED                                 NaN             NaN
# 30      AED                                 NaN             NaN
# 31      AED                                 NaN             NaN
# 32      AED                                 NaN             NaN
# 33      AED                                 NaN             NaN
# 34      AED                                 NaN             NaN
# 35      AED                                 NaN             NaN
# 36      AED                                 NaN             NaN
# 37      AED                                 NaN             NaN
# 38      AED                                 NaN             NaN
# 39      AED                                 NaN             NaN
# 40      AED                                 NaN             NaN
# 41      AED                                 NaN             NaN
# 42      AED                                 NaN             NaN
# 43      AED                                 NaN             NaN
# 44      AED                                 NaN             NaN
# 45      AED                                 NaN             NaN

# %%
def getBoldataframe(TradingCode, datalist):
    codeVector = []
    for procode in datalist['tradingTypeCode']:
        if procode ==TradingCode:
            codeVector.append(True)
        else:
            codeVector.append(False)

    return datalist[codeVector]

# %%
# Distangolishing rep.Exporter and exporter in tacking sheet.
repOrMainCo = [True if (('UAE' in str(x))or('uae' in str(x))or('U.A.E' in str(x))or('u.a.e' in str(x))) else False for x in track['country']]# All type of uae

def randomExporter(i, datalist):
    tradedataframe = getBoldataframe(i,datalist)
    r, _ = tradedataframe.shape
    count = np.floor(np.random.rand()*r)
    return str(datalist.loc[count,'companies']),str(datalist.loc[count,'country'])
repExporter = []
cityOfRepExporter = []
exporter = []
cityOfExporter = []
for i in range(len(repOrMainCo)):
    if repOrMainCo[i]:
        repExporter.append(str(track.loc[i, 'exporter/repExporter']).upper())
        cityOfRepExporter.append(str(track.loc[i, 'country']).title())
    else:
        repExporter.append('')
        cityOfRepExporter.append('')

    if not (repOrMainCo[i]):
        exporter.append(str(track.loc[i, 'exporter/repExporter']).upper())
        cityOfExporter.append(str(track.loc[i, 'country']).title())
    else:
        exp , cityExp = randomExporter(track.loc[i,'TYPE OFProducts'],Colist)
        exporter.append(exp)
        cityOfExporter.append(cityExp.title())

# %%
ones = {
    0: '', 1: 'One', 2: 'Two', 3: 'Three', 4: 'Four', 5: 'Five', 6: 'Six',
    7: 'Seven', 8: 'Eight', 9: 'Nine', 10: 'Ten', 11: 'Eleven', 12: 'Twelve',
    13: 'Thirteen', 14: 'Fourteen', 15: 'Fifteen', 16: 'Sixteen',
    17: 'Seventeen', 18: 'Eighteen', 19: 'Nineteen'}
tens = {
    2: 'Twenty', 3: 'Thirty', 4: 'Forty', 5: 'Fifty', 6: 'Sixty',
    7: 'Seventy', 8: 'Eighty', 9: 'Ninety'}
illions = {
    1: 'Thousand', 2: 'Million', 3: 'Billion', 4: 'Trillion', 5: 'Quadrillion',
    6: 'Quintillion', 7: 'Sextillion', 8: 'Septillion', 9: 'Octillion',
    10: 'Nonillion', 11: 'Decillion'}

def say_number(i):
    """
    Convert an integer in to it's word representation.

    say_number(i: integer) -> string
    """
    if i < 0:
        return _join('Negative', _say_number_pos(-i))
    if i == 0:
        return 'Zero'

    return _say_number_pos(i)


def _say_number_pos(i):
    if i == 0:
        return ''
    if i < 1:
        return str(np.round(i*100)) + '/100'
    if i < 20:
        return _join(ones[int(i)],_say_number_pos(i % 1))
    if i < 100:
        return _join(_join(tens[i // 10], ones[int(i) % 10]),_say_number_pos(i % 1))
    if i < 1000:
        return _divide(i, 100, 'Hundred')
    for illions_number, illions_name in illions.items():
        if i < 1000**(illions_number + 1):
            break
    return _divide(i, 1000**illions_number, illions_name)


def _divide(dividend, divisor, magnitude):
    return _join(
        _say_number_pos(dividend // divisor),
        magnitude,
        _say_number_pos(dividend % divisor),
    )


def _join(*args):
    return ' '.join(filter(bool, args))

# %%
amountToWord = []
c = 0
for number in track['amount']:
    number = np.round(number, decimals=2)
    if str(track.loc[c,'currency']).lower() == 'euro':
        amountToWord.append(say_number(number) + ' Euros Only')
    elif str(track.loc[c,'currency']).lower() == 'aed':
        amountToWord.append(say_number(number) + ' Dirhams Only')
    elif str(track.loc[c,'currency']).lower() == 'pound':
        amountToWord.append(say_number(number) + ' Pound sterlings Only')
    elif str(track.loc[c,'currency']).lower() == 'cad':
        amountToWord.append(say_number(number) + ' canadian Dollars Only')
    elif str(track.loc[c,'currency']).lower() == 'usd':
        amountToWord.append(say_number(number) + ' U.S Dollars Only')
    c +=1

# %%
#,DIS1,QTY1,UNIT1,UNITPRICE1,TOTAL1,DIS2,QTY2,UNIT2,UNITPRICE2,TOTAL2
# businessType, REF, Date,IMPORTER,CTOFIM,REPPOFIM,CTOFREPOFIM,REPOFEXPORTER,CTOFREPOFEXPORTER,EXPORTER,CTOFEX,TOTALAMOUNT,Currency,INWORDS,ORIGIN,LO,DIS, amountInWord

importer = track['SOURCE COMPANY']
repImporter = track['COMPANY NAME']
cityOfImporter = track['SourceCo.City']
cityOfrepImporter = track['CO.City']

# %%
# def lcs(X , Y): 
#     # find the length of the strings 
#     m = len(X) 
#     n = len(Y) 
  
#     # declaring the array for storing the dp values 
#     L = [[None]*(n+1) for i in range(m+1)] 
  
#     """Following steps build L[m+1][n+1] in bottom up fashion 
#     Note: L[i][j] contains length of LCS of X[0..i-1] 
#     and Y[0..j-1]"""
#     for i in range(m+1): 
#         for j in range(n+1): 
#             if i == 0 or j == 0 : 
#                 L[i][j] = 0
#             elif X[i-1] == Y[j-1]: 
#                 L[i][j] = L[i-1][j-1]+1
#             else: 
#                 L[i][j] = max(L[i-1][j] , L[i][j-1]) 
  
#     # L[m][n] contains the length of LCS of X[0..n-1] & Y[0..m-1] 
#     return L[m][n] 
# #end of function lcs

# %%
# def getClientRef(c, clientlist):
#     num = str(clientlist.loc[c,'SR. NO.']) + '.'
#     for char in clientlist.loc[c,'LIST OF COMPANY']:
#         if char != '.':
#             num = num + char
#         else:
#             break
#     return num
    
# def bestmatch(candid,clientlist):
#     # Remove all bad charachters.
#     candid = ''.join(e for e in candid if e.isalnum())
#     c = 0
#     maxAl = 0
#     candidRow = []
#     num = ''
#     maxLCStoClient = 0
#     for client in clientlist['LIST OF COMPANY']:
#     #     print(client)
#         candidLcs = lcs(candid.lower(), client.lower())
#         LCStoClient = candidLcs / len(client)
# #         print(candidLcs)
# #         print(len(candid),candidLcs)
# #         if candidLcs > maxAl:
# #             match = c
# #             maxAl = candidLcs
# #             maxLCStoClient = LCStoClient
# #         elif (candidLcs == maxAl) and (maxLCStoClient < LCStoClient):
# #             match = c
# #             maxAl = candidLcs
# #             maxLCStoClient = LCStoClient                
                
# #         print(len(candid),candidLcs)
#         if (candidLcs == len(candid)):
# #             print(len(client.lower()))
# #             print(len(candid),candidLcs)
#             if (candidLcs / len(client.lower()) >= 0.5):
#                 if (maxLCStoClient < LCStoClient):
#                     candidRow = list(clientlist.iloc[c])
#                     num = getClientRef(c, clientlist)
#                     maxLCStoClient = LCStoClient
# #                 print(maxLCStoClient)
# #                 print(num, candidRow)
#         c+=1


#     return num, candidRow
# bestmatch('AL FEEL TRADING LLC',clientlist)

# %%
def getClientRef(c, clientlist):
    num = str(clientlist.loc[c,'SR. NO.']) + '.'
    num = num + clientlist.loc[c,'LIST OF COMPANY'][:4]
#     for char in clientlist.loc[c,'LIST OF COMPANY']:
#         if char != '.':
#             num = num + char
#         else:
#             break
    return num
def exactMatch(candid,clientlist):
    candid = ''.join(e for e in candid if e.isalnum())
    candidRow = []
    c = 0
    num = ''
    for client in clientlist['LIST OF COMPANY']:
        client = ''.join(e for e in client if e.isalnum())
        if client == candid:
            candidRow = list(clientlist.iloc[c])
            num = getClientRef(c, clientlist)
        c +=1
    return num, candidRow

# %%
for i in range(len(exporter)):
    if (str(exporter[i]) == '') or (str(exporter[i]) == str(np.nan)) or (str(exporter[i]) == 'NAN'):
        exp , cityExp = randomExporter(track.loc[i,'TYPE OFProducts'],Colist)
        exporter[i] =  exp
        cityOfExporter[i] = cityExp

# %%
numlist = []
veclist = []
c = 0
for client in repExporter:
#     num , vec = bestmatch(client,clientlist)
    num, vec = exactMatch(client,clientlist)
    numlist.append(num)
    veclist.append(vec)
    if vec != []:
        cityOfRepExporter[c] = vec[3].title()
        exporter[c] = vec[4].upper()
        cityOfExporter[c] = vec[5]
    c += 1

# %%
def QtyClassification(amount, mean):
    estQty = int(amount / mean)
    if (estQty < 30):
        return 1
    elif (estQty >= 30) and (estQty < 80):
        return np.ceil(np.random.randint(1,2,1))
    
    if (estQty >= 80) and (estQty < 150):
        return np.ceil(np.random.randint(2,3,1))
    
    elif (estQty >= 150) and (estQty < 300):
        return np.ceil(np.random.randint(2,4,1))
    
    elif (estQty >= 300) and (estQty < 600):
        return np.ceil(np.random.randint(3,4,1))

    elif (estQty >= 600) and (estQty <1000 ):
        return np.ceil(np.random.randint(4,5,1))

    elif (estQty > 1000 ):
        return 5

# %%
#Choosing products

def getRandomKProduct(amount,iD, datalist):
    tradedataframe = getBoldataframe(iD,datalist)
    codeVector = []
    amount = np.round(amount, decimals=2)
    # removing greater than amount
    for proAmount in tradedataframe['dollar']:
        proAmount = np.round(proAmount, decimals=2)
        if amount > proAmount:
            codeVector.append(True)
        else:
            codeVector.append(False)
    tradedataframe = tradedataframe[codeVector]
    #Computing mean value
    codeVector = []
    mean = np.mean(tradedataframe['dollar'])

    for proAmount in tradedataframe['dollar']:
        if (proAmount > mean/80) and proAmount < mean*80:
            codeVector.append(True)
        else:
            codeVector.append(False)
    
    r, _ = tradedataframe.shape

    tradedataframe = tradedataframe[codeVector]
    
    r, _ = tradedataframe.shape

    k = int(QtyClassification(amount , mean))

    produc = []
    if k < r:
        for i in range(k):
            count = np.random.randint(0,r-1,1)

            produc.append(list(tradedataframe.iloc[count[0]]))
            tradedataframe.drop(tradedataframe.index[count[0]], inplace=True)
            r, c = tradedataframe.shape

    else:
        produc =tradedataframe

    RandomKProduct = pd.DataFrame(produc)

    RandomKProduct.columns = ['p_name','unit','dollar','dirham','euro','type','tradingTypeCode']
    return RandomKProduct

# %%
def changeCurrency(i , data):
#     print(str(track.loc[i,'currency']).lower())
    
    if str(track.loc[i,'currency']).lower() == 'euro':

        return float(track.loc[i,'amount'] * 1.13)
    elif str(track.loc[i,'currency']).lower()[:] == 'aed':

        return float(track.loc[i,'amount'] * 0.27)
    elif str(track.loc[i,'currency']).lower() == 'pound':

        return float(track.loc[i,'amount'] * 1.32)
    elif str(track.loc[i,'currency']).lower() == 'cad':

        return float(track.loc[i,'amount'] * 0.75)
    else:

        return

# %%
def returnCurrency( unitp, i, trak):
    if str(track.loc[i,'currency']).lower() == 'euro':
        return float(unitp) / 0.89
    elif str(track.loc[i,'currency']).lower() == 'aed':
        return float(unitp) / 3.67
    elif str(track.loc[i,'currency']).lower() == 'pound':
        return float(unitp) / 0.76
    elif str(track.loc[i,'currency']).lower() == 'cad':
        return float(unitp) / 1.34
    else:
        return unitp

# %%
#amount    currency
#1
p1name = []
p1unit = []
p1unitp = []
p1qty = []
p1total = []
#2
p2name = []
p2unit = []
p2unitp = []
p2qty = []
p2total = []
#3
p3name = []
p3unit = []
p3unitp = []
p3qty = []
p3total = []
#4
p4name = []
p4unit = []
p4unitp = []
p4qty = []
p4total = []
#5
p5name = []
p5unit = []
p5unitp = []
p5qty = []
p5total = []
for i in range(len(track['date'])):

    pname = []
    unit = []
    unitp = []
    qty = []
    total = []

    if str(track.loc[i,'currency']).lower() == 'usd':
        amount = float(track.loc[i,'amount'])
    else:
        amount = float(changeCurrency(i,track))
    amount = np.round(amount, decimals=2)
    TradingCode = track.loc[i, 'TYPE OFProducts']
    RandomKProduct = getRandomKProduct(amount, TradingCode, productlist)
    RandomKProduct = RandomKProduct.sort_values(by='dollar', ascending=False)
    
    copyamount = amount = np.round(float(track.loc[i,'amount']), decimals=2)

    #allocating rest of amount
    tot = 0
    tempqty = 0
    if (len(RandomKProduct['p_name']) > 1):
        for j in range(len(RandomKProduct['p_name']) - 1):
            bound = int(copyamount / float(RandomKProduct.loc[j,'dollar'] ))
            pname.append(RandomKProduct.loc[j,'p_name'] )
            unit.append(RandomKProduct.loc[j,'unit'])
            unitp.append(returnCurrency(RandomKProduct.loc[j,'dollar'],i ,track))
            tempqty = np.floor(np.random.randint(1,(bound * 0.7),1)[0])
#             print((amount - (unitp[-1] * tempqty))/float(RandomKProduct.loc[j + 1,'dollar']))
#             while((amount - (unitp[-1] * tempqty))/float(RandomKProduct.loc[j + 1,'dollar']) < 1) and (amount - (unitp[-1] * tempqty)) < 0:
#                 tempqty = np.floor(np.random.randint(1,(bound/2),1)[0])
#                 print((amount - (unitp[-1] * tempqty))/float(RandomKProduct.loc[j + 1,'dollar']))
            copyamount = np.round(copyamount - (unitp[-1] * tempqty), decimals=2)
            qty.append(tempqty)
            total.append(np.round((unitp[-1] * qty[-1]), decimals=2))
            tot += np.round((unitp[-1] * qty[-1]), decimals=2)
    k = len(RandomKProduct['p_name']) - 1
    pname.append(RandomKProduct.loc[k,'p_name'] )
    unit.append(RandomKProduct.loc[k,'unit'])
    unitp.append(returnCurrency(RandomKProduct.loc[k,'dollar'],i ,track))
    qty.append(int(copyamount / RandomKProduct.loc[k,'dollar']))


    unitp[-1] = float(copyamount / qty[-1])
    total.append(np.round((amount - tot), decimals=2))

    

    #1
    p1name.append(pname[0])
    p1unit.append(unit[0])
    p1unitp.append(unitp[0])
    p1qty.append(qty[0])
    p1total.append(total[0])
    #2
    if len(pname) > 1:
        p2name.append(pname[1])
        p2unit.append(unit[1])
        p2unitp.append(unitp[1])
        p2qty.append(qty[1])
        p2total.append(total[1])
    else:
        p2name.append('')
        p2unit.append('')
        p2unitp.append('')
        p2qty.append('')
        p2total.append('')
        
    #3
    if len(pname) > 2:
        p3name.append(pname[2])
        p3unit.append(unit[2])
        p3unitp.append(unitp[2])
        p3qty.append(qty[2])
        p3total.append(total[2])
    else:
        p3name.append('')
        p3unit.append('')
        p3unitp.append('')
        p3qty.append('')
        p3total.append('')        
    #4
    if len(pname) > 3:
        p4name.append(pname[3])
        p4unit.append(unit[3])
        p4unitp.append(unitp[3])
        p4qty.append(qty[3])
        p4total.append(total[3])
    else:
        p4name.append('')
        p4unit.append('')
        p4unitp.append('')
        p4qty.append('')
        p4total.append('')        
    #5
    if len(pname) > 4:
        p5name.append(pname[4])
        p5unit.append(unit[4])
        p5unitp.append(unitp[4])
        p5qty.append(qty[4])
        p5total.append(total[4])
    else:
        p5name.append('')
        p5unit.append('')
        p5unitp.append('')
        p5qty.append('')
        p5total.append('')

# %%
#Loading
load = []
loadingWithoutLoading = []
for city in cityOfExporter:
    load.append('Loading: ' + str(city))
    loadingWithoutLoading.append(str(city))

# %%
#dischareg
dischareg = []
dischargeWithoutDischarge = []
countryOfDestination = []
countryOfDestinationWith = []
bol = False
for city in cityOfImporter:
    city = str(city)
    dischareg.append('Discharge: ' + str(city))
    dischargeWithoutDischarge.append(str(city))
    if city == '':
        countryOfDestination.append(city.upper())
        continue
    for i in range(len(city)):
        if city[i] == ',':
            countryOfDestination.append(str(city[(i+2):len(city)]).upper())
            countryOfDestinationWith.append(('Country of destination : ' + str(city[(i+2):len(city)])).upper())
            bol = True
            break
        else:
            bol = False
    if not bol:
        countryOfDestination.append(city.upper())   
        countryOfDestinationWith.append(('Country of destination : ' + city).upper())

# %%
amountInWordsWithString = []
for  amToW in amountToWord:
    amountInWordsWithString.append('Amount in words : ' + amToW)

# %%
#Date
datePO = [] 
dateSQ = []
datePI = []
dateCIorPL =[]

datePOWith = [] 
dateSQWith = []
datePIWith = []
dateCIorPLWith =[]

for i in range(len(track['date'])):
    datePO.append('=TEXT(AP' + str(i+2) + ' -30,"dd/mm/yyyy")')
    dateSQ.append('=TEXT(AP' + str(i+2) + ' -31,"dd/mm/yyyy")')
    datePI.append('=TEXT(AP' + str(i+2) + ' -25,"dd/mm/yyyy")')
    dateCIorPL.append('=TEXT(AP' + str(i+2) + ' +10,"dd/mm/yyyy")')

    datePOWith.append('="Date: " & (TEXT(AP' + str(i+2) + ' -30,"dd/mm/yyyy"))')
    dateSQWith.append('="Date: " & (TEXT(AP' + str(i+2) + ' -31,"dd/mm/yyyy"))')
    datePIWith.append('="Date: " & (TEXT(AP' + str(i+2) + ' -25,"dd/mm/yyyy"))')
    dateCIorPLWith.append('="Date: " & (TEXT(AP' + str(i+2) + ' +10,"dd/mm/yyyy"))')

# %%
forPO = []
forPO = pd.DataFrame()
forPO['REF'] = track['refrence']

forPO['repExporter'], forPO['cityOfRepExporter'] = repExporter, list(cityOfRepExporter)
forPO['exporter'], forPO['cityOfExporter']  = exporter, cityOfExporter

forPO['importer'], forPO['cityOfImporter'] = importer, cityOfImporter
forPO['repImporter'], forPO['cityOfrepImporter'] = repImporter, list(cityOfrepImporter)

forPO['Origin'], forPO['laoding'], forPO['Discharge'] = origin, load, dischareg

forPO['totalAmount'], forPO['amountToWord'] = track['amount'], amountToWord
#1
forPO['p1name'] = p1name
forPO['p1qty'] = p1qty
forPO['p1unit'] = p1unit
forPO['p1unitp'] = p1unitp
forPO['p1total'] = p1total
#2
forPO['p2name'] = p2name
forPO['p2qty'] = p2qty
forPO['p2unit'] = p2unit
forPO['p2unitp'] = p2unitp
forPO['p2total'] =p2total
#3
forPO['p3name'] = p3name
forPO['p3qty'] = p3qty
forPO['p3unit'] = p3unit
forPO['p3unitp'] = p3unitp
forPO['p3total'] = p3total
#4
forPO['p4name'] = p4name
forPO['p4qty'] = p4qty
forPO['p4unit'] = p4unit
forPO['p4unitp'] = p4unitp
forPO['p4total'] = p4total
#5
forPO['p5name'] = p5name
forPO['p5qty'] = p5qty
forPO['p5unit'] = p5unit
forPO['p5unitp'] = p5unitp
forPO['p5total'] = p5total

forPO['numOfClient'] = numlist

forPO['currency'], forPO['date'] = track['currency'], track['date']

forPO['amount in words'] = amountInWordsWithString
forPO['origin without origin'] = originWithoutOrigin
forPO['loading without loading'] = loadingWithoutLoading
forPO['discharge without discharge'] = dischargeWithoutDischarge

forPO['country of manufacture'] = countryOfManufacture
forPO['country of destination'] = countryOfDestination

forPO['date of PO'] = datePO
forPO['date of SQ'] = dateSQ
forPO['date of PI'] = datePI
forPO['date of CIorPL'] = dateCIorPL

forPO['countryOfManufacture'] = countryOfManufactureWith
forPO['countryOfDestinationWith'] = countryOfDestinationWith

forPO['datePOWith'] = datePOWith
forPO['dateSQWith'] = dateSQWith
forPO['datePIWith'] = datePIWith
forPO['dateCIorPLWith'] = dateCIorPLWith

forPO.to_csv('Tracking Sheet output.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ed7224bab28a> in <module>
#       1 forPO = []
# ----> 2 forPO = pd.DataFrame()
#       3 forPO['REF'] = track['refrence']
#       4
#       5 forPO['repExporter'], forPO['cityOfRepExporter'] = repExporter, list(cityOfRepExporter)
#
# NameError: name 'pd' is not defined
