# %%
import pandas as pd

# %%
naval=['']
clientlist = pd.read_csv('CLIENT_LIST.csv')

# %%
clientlist
# Out:
#                                             Unnamed: 0  \
# 0                BORNOVA BULDING MATERIALS TRADING LLC
# 1                          YAKAMOZ GENERAL TRADING LLC
# 2              STIRLING BRIDGE CHEMICALS TRADING L.L.C
# 3                            TRUVA GENERAL TRADING LLC
# 4                         SERAY FURNITURES TRADING LLC
# 5                                        NORTH SEA FZE
# 6                     BEYLERBEYI GENERAL TRADING L.L.C
# 7    KANNUR INDUSTRIAL PLANT EQUIPMENT & SPARE PART...
# 8                           ELYSEE GENERAL TRADING LLC
# 9    D E V INDUSTRIAL PLANT EQUIPMENT & SPARE PARTS...
# 10          YEDI TEPE BUILDING MATERIALS TRADING L.L.C
# 11                      BEYZADE GENERAL TRADING L.L.C.
# 12                   DAY & NIGHT GENERAL TRADING L.L.C
# 13                              SAND BOX TRADING L.L.C
# 14                      MARCELLO GENERAL TRADING L.L.C
# 15   PRECISION VISION HEAVY EQUIPMENT & MACHINERY T...
# ...

# %%
clientlist = pd.read_csv('CLIENT_LIST.csv')
