# %%
import pandas as pd
import numpy as np

# %%
miss_value = ['']
clientlist = pd.read_csv('2018 ABACUS CLIENTS.csv')
# clientlist

# %%
productlist = pd.read_csv('product.csv',encoding='latin1' )
# productlist
productlist
# Out:
#                                                  p_name           unit  \
# 0     0.125-3.0mm Building Material Gi Galvanized St...           TONS
# 1     0.12-6.0mm Dx51d Steel Material Galvanized Ste...           TONS
# 2     0.15*665mm Ral3009 PPGI Corrugated Prepainted ...           TONS
# 3          0.15-0.8mm Cold Rolled Galvanized Steel Coil           TONS
# 4                    100X100mm Carbon Steel Square Tube           TONS
# 5     12mm Building Material Artificial Stone Acryli...            PCS
# 6     12mm Building Material Big Slab Marble Like Ve...            PCS
# 7     150kg/M3 Insulation Board Rockwool with 80% Ba...           TONS
# 8                     201 304 316 Stainless Steel Plate           TONS
# 9     2017 Building Material Rapid Rolling High Spee...            PCS
# 10              25mm White Color Marble Honeycomb Panel  SQUARE METERS
# 11    3003h24 Flat Aluminum Sheet Metal Building Con...  SQUARE METERS
# 12                  316 Grade Stainless Steel Round Bar           TONS
# 13                                  4pcf EVA Foam Sheet  SQUARE METERS
# 14         80X40X2.0mm-380X110X4.0mm C Channel C Purlin           TONS
# 15    A36 Carbon Checkered Floor Steel Plate/Ms Chec...           TONS
# 16                    Acoustic Decorative Ceiling Tiles  SQUARE METERS
# 17      Aluminium Bi-Fold Door and Glass Accordion Door            PCS
# 18    Aluminium Extrusion Building Material Horizont...  SQUARE METERS
# 19                                    Aluminium Profile           TONS
# 20    Aluminium Sliding Door Security Doors with Dou...  SQUARE METERS
# 21                         Aluminium Tilt & Turn Window  SQUARE METERS
# 22    Aluminum Awing Windows with Timber Reveal Install  SQUARE METERS
# 23                          Aluminum Curtain Wall Panel  SQUARE METERS
# 24                                      Aluminum Panels  SQUARE METERS
# 25    ANSI Certified Building Material/Construction ...            PCS
# 26    Artificial Quartz Stone with SGS Standards (bl...            PCS
# 27    Artificial Quartz STONSe for Building Material...  SQUARE METERS
# 28            ASTM A53 ERW Welded Galvanized Steel Pipe           TONS
# 29    ASTM Cold Rolled Stainless Steel Sheet Buildin...           TONS
# ...                                                 ...            ...
# 3325  Shoe Leather Computer Programmable Pattern Sew...            PCS
# 3326  Four-Column Fabric Sample Die Hydraulic Press ...            PCS
# 3327      Jgh-103 CO2 Laser Marking Machine for Leather           SETS
# 3328    Hg-120t Hydraulic Embossing Machine for Leather            PCS
# 3329       Automatic Double-Side Leather Canvas Rubber            SETS
# 3330  Spm 8 Colors Manual Rotary Leather/Textile Pri...           SETS
# 3331  Genuine L Leather Luxury V Women Black Tote Ha...            PCS
# 3332  Custom Lady Hang Bag Factory Handmade GenuineL...            PCS
# 3333  Full Grain Real Leather Luxury Handbags, Leath...            PCS
# 3334  Fashion Brand Replica Handbag Leather Women Ha...            PCS
# 3335  Genuine Leather Handbags for Women, Luxury Bra...            PCS
# 3336  Built-in Fingerprint Lock Handbag Men's Genuin...            PCS
# 3337  Custom Design High Quality Carbon Fiber Leathe...            PCS
# 3338        New Design L Style V Luxury Leather Handbag            PCS
# 3339  Full Grain Leather Luxury Handbag, Fancy Handb...            PCS
# 3340  Genuine Leather Lady Handbag From Guangzhou Fa...            PCS
# 3341  Women Bag Female Travel Full Grain Leather Han...            PCS
# 3342  Modern Living Room Furniture L Shape Genuine R...            PCS
# 3343  Home Furniture Living Room L Shape Leather Rec...            PCS
# 3344  Latest Multi-Purpose Sectional Wooden Leather ...            PCS
# 3345  Modern Living Room Furniture Italian Leather S...           SETS
# 3346  (SP-HC584) Customized China Loose Furniture Si...            PCS
# 3347  S749 Popular Living Room Furniture Sofa Buffal...            PCS
# 3348  American Style Classic Furniture Elegant Leath...            PCS
# 3349                240g TPU Leather for Furniture Sofa  SQUARE METERS
# 3350  Professional Furniture Factory Wholesale Price...            PCS
# 3351  Black Modern Denmark Style Wooden Italian Leat...            PCS
# 3352  European Home Furniture Living Room Corner Rec...            PCS
# 3353  Modern Home Furniture Living Room L Shape Recl...            PCS
# 3354            Women Back Color PU Leather Bike Jacket            PCS
#
#        dollar      dirham       euro      type  tradingTypeCode
# 0      600.00   2202.0000   516.0000  BUILDING                1
# 1      850.00   3119.5000   731.0000  BUILDING                1
# 2      820.00   3009.4000   705.2000  BUILDING                1
# 3      550.00   2018.5000   473.0000  BUILDING                1
# 4      650.00   2385.5000   559.0000  BUILDING                1
# 5      120.00    440.4000   103.2000  BUILDING                1
# 6      129.00    473.4300   110.9400  BUILDING                1
# 7      925.00   3394.7500   795.5000  BUILDING                1
# 8      650.00   2385.5000   559.0000  BUILDING                1
# 9     1200.00   4404.0000  1032.0000  BUILDING                1
# 10      60.00    220.2000    51.6000  BUILDING                1
# 11      68.00    249.5600    58.4800  BUILDING                1
# 12    3888.00  14268.9600  3343.6800  BUILDING                1
# 13     260.00    954.2000   223.6000  BUILDING                1
# 14     650.00   2385.5000   559.0000  BUILDING                1
# 15     700.00   2569.0000   602.0000  BUILDING                1
# 16      50.00    183.5000    43.0000  BUILDING                1
# 17     350.00   1284.5000   301.0000  BUILDING                1
# 18      70.00    256.9000    60.2000  BUILDING                1
# 19    2300.00   8441.0000  1978.0000  BUILDING                1
# 20     100.00    367.0000    86.0000  BUILDING                1
# 21     100.00    367.0000    86.0000  BUILDING                1
# 22     100.00    367.0000    86.0000  BUILDING                1
# 23      60.00    220.2000    51.6000  BUILDING                1
# 24      60.00    220.2000    51.6000  BUILDING                1
# 25      52.00    190.8400    44.7200  BUILDING                1
# 26      60.00    220.2000    51.6000  BUILDING                1
# 27     120.00    440.4000   103.2000  BUILDING                1
# 28     800.00   2936.0000   688.0000  BUILDING                1
# 29    6000.00  22020.0000  5160.0000  BUILDING                1
# ...       ...         ...        ...       ...              ...
# 3325  3500.00  12845.0000  3010.0000   Leather               60
# 3326  5090.00  18680.3000  4377.4000   Leather               60
# 3327  5200.00  19084.0000  4472.0000   Leather               60
# 3328  8000.00  29360.0000  6880.0000   Leather               60
# 3329  2500.00   9175.0000  2150.0000   Leather               60
# 3330  5000.00  18350.0000  4300.0000   Leather               60
# 3331    75.00    275.2500    64.5000   LEATHER               60
# 3332    40.00    146.8000    34.4000   LEATHER               60
# 3333    90.00    330.3000    77.4000   LEATHER               60
# 3334   210.00    770.7000   180.6000   LEATHER               60
# 3335    65.00    238.5500    55.9000   LEATHER               60
# 3336    69.00    253.2300    59.3400   LEATHER               60
# 3337   169.00    620.2300   145.3400   LEATHER               60
# 3338    75.00    275.2500    64.5000   LEATHER               60
# 3339    59.00    216.5300    50.7400   LEATHER               60
# 3340    43.50    159.6450    37.4100   LEATHER               60
# 3341    79.00    289.9300    67.9400   LEATHER               60
# 3342  1160.00   4257.2000   997.6000   LEATHER               60
# 3343  1160.00   4257.2000   997.6000   LEATHER               60
# 3344  1000.00   3670.0000   860.0000   LEATHER               60
# 3345   700.00   2569.0000   602.0000   LEATHER               60
# 3346   100.00    367.0000    86.0000   LEATHER               60
# 3347   700.00   2569.0000   602.0000   LEATHER               60
# 3348  1360.00   4991.2000  1169.6000   LEATHER               60
# 3349    40.31    147.9377    34.6666   LEATHER               60
# 3350  1275.00   4679.2500  1096.5000   LEATHER               60
# 3351  1100.00   4037.0000   946.0000   LEATHER               60
# 3352  1380.00   5064.6000  1186.8000   LEATHER               60
# 3353  1160.00   4257.2000   997.6000   LEATHER               60
# 3354    60.00    220.2000    51.6000   LEATHER               60
#
# [3355 rows x 7 columns]

# %%
Colist = pd.read_excel('List of Companies.xlsx')
Colist
# Out:
#                                              companies  \
# 0                             ORLUX IMPORT,EXPORT GMBH
# 1    SHANDONG FUPPON AGRICULTURAL MACHINERY EQUIPME...
# 2                                       NEW HOPE GROUP
# 3                                              CARGILL
# 4                                         LAND O'LAKES
# 5                                                  BRF
# 6                                      FORFARMERS N.V.
# 7                                              NUTRECO
# 8                                           JA ZEN,NOH
# 9                                 ADII SYNERGY SDN BHD
# 10                                           FIMAR SPA
# 11                   KAITO ENTERPRISES COMPANY LIMITED
# 12                                ADII SYNERGY SDN BHD
# 13                                           FIMAR SPA
# 14                   KAITO ENTERPRISES COMPANY LIMITED
# 15         SUZHOU CLEANSTAR ELECTRIC APPLIANCE CO. LTD
# 16              GUANGDONG ZHONGBAO KITCHENWARE CO. LTD
# 17                HOWELL CLEAN APPLIANCES (HK) LIMITED
# 18              GUANGDONG ZHONGBAO KITCHENWARE CO. LTD
# 19                HOWELL CLEAN APPLIANCES (HK) LIMITED
# 20         SUZHOU CLEANSTAR ELECTRIC APPLIANCE CO. LTD
# 21                   ANHUIARTS & CRAFTS IMP.EXP.CO.LTD
# 22                   ANHUIARTS & CRAFTS IMP.EXP.CO.LTD
# 23                                      MENGYANG GROUP
# 24                                          SENECA SRL
# 25                              R.B.AUTOMAZIONE S.R.L.
# 26                           ARAYMOND FLUID CONNECTION
# 27                               AUTOMATION CO. UNITED
# 28                    FAURECIA SIEGES D AUTOMOBILE SAS
# 29                            GTEC AUTOMOBILE PTE LTD.
# ..                                                 ...
# 957        GUANGZHOU ASTAR KITCHEN EQUIPMENT CO., LTD.
# 958          P & S INTERNATIONAL ELECTRONICS CO., LTD.
# 959           SHANDONG PESEN IMPORT & EXPORT CO., LTD.
# 960               APEX REFRIGERATION EQUIPMENT LIMITED
# 961             WUXI MENGYANG AUTOMOBILE MOTOR CO.LTD.
# 962            WUXI YUAN YUAN MOTOR MANUFACTURE CO.LTD
# 963           WUXI MENGTE HYDRAULIC MANUFACTURE CO.LTD
# 964                HARBIN MENGYANG IMP.& EXP.CORP.LTD.
# 965                               MICHELIN REIFENWERKE
# 966                               SUMITOMO CORPORATION
# 967                              AISIN SEIKI CO., LTD.
# 968                              ZF FRIEDRICHSHAFEN AG
# 969                            MAGNA INTERNATIONAL INC
# 970                                  DENSO DAIAN PLANT
# 971                                   JOHNSON CONTROLS
# 972     CONTINENTAL AUTOMOTIVE SYSTEMS SLOVAKIA S.R.O.
# 973                      ACTRON TECHNOLOGY CORPORATION
# 974                              ADRIANA RESOURCES INC
# 975                                AMALGAMATIONS GROUP
# 976                           ANAND AUTOMOTIVE LIMITED
# 977                       TAKATA INDIA PRIVATE LIMITED
# 978                                   ANG AUTO LIMITED
# 979                    ANHUI BBCA BIOCHEMICAL CO.,LTD.
# 980             ANHUI FENGYUAN PHARMACEUTICAL CO. LTD.
# 981                   ANHUI GUJING DISTILLERY CO. LTD.
# 982                                APM SPRINGS SDN BHD
# 983             ANHUI ZHONGDING SEALING PARTS CO., LTD
# 984                               AUNDE FAZE THREE LTD
# 985                       AZUREWAVE TECHNOLOGIES, INC.
# 986                      BALKRISHNA INDUSTRIES LIMITED
#
#                        country                    type  \
# 0           Frankfurt, Germany            AGRICULTURAL
# 1             Liaocheng, China  AGRICULTURAL MACHINERY
# 2           Gansu Sheng, China             ANIMAL FOOD
# 3        Topeka, United States             ANIMAL FOOD
# 4       Florida, United States             ANIMAL FOOD
# 5         Ponta Grossa, Brazil             ANIMAL FOOD
# 6          Lochem, Netherlands             ANIMAL FOOD
# 7         Boxmeer, Netherlands             ANIMAL FOOD
# 8                 Tokyo, Japan             ANIMAL FOOD
# 9       Kuala Lumpur, Malaysia               APLLIANCE
# 10      Villa Verucchio, Italy               APLLIANCE
# 11            Hong Kong, China               APLLIANCE
# 12      Kuala Lumpur, Malaysia               APLLIANCE
# 13      Villa Verucchio, Italy               APLLIANCE
# 14            Hong Kong, China               APLLIANCE
# 15             Shanghai, China               APPLIANCE
# 16            Guangdong, China               APPLIANCE
# 17            Hong Kong, China               APPLIANCE
# 18            Guangdong, China               APPLIANCE
# 19            Hong Kong, China               APPLIANCE
# 20             Shanghai, China               APPLIANCE
# 21                Anhui, China                     ART
# 22                Anhui, China                     ART
# 23              Jiangsu, China               SPARE CAR
# 24                Padua, Italy               SPARE CAR
# 25               Genova, Italy               SPARE CAR
# 26            Grenoble, France               SPARE CAR
# 27   Liverpool, United Kingdom               SPARE CAR
# 28            Nanterre, France               SPARE CAR
# 29               Padova, Italy               SPARE CAR
# ..                         ...                     ...
# 957           Guangzhou, China            refrigerator
# 958              Xiamen, China            refrigerator
# 959               Jinan, China            refrigerator
# 960              Foshan, China            refrigerator
# 961                Wuxi, China              Auto parts
# 962             Jiangsu, China              Auto parts
# 963                Wuxi, China              Auto parts
# 964              Harbin, China              Auto parts
# 965         Karlsruhe, Germany              Auto parts
# 966               Osaka, Japan              Auto parts
# 967              Kariya, Japan              Auto parts
# 968   Friedrichshafen, Germany              Auto parts
# 969           Brampton, Canada              Auto parts
# 970               Inabe, Japan              Auto parts
# 971        Richland Hills, USA              Auto parts
# 972           Zvolen, Slovakia              Auto parts
# 973       Taoyuan City, Taiwan              Auto parts
# 974            Toronto, Canada              Auto parts
# 975             Chennai, India              Auto parts
# 976           New Delhi, India              Auto parts
# 977               Anjur, India              Auto parts
# 978           New Delhi, India              Auto parts
# 979              Bengbu, China              Auto parts
# 980               Anhui, China              Auto parts
# 981              Bozhou, China              Auto parts
# 982       Port Klang, Malaysia              Auto parts
# 983             Ningguo, China              Auto parts
# 984              Mumbai, India              Auto parts
# 985    New Taipei City, Taiwan              Auto parts
# 986              Mumbai, India              Auto parts
#
#                      origin  loading  discharge  tradingTypeCode
# 0           Origin: Germany      NaN        NaN             21.0
# 1             Origin: China      NaN        NaN             21.0
# 2             Origin: China      NaN        NaN             22.0
# 3     Origin: United States      NaN        NaN             22.0
# 4     Origin: United States      NaN        NaN             22.0
# 5            Origin: Brazil      NaN        NaN             22.0
# 6       Origin: Netherlands      NaN        NaN             22.0
# 7       Origin: Netherlands      NaN        NaN             22.0
# 8             Origin: Japan      NaN        NaN             22.0
# 9          Origin: Malaysia      NaN        NaN             17.0
# 10            Origin: Italy      NaN        NaN             17.0
# 11            Origin: China      NaN        NaN             17.0
# 12         Origin: Malaysia      NaN        NaN             17.0
# 13            Origin: Italy      NaN        NaN             17.0
# 14            Origin: China      NaN        NaN             17.0
# 15            Origin: China      NaN        NaN             17.0
# 16            Origin: China      NaN        NaN             17.0
# 17            Origin: China      NaN        NaN             17.0
# 18            Origin: China      NaN        NaN             17.0
# 19            Origin: China      NaN        NaN             17.0
# 20            Origin: China      NaN        NaN             17.0
# 21            Origin: China      NaN        NaN              NaN
# 22            Origin: China      NaN        NaN              NaN
# 23            Origin: China      NaN        NaN             26.0
# 24            Origin: Italy      NaN        NaN             26.0
# 25            Origin: Italy      NaN        NaN             26.0
# 26           Origin: France      NaN        NaN             26.0
# 27   Origin: United Kingdom      NaN        NaN             26.0
# 28           Origin: France      NaN        NaN             26.0
# 29            Origin: Italy      NaN        NaN             26.0
# ..                      ...      ...        ...              ...
# 957                     NaN      NaN        NaN             57.0
# 958                     NaN      NaN        NaN             57.0
# 959                     NaN      NaN        NaN             57.0
# 960                     NaN      NaN        NaN             57.0
# 961                     NaN      NaN        NaN             26.0
# 962                     NaN      NaN        NaN             26.0
# 963                     NaN      NaN        NaN             26.0
# 964                     NaN      NaN        NaN             26.0
# 965                     NaN      NaN        NaN             26.0
# 966                     NaN      NaN        NaN             26.0
# 967                     NaN      NaN        NaN             26.0
# 968                     NaN      NaN        NaN             26.0
# 969                     NaN      NaN        NaN             26.0
# 970                     NaN      NaN        NaN             26.0
# 971                     NaN      NaN        NaN             26.0
# 972                     NaN      NaN        NaN             26.0
# 973                     NaN      NaN        NaN             26.0
# 974                     NaN      NaN        NaN             26.0
# 975                     NaN      NaN        NaN             26.0
# 976                     NaN      NaN        NaN             26.0
# 977                     NaN      NaN        NaN             26.0
# 978                     NaN      NaN        NaN             26.0
# 979                     NaN      NaN        NaN             26.0
# 980                     NaN      NaN        NaN             26.0
# 981                     NaN      NaN        NaN             26.0
# 982                     NaN      NaN        NaN             26.0
# 983                     NaN      NaN        NaN             26.0
# 984                     NaN      NaN        NaN             26.0
# 985                     NaN      NaN        NaN             26.0
# 986                     NaN      NaN        NaN             26.0
#
# [987 rows x 7 columns]

# %%
track = pd.read_excel('TRACK.xlsx')
track
# Out:
#        refrence                      COMPANY NAME       CO.City  \
# 0      SS-20234  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 1      SS-20231  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 2      SS-20232  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 3   SS-20230-CL  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 4   SS-20233-CL  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 5      SS-20260  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 6      SS-20242  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 7      SS-20236  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 8      SS-20248  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 9      SS-20258  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 10     SS-20263  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 11  SS-20262-CL  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 12  SS-20257-CL  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 13  SS-20253-CL  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 14  SS-20240-CL  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 15  SS-20246-CL  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 16  SS-20251-CL  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 17  SS-20250-CL  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 18     SS-20271  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 19     SS-20272  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 20     SS-20273  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 21     SS-20268  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 22  SS-20270-CL  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 23  SS-20265-CL  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
# 24  SS-20267-CL  SMART STAR MACHINERY TRADING LLC  Dubai, U.A.E
#
#                           SOURCE COMPANY   SourceCo.City TYPE OF TRANSACTION  \
# 0   KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 1   KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 2   KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 3   KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 4   KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 5   KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 6   KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 7   KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 8   KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 9   KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 10  KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 11  KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 12  KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 13  KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 14  KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 15  KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 16  KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 17  KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 18  KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 19  KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 20  KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 21  KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 22  KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 23  KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
# 24  KAITO CONSTRUCTION MACHINERY CO. LTD  Jiangsu, China      GOODS IN TRUST
#
#            MONTH  TYPE OFProducts       date   amount currency  \
# 0   JANUARY 2018               25 2019-04-28    44112      AED
# 1   JANUARY 2018                1 2019-04-25    21320      USD
# 2   JANUARY 2018                1 2019-04-25    61425      USD
# 3   JANUARY 2018               25 2019-04-24    56700     EURO
# 4   JANUARY 2018               25 2019-04-22  1560000      AED
# 5   JANUARY 2018               25 2019-05-25    43200      USD
# 6   JANUARY 2018               25 2019-05-02    24985     EURO
# 7   JANUARY 2018                1 2019-05-01    10000     EURO
# 8   JANUARY 2018                1 2019-05-06    84653     EURO
# 9   JANUARY 2018               46 2019-05-22    75305     EURO
# 10  JANUARY 2018               35 2019-05-30     7500      USD
# 11  JANUARY 2018               25 2019-05-23    75106     EURO
# 12  JANUARY 2018               25 2019-05-18   101738     EURO
# 13  JANUARY 2018               25 2019-05-05    99926     EURO
# 14  JANUARY 2018               27 2019-05-02    55948     EURO
# 15  JANUARY 2018               25 2019-05-04   880000      AED
# 16  JANUARY 2018               25 2019-05-01  1352000      AED
# 17  JANUARY 2018                1 2019-05-02   138465     EURO
# 18  JANUARY 2018                1 2019-06-19   117000     EURO
# 19  JANUARY 2018                1 2019-06-19    64800      USD
# 20  JANUARY 2018               25 2019-06-24    21151     EURO
# 21  JANUARY 2018               44 2019-06-16    27206      USD
# 22  JANUARY 2018               26 2019-06-16    16414      USD
# 23  JANUARY 2018               25 2019-06-01    43000     EURO
# 24  JANUARY 2018               26 2019-06-11   196960     EURO
#
#                                  exporter/repExporter  \
# 0                                                 NaN
# 1                        FLASON ELECTRONIC CO LIMITED
# 2               HANGZHOU WEIGUANG ELECTRONIC CO., LTD
# 3                                 QUALITY FORMING SRL
# 4                                                 NaN
# 5                    SHAOXING TLONG ELECTRIC CO., LTD
# 6                                                 NaN
# 7                    HEYLAN MANUFACTURERS AND TRADERS
# 8                                     NADE ELEKTRONIK
# 9                           PETROCHEX TRADING DWC LLC
# 10                      POWER ELECTRIC GLOBAL LIMITED
# 11                                QUALITY FORMING SRL
# 12                                QUALITY FORMING SRL
# 13                                QUALITY FORMING SRL
# 14  PARATEK MAKINA MUHENDISLIK INSAAT TURIZM SANAY...
# 15                                                NaN
# 16                                                NaN
# 17                   BEMAS METAL SANAYI VE TICARET AS
# 18                                    EURORICAMBI SPA
# 19                             QINGDAO SUNSONG CO LTD
# 20                                QUALITY FORMING SRL
# 21       SHANGHAI LIANYING IMPORT AND EXPORT CO., LTD
# 22                                    VICTKEY LIMITED
# 23                                QUALITY FORMING SRL
# 24                            HWASEUNG R & A Co.,Ltd.
#
#                           country  Unnamed: 13  Unnamed: 14  \
# 0                             NaN          NaN          NaN
# 1                 Shenzhen, China          NaN          NaN
# 2                 Hangzhou, China          NaN          NaN
# 3                Orzinuovi, Italy          NaN          NaN
# 4                             NaN          NaN          NaN
# 5                 Zhejiang, China          NaN          NaN
# 6                             NaN          NaN          NaN
# 7             Moratuwa, Sri Lanka          NaN          NaN
# 8                Istanbul, Turkey          NaN          NaN
# 9                    Dubai, U.A.E          NaN          NaN
# 10       British Columbia, Canada          NaN          NaN
# 11               Orzinuovi, Italy          NaN          NaN
# 12               Orzinuovi, Italy          NaN          NaN
# 13               Orzinuovi, Italy          NaN          NaN
# 14               Istanbul, Turkey          NaN          NaN
# 15                            NaN          NaN          NaN
# 16                            NaN          NaN          NaN
# 17                  Izmir, Turkey          NaN          NaN
# 18                 Bologna, Italy          NaN          NaN
# 19                Shandong, China          NaN          NaN
# 20               Orzinuovi, Italy          NaN          NaN
# 21                Shanghai, China          NaN          NaN
# 22                Shanghai, China          NaN          NaN
# 23               Orzinuovi, Italy          NaN          NaN
# 24  Gyeongsangnam-do, South Korea          NaN          NaN
#
#                                           Unnamed: 15
# 0                       USED MACHINERY OR SPARE PARTS
# 1                          https://www.flasonsmt.com/
# 2                     http://www.wgmotor.com/english/
# 3                      PURCHASED MACHINER SPARE PARTS
# 4                       USED MACHINERY OR SPARE PARTS
# 5   Radial blower , Hydraulic valve sets , Actuati...
# 6                       USED MACHINERY OR SPARE PARTS
# 7                      http://www.heylancocopeat.com/
# 8                     http://nade.allactiontrade.com/
# 9                                  PETROLEUM PRODUCTS
# 10                                ELECTRICAL SUPPLIES
# 11                     PURCHASED MACHINER SPARE PARTS
# 12                     PURCHASED MACHINER SPARE PARTS
# 13                     PURCHASED MACHINER SPARE PARTS
# 14                                    USED MACHINERY
# 15                      USED MACHINERY OR SPARE PARTS
# 16                      USED MACHINERY OR SPARE PARTS
# 17                         http://www.bemasmetal.com/
# 18                        http://www.euroricambi.com/
# 19                             http://en.sun-song.cn/
# 20                     PURCHASED MACHINER SPARE PARTS
# 21  Frozen foodstuffs: roasted eel, noodles Udon a...
# 22                  Ball Bearing Slide, Lock Products
# 23                     PURCHASED MACHINER SPARE PARTS
# 24   Parts and Accessories for Motor Vehicles and ...

# %%
def getBoldataframe(TradingCode, datalist):
    codeVector = []
    for procode in datalist['tradingTypeCode']:
        if procode ==TradingCode:
            codeVector.append(True)
        else:
            codeVector.append(False)

    return datalist[codeVector]

# %%
# Distangolishing rep.Exporter and exporter in tacking sheet.
repOrMainCo = [True if (('UAE' in str(x))or('uae' in str(x))or('U.A.E' in str(x))or('u.a.e' in str(x))) else False for x in track['country']]# All type of uae

def randomExporter(i, datalist):
    tradedataframe = getBoldataframe(i,datalist)
    r, _ = tradedataframe.shape
    count = np.floor(np.random.rand()*r)
    return str(datalist.loc[count,'companies']),str(datalist.loc[count,'country'])
repExporter = []
cityOfRepExporter = []
exporter = []
cityOfExporter = []
for i in range(len(repOrMainCo)):
    if repOrMainCo[i]:
        repExporter.append(str(track.loc[i, 'exporter/repExporter']).upper())
        cityOfRepExporter.append(str(track.loc[i, 'country']).title())
    else:
        repExporter.append('')
        cityOfRepExporter.append('')

    if not (repOrMainCo[i]):
        exporter.append(str(track.loc[i, 'exporter/repExporter']).upper())
        cityOfExporter.append(str(track.loc[i, 'country']).title())
    else:
        exp , cityExp = randomExporter(track.loc[i,'TYPE OFProducts'],Colist)
        exporter.append(exp)
        cityOfExporter.append(cityExp.title())

# %%
ones = {
    0: '', 1: 'One', 2: 'Two', 3: 'Three', 4: 'Four', 5: 'Five', 6: 'Six',
    7: 'Seven', 8: 'Eight', 9: 'Nine', 10: 'Ten', 11: 'Eleven', 12: 'Twelve',
    13: 'Thirteen', 14: 'Fourteen', 15: 'Fifteen', 16: 'Sixteen',
    17: 'Seventeen', 18: 'Eighteen', 19: 'Nineteen'}
tens = {
    2: 'Twenty', 3: 'Thirty', 4: 'Forty', 5: 'Fifty', 6: 'Sixty',
    7: 'Seventy', 8: 'Eighty', 9: 'Ninety'}
illions = {
    1: 'Thousand', 2: 'Million', 3: 'Billion', 4: 'Trillion', 5: 'Quadrillion',
    6: 'Quintillion', 7: 'Sextillion', 8: 'Septillion', 9: 'Octillion',
    10: 'Nonillion', 11: 'Decillion'}

def say_number(i):
    """
    Convert an integer in to it's word representation.

    say_number(i: integer) -> string
    """
    if i < 0:
        return _join('Negative', _say_number_pos(-i))
    if i == 0:
        return 'Zero'

    return _say_number_pos(i)


def _say_number_pos(i):
    if i == 0:
        return ''
    if i < 1:
        return str(np.round(i*100)) + '/100'
    if i < 20:
        return _join(ones[int(i)],_say_number_pos(i % 1))
    if i < 100:
        return _join(_join(tens[i // 10], ones[int(i) % 10]),_say_number_pos(i % 1))
    if i < 1000:
        return _divide(i, 100, 'Hundred')
    for illions_number, illions_name in illions.items():
        if i < 1000**(illions_number + 1):
            break
    return _divide(i, 1000**illions_number, illions_name)


def _divide(dividend, divisor, magnitude):
    return _join(
        _say_number_pos(dividend // divisor),
        magnitude,
        _say_number_pos(dividend % divisor),
    )


def _join(*args):
    return ' '.join(filter(bool, args))

# %%
amountToWord = []
c = 0
for number in track['amount']:
    number = np.round(number, decimals=2)
    if str(track.loc[c,'currency']).lower() == 'euro':
        amountToWord.append(say_number(number) + ' Euros Only')
    elif str(track.loc[c,'currency']).lower() == 'aed':
        amountToWord.append(say_number(number) + ' Dirhams Only')
    elif str(track.loc[c,'currency']).lower() == 'pound':
        amountToWord.append(say_number(number) + ' Pound sterlings Only')
    elif str(track.loc[c,'currency']).lower() == 'cad':
        amountToWord.append(say_number(number) + ' canadian Dollars Only')
    elif str(track.loc[c,'currency']).lower() == 'usd':
        amountToWord.append(say_number(number) + ' U.S Dollars Only')
    c +=1

# %%
#,DIS1,QTY1,UNIT1,UNITPRICE1,TOTAL1,DIS2,QTY2,UNIT2,UNITPRICE2,TOTAL2
# businessType, REF, Date,IMPORTER,CTOFIM,REPPOFIM,CTOFREPOFIM,REPOFEXPORTER,CTOFREPOFEXPORTER,EXPORTER,CTOFEX,TOTALAMOUNT,Currency,INWORDS,ORIGIN,LO,DIS, amountInWord

importer = track['SOURCE COMPANY']
repImporter = track['COMPANY NAME']
cityOfImporter = track['SourceCo.City']
cityOfrepImporter = track['CO.City']

# %%
# def lcs(X , Y): 
#     # find the length of the strings 
#     m = len(X) 
#     n = len(Y) 
  
#     # declaring the array for storing the dp values 
#     L = [[None]*(n+1) for i in range(m+1)] 
  
#     """Following steps build L[m+1][n+1] in bottom up fashion 
#     Note: L[i][j] contains length of LCS of X[0..i-1] 
#     and Y[0..j-1]"""
#     for i in range(m+1): 
#         for j in range(n+1): 
#             if i == 0 or j == 0 : 
#                 L[i][j] = 0
#             elif X[i-1] == Y[j-1]: 
#                 L[i][j] = L[i-1][j-1]+1
#             else: 
#                 L[i][j] = max(L[i-1][j] , L[i][j-1]) 
  
#     # L[m][n] contains the length of LCS of X[0..n-1] & Y[0..m-1] 
#     return L[m][n] 
# #end of function lcs

# %%
# def getClientRef(c, clientlist):
#     num = str(clientlist.loc[c,'SR. NO.']) + '.'
#     for char in clientlist.loc[c,'LIST OF COMPANY']:
#         if char != '.':
#             num = num + char
#         else:
#             break
#     return num
    
# def bestmatch(candid,clientlist):
#     # Remove all bad charachters.
#     candid = ''.join(e for e in candid if e.isalnum())
#     c = 0
#     maxAl = 0
#     candidRow = []
#     num = ''
#     maxLCStoClient = 0
#     for client in clientlist['LIST OF COMPANY']:
#     #     print(client)
#         candidLcs = lcs(candid.lower(), client.lower())
#         LCStoClient = candidLcs / len(client)
# #         print(candidLcs)
# #         print(len(candid),candidLcs)
# #         if candidLcs > maxAl:
# #             match = c
# #             maxAl = candidLcs
# #             maxLCStoClient = LCStoClient
# #         elif (candidLcs == maxAl) and (maxLCStoClient < LCStoClient):
# #             match = c
# #             maxAl = candidLcs
# #             maxLCStoClient = LCStoClient                
                
# #         print(len(candid),candidLcs)
#         if (candidLcs == len(candid)):
# #             print(len(client.lower()))
# #             print(len(candid),candidLcs)
#             if (candidLcs / len(client.lower()) >= 0.5):
#                 if (maxLCStoClient < LCStoClient):
#                     candidRow = list(clientlist.iloc[c])
#                     num = getClientRef(c, clientlist)
#                     maxLCStoClient = LCStoClient
# #                 print(maxLCStoClient)
# #                 print(num, candidRow)
#         c+=1


#     return num, candidRow
# bestmatch('AL FEEL TRADING LLC',clientlist)

# %%
def getClientRef(c, clientlist):
    num = str(clientlist.loc[c,'SR. NO.']) + '.'
    num = num + clientlist.loc[c,'LIST OF COMPANY'][:4]
#     for char in clientlist.loc[c,'LIST OF COMPANY']:
#         if char != '.':
#             num = num + char
#         else:
#             break
    return num
def exactMatch(candid,clientlist):
    candid = ''.join(e for e in candid if e.isalnum())
    candidRow = []
    c = 0
    num = ''
    for client in clientlist['LIST OF COMPANY']:
        client = ''.join(e for e in client if e.isalnum())
        if client == candid:
            candidRow = list(clientlist.iloc[c])
            num = getClientRef(c, clientlist)
        c +=1
    return num, candidRow

# %%
for i in range(len(exporter)):
    if (str(exporter[i]) == '') or (str(exporter[i]) == str(np.nan)) or (str(exporter[i]) == 'NAN'):
        exp , cityExp = randomExporter(track.loc[i,'TYPE OFProducts'],Colist)
        exporter[i] =  exp
        cityOfExporter[i] = cityExp

# %%
numlist = []
veclist = []
c = 0
for client in repExporter:
#     num , vec = bestmatch(client,clientlist)
    num, vec = exactMatch(client,clientlist)
    numlist.append(num)
    veclist.append(vec)
    if vec != []:
        cityOfRepExporter[c] = vec[3].title()
        exporter[c] = vec[4].upper()
        cityOfExporter[c] = vec[5]
    c += 1

# %%
def QtyClassification(amount, mean):
    estQty = int(amount / mean)
    if (estQty < 30):
        return 1
    elif (estQty >= 30) and (estQty < 80):
        return np.ceil(np.random.randint(1,2,1))
    
    if (estQty >= 80) and (estQty < 150):
        return np.ceil(np.random.randint(2,3,1))
    
    elif (estQty >= 150) and (estQty < 300):
        return np.ceil(np.random.randint(2,4,1))
    
    elif (estQty >= 300) and (estQty < 600):
        return np.ceil(np.random.randint(3,4,1))

    elif (estQty >= 600) and (estQty <1000 ):
        return np.ceil(np.random.randint(4,5,1))

    elif (estQty > 1000 ):
        return 5

# %%
#Choosing products

def getRandomKProduct(amount,iD, datalist):
    tradedataframe = getBoldataframe(iD,datalist)
    codeVector = []
    amount = np.round(amount, decimals=2)
    # removing greater than amount
    for proAmount in tradedataframe['dollar']:
        proAmount = np.round(proAmount, decimals=2)
        if amount > proAmount:
            codeVector.append(True)
        else:
            codeVector.append(False)
    tradedataframe = tradedataframe[codeVector]
    #Computing mean value
    codeVector = []
    mean = np.mean(tradedataframe['dollar'])

    for proAmount in tradedataframe['dollar']:
        if (proAmount > mean/80) and proAmount < mean*80:
            codeVector.append(True)
        else:
            codeVector.append(False)
    
    r, _ = tradedataframe.shape

    tradedataframe = tradedataframe[codeVector]
    
    r, _ = tradedataframe.shape

    k = int(QtyClassification(amount , mean))

    produc = []
    if k < r:
        for i in range(k):
            count = np.random.randint(0,r-1,1)

            produc.append(list(tradedataframe.iloc[count[0]]))
            tradedataframe.drop(tradedataframe.index[count[0]], inplace=True)
            r, c = tradedataframe.shape

    else:
        produc =tradedataframe

    RandomKProduct = pd.DataFrame(produc)

    RandomKProduct.columns = ['p_name','unit','dollar','dirham','euro','type','tradingTypeCode']
    return RandomKProduct

# %%
def changeCurrency(i , data):
#     print(str(track.loc[i,'currency']).lower())
    
    if str(track.loc[i,'currency']).lower() == 'euro':

        return float(track.loc[i,'amount'] * 1.13)
    elif str(track.loc[i,'currency']).lower()[:] == 'aed':

        return float(track.loc[i,'amount'] * 0.27)
    elif str(track.loc[i,'currency']).lower() == 'pound':

        return float(track.loc[i,'amount'] * 1.32)
    elif str(track.loc[i,'currency']).lower() == 'cad':

        return float(track.loc[i,'amount'] * 0.75)
    else:

        return

# %%
def returnCurrency( unitp, i, trak):
    if str(track.loc[i,'currency']).lower() == 'euro':
        return float(unitp) * 0.89
    elif str(track.loc[i,'currency']).lower() == 'aed':
        return float(unitp) * 3.67
    elif str(track.loc[i,'currency']).lower() == 'pound':
        return float(unitp) * 0.76
    elif str(track.loc[i,'currency']).lower() == 'cad':
        return float(unitp) * 1.34
    else:
        return unitp

# %%
#amount    currency
#1
p1name = []
p1unit = []
p1unitp = []
p1qty = []
p1total = []
#2
p2name = []
p2unit = []
p2unitp = []
p2qty = []
p2total = []
#3
p3name = []
p3unit = []
p3unitp = []
p3qty = []
p3total = []
#4
p4name = []
p4unit = []
p4unitp = []
p4qty = []
p4total = []
#5
p5name = []
p5unit = []
p5unitp = []
p5qty = []
p5total = []
for i in range(len(track['date'])):

    pname = []
    unit = []
    unitp = []
    qty = []
    total = []

    if str(track.loc[i,'currency']).lower() == 'usd':
        amount = float(track.loc[i,'amount'])
    else:
        amount = float(changeCurrency(i,track))
    amount = np.round(amount, decimals=2)
    TradingCode = track.loc[i, 'TYPE OFProducts']
    RandomKProduct = getRandomKProduct(amount, TradingCode, productlist)
    RandomKProduct = RandomKProduct.sort_values(by='dollar', ascending=False)
    
    copyamount = amount = np.round(float(track.loc[i,'amount']), decimals=2)

    #allocating rest of amount
    tot = 0
    tempqty = 0
    if (len(RandomKProduct['p_name']) > 1):
        for j in range(len(RandomKProduct['p_name']) - 1):
            bound = int(copyamount / float(returnCurrency(RandomKProduct.loc[j,'dollar'],i ,track)))
            pname.append(RandomKProduct.loc[j,'p_name'] )
            unit.append(RandomKProduct.loc[j,'unit'])
            unitp.append(returnCurrency(RandomKProduct.loc[j,'dollar'],i ,track))
            tempqty = np.floor(np.random.randint(1,(bound * 0.7),1)[0])
#             print((amount - (unitp[-1] * tempqty))/float(RandomKProduct.loc[j + 1,'dollar']))
#             while((amount - (unitp[-1] * tempqty))/float(RandomKProduct.loc[j + 1,'dollar']) < 1) and (amount - (unitp[-1] * tempqty)) < 0:
#                 tempqty = np.floor(np.random.randint(1,(bound/2),1)[0])
#                 print((amount - (unitp[-1] * tempqty))/float(RandomKProduct.loc[j + 1,'dollar']))
            copyamount = np.round(copyamount - (unitp[-1] * tempqty), decimals=2)
            qty.append(tempqty)
            total.append(np.round((unitp[-1] * qty[-1]), decimals=2))
            tot += np.round((unitp[-1] * qty[-1]), decimals=2)
    k = len(RandomKProduct['p_name']) - 1
    pname.append(RandomKProduct.loc[k,'p_name'] )
    unit.append(RandomKProduct.loc[k,'unit'])
    unitp.append(returnCurrency(RandomKProduct.loc[k,'dollar'],i ,track))
    qty.append(int(copyamount / unitp[-1]))


    unitp[-1] = float(copyamount / qty[-1])
    total.append(np.round((amount - tot), decimals=2))

    

    #1
    p1name.append(pname[0])
    p1unit.append(unit[0])
    p1unitp.append(unitp[0])
    p1qty.append(qty[0])
    p1total.append(total[0])
    #2
    if len(pname) > 1:
        p2name.append(pname[1])
        p2unit.append(unit[1])
        p2unitp.append(unitp[1])
        p2qty.append(qty[1])
        p2total.append(total[1])
    else:
        p2name.append('')
        p2unit.append('')
        p2unitp.append('')
        p2qty.append('')
        p2total.append('')
        
    #3
    if len(pname) > 2:
        p3name.append(pname[2])
        p3unit.append(unit[2])
        p3unitp.append(unitp[2])
        p3qty.append(qty[2])
        p3total.append(total[2])
    else:
        p3name.append('')
        p3unit.append('')
        p3unitp.append('')
        p3qty.append('')
        p3total.append('')        
    #4
    if len(pname) > 3:
        p4name.append(pname[3])
        p4unit.append(unit[3])
        p4unitp.append(unitp[3])
        p4qty.append(qty[3])
        p4total.append(total[3])
    else:
        p4name.append('')
        p4unit.append('')
        p4unitp.append('')
        p4qty.append('')
        p4total.append('')        
    #5
    if len(pname) > 4:
        p5name.append(pname[4])
        p5unit.append(unit[4])
        p5unitp.append(unitp[4])
        p5qty.append(qty[4])
        p5total.append(total[4])
    else:
        p5name.append('')
        p5unit.append('')
        p5unitp.append('')
        p5qty.append('')
        p5total.append('')

# %%
#Origin
origin = []
originWithoutOrigin = []
countryOfManufacture = []
countryOfManufactureWith = []
bol = False
for word in cityOfExporter:
    word = str(word)
    if word == '':
        origin.append(word)
        continue
    for i in range(len(word)):
        if word[i] == ',':
            origin.append('Origin: ' + str(word[(i+2):len(word)]))
            originWithoutOrigin.append(str(word[(i+2):len(word)]))
            countryOfManufacture.append(str(word[(i+2):len(word)]).upper())
            countryOfManufactureWith.append(('Country of Manufacture : ' + str(word[(i+2):len(word)])).upper())
            bol = True
            break
        else:
            bol = False
    if not bol:
        origin.append('Origin: ' + word)
        originWithoutOrigin.append(word)
        countryOfManufacture.append(str(word).upper())
        countryOfManufactureWith.append(('Country of Manufacture : ' + str(word)).upper())

# %%
#Loading
load = []
loadingWithoutLoading = []
for city in cityOfExporter:
    load.append('Loading: ' + str(city))
    loadingWithoutLoading.append(str(city))

# %%
#dischareg
dischareg = []
dischargeWithoutDischarge = []
countryOfDestination = []
countryOfDestinationWith = []
bol = False
for city in cityOfImporter:
    city = str(city)
    dischareg.append('Discharge: ' + str(city))
    dischargeWithoutDischarge.append(str(city))
    if city == '':
        countryOfDestination.append(city.upper())
        continue
    for i in range(len(city)):
        if city[i] == ',':
            countryOfDestination.append(str(city[(i+2):len(city)]).upper())
            countryOfDestinationWith.append(('Country of destination : ' + str(city[(i+2):len(city)])).upper())
            bol = True
            break
        else:
            bol = False
    if not bol:
        countryOfDestination.append(city.upper())   
        countryOfDestinationWith.append(('Country of destination : ' + city).upper())

# %%
amountInWordsWithString = []
for  amToW in amountToWord:
    amountInWordsWithString.append('Amount in Words : ' + amToW)

# %%
#Date
datePO = [] 
dateSQ = []
datePI = []
dateCIorPL =[]

datePOWith = [] 
dateSQWith = []
datePIWith = []
dateCIorPLWith =[]

for i in range(len(track['date'])):
    datePO.append('=TEXT(AP' + str(i+2) + ' -30,"dd/mm/yyyy")')
    dateSQ.append('=TEXT(AP' + str(i+2) + ' -31,"dd/mm/yyyy")')
    datePI.append('=TEXT(AP' + str(i+2) + ' -25,"dd/mm/yyyy")')
    dateCIorPL.append('=TEXT(AP' + str(i+2) + ' +10,"dd/mm/yyyy")')

    datePOWith.append('="Date: " & (TEXT(AP' + str(i+2) + ' -30,"dd/mm/yyyy"))')
    dateSQWith.append('="Date: " & (TEXT(AP' + str(i+2) + ' -31,"dd/mm/yyyy"))')
    datePIWith.append('="Date: " & (TEXT(AP' + str(i+2) + ' -25,"dd/mm/yyyy"))')
    dateCIorPLWith.append('="Date: " & (TEXT(AP' + str(i+2) + ' +10,"dd/mm/yyyy"))')

# %%
currwith = []
for curr in track['Currency']:
    currwith.append('Currency : ' + curr)

# %%
forPO = []
forPO = pd.DataFrame()
forPO['REF'] = track['refrence']

forPO['repExporter'], forPO['cityOfRepExporter'] = repExporter, list(cityOfRepExporter)
forPO['exporter'], forPO['cityOfExporter']  = exporter, cityOfExporter

forPO['importer'], forPO['cityOfImporter'] = importer, cityOfImporter
forPO['repImporter'], forPO['cityOfrepImporter'] = repImporter, list(cityOfrepImporter)

forPO['Origin'], forPO['laoding'], forPO['Discharge'] = origin, load, dischareg

forPO['totalAmount'], forPO['amountToWord'] = track['amount'], amountToWord
#1
forPO['p1name'] = p1name
forPO['p1qty'] = p1qty
forPO['p1unit'] = p1unit
forPO['p1unitp'] = p1unitp
forPO['p1total'] = p1total
#2
forPO['p2name'] = p2name
forPO['p2qty'] = p2qty
forPO['p2unit'] = p2unit
forPO['p2unitp'] = p2unitp
forPO['p2total'] =p2total
#3
forPO['p3name'] = p3name
forPO['p3qty'] = p3qty
forPO['p3unit'] = p3unit
forPO['p3unitp'] = p3unitp
forPO['p3total'] = p3total
#4
forPO['p4name'] = p4name
forPO['p4qty'] = p4qty
forPO['p4unit'] = p4unit
forPO['p4unitp'] = p4unitp
forPO['p4total'] = p4total
#5
forPO['p5name'] = p5name
forPO['p5qty'] = p5qty
forPO['p5unit'] = p5unit
forPO['p5unitp'] = p5unitp
forPO['p5total'] = p5total

forPO['numOfClient'] = numlist

forPO['currency'], forPO['date'] = track['currency'], track['date']

forPO['amount in words'] = amountInWordsWithString
forPO['origin without origin'] = originWithoutOrigin
forPO['loading without loading'] = loadingWithoutLoading
forPO['discharge without discharge'] = dischargeWithoutDischarge

forPO['country of manufacture'] = countryOfManufacture
forPO['country of destination'] = countryOfDestination

forPO['date of PO'] = datePO
forPO['date of SQ'] = dateSQ
forPO['date of PI'] = datePI
forPO['date of CIorPL'] = dateCIorPL

forPO['countryOfManufacture'] = countryOfManufactureWith
forPO['countryOfDestinationWith'] = countryOfDestinationWith

forPO['datePOWith'] = datePOWith
forPO['dateSQWith'] = dateSQWith
forPO['datePIWith'] = datePIWith
forPO['dateCIorPLWith'] = dateCIorPLWith

forPO['withcurrency'] = currwith

forPO.to_csv('Tracking Sheet Output.csv', index = False)
